# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None,120,25,1], 'inputs')
targets = tf.placeholder(tf.float32, [None, 25], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
def conv2d(x, w):
    return tf.nn.conv2d(x, w, strides = [1, 1, 1, 1], padding = 'VALID')
def pool(x, m, n):
    """
    
    Args:
        x: outputs of the last layer
        m: Raw of the max_pooling
        n: Column of the max_pooling
    
    """
    return tf.nn.max_pool(x, ksize = [1, m, n, 1], strides = [1, m, n, 1], padding = 'VALID')

# %%
weights = {
    'c1': tf.Variable(tf.random_normal([5, 1, 1, 30])),
    'c2': tf.Variable(tf.random_normal([5, 1, 30, 50])),
    'c3': tf.Variable(tf.random_normal([5, 1, 50, 70])),
    'd1': tf.Variable(tf.random_normal([7*25*70, 500])),
    'd2': tf.Variable(tf.random_normal([500,100])),
    'out': tf.Variable(tf.random_normal([100,25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([30])),
    'b2': tf.Variable(tf.random_normal([50])),
    'b3': tf.Variable(tf.random_normal([70])),
    'd1': tf.Variable(tf.random_normal([500])),
    'd2': tf.Variable(tf.random_normal([100])),
    'out': tf.Variable(tf.random_normal([25]))
}

def multilayer_cnn(data):
    conv1 = tf.nn.tanh(conv2d(data, weights['c1']) + biases['b1'])
    pool1 = pool(conv1, 2, 1)
    conv2 = tf.nn.tanh(conv2d(pool1, weights['c2']) + biases['b2'])
    pool2 = pool(conv2, 3, 1)
    conv3 = tf.nn.tanh(conv2d(pool2, weights['c3']) + biases['b3'])
    pool3 = pool(conv3, 2, 1)
    pool3_flat = tf.reshape(pool3, [-1, 7*25*70])
    d1_layer = tf.nn.tanh(tf.matmul(pool3_flat, weights['d1']) + biases['d1'])
    d2_layer = tf.nn.tanh(tf.matmul(d1_layer, weights['d2']) + biases['d2'])
    out_layer = tf.matmul(d2_layer, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_cnn(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
CNN_3cnn_2d_large_25 = [error_train, acc_train, error_valid, acc_valid]
np.save('CNN_3cnn_2d_large_25', CNN_3cnn_2d_large_25)
# Out:
# End of epoch 1: running error average = 7.25 running acc average = 0.11
# End of epoch 2: running error average = 2.44 running acc average = 0.12
# End of epoch 3: running error average = 2.28 running acc average = 0.15
# End of epoch 4: running error average = 2.20 running acc average = 0.17
# End of epoch 5: running error average = 2.17 running acc average = 0.18
# End of epoch 6: running error average = 2.15 running acc average = 0.19
# End of epoch 7: running error average = 2.14 running acc average = 0.19
# End of epoch 8: running error average = 2.14 running acc average = 0.20
# End of epoch 9: running error average = 2.13 running acc average = 0.20
# End of epoch 10: running error average = 2.12 running acc average = 0.20
# End of epoch 11: running error average = 2.12 running acc average = 0.20
# End of epoch 12: running error average = 2.11 running acc average = 0.20
# End of epoch 13: running error average = 2.09 running acc average = 0.21
# End of epoch 14: running error average = 2.10 running acc average = 0.21
# End of epoch 15: running error average = 2.10 running acc average = 0.21
# End of epoch 16: running error average = 2.08 running acc average = 0.23
# End of epoch 17: running error average = 2.07 running acc average = 0.23
# End of epoch 18: running error average = 2.05 running acc average = 0.24
# End of epoch 19: running error average = 2.05 running acc average = 0.23
# End of epoch 20: running error average = 2.04 running acc average = 0.24
# End of epoch 21: running error average = 2.03 running acc average = 0.24
# End of epoch 22: running error average = 2.01 running acc average = 0.25
# End of epoch 23: running error average = 2.02 running acc average = 0.25
# End of epoch 24: running error average = 1.98 running acc average = 0.26
# End of epoch 25: running error average = 1.96 running acc average = 0.28
# End of epoch 26: running error average = 1.94 running acc average = 0.28
# End of epoch 27: running error average = 1.93 running acc average = 0.28
# End of epoch 28: running error average = 1.93 running acc average = 0.29
# End of epoch 29: running error average = 1.95 running acc average = 0.29
# End of epoch 30: running error average = 1.92 running acc average = 0.30
# End of epoch 31: running error average = 1.94 running acc average = 0.29
# End of epoch 32: running error average = 1.92 running acc average = 0.29
# End of epoch 33: running error average = 1.91 running acc average = 0.30
# End of epoch 34: running error average = 1.90 running acc average = 0.31
# End of epoch 35: running error average = 1.90 running acc average = 0.31
# End of epoch 36: running error average = 1.89 running acc average = 0.30
# End of epoch 37: running error average = 1.91 running acc average = 0.30
# End of epoch 38: running error average = 1.91 running acc average = 0.30
# End of epoch 39: running error average = 1.91 running acc average = 0.30
# End of epoch 40: running error average = 1.91 running acc average = 0.30
# End of epoch 41: running error average = 1.90 running acc average = 0.31
# End of epoch 42: running error average = 1.89 running acc average = 0.31
# End of epoch 43: running error average = 1.88 running acc average = 0.31
# End of epoch 44: running error average = 1.88 running acc average = 0.31
# End of epoch 45: running error average = 1.88 running acc average = 0.32
# End of epoch 46: running error average = 1.88 running acc average = 0.32
# End of epoch 47: running error average = 1.88 running acc average = 0.32
# End of epoch 48: running error average = 1.86 running acc average = 0.32
# End of epoch 49: running error average = 1.86 running acc average = 0.33

# %%
data = np.load('CNN_3cnn_2d_large_25.npy')

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('CNN_3cnn_2d_large_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('CNN_3cnn_2d_large_25(error).pdf')

# %%
data = np.load('CNN_3cnn_2d_large_25.npy')

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('CNN_3cnn_2d_large_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('CNN_3cnn_2d_large_25(acc).pdf')
