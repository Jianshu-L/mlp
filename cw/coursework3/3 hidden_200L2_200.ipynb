# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s16/s1607197/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 200
n_hidden_2 = 200
n_hidden_3 = 200
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 200
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_200_L2_200 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 28394.56 running acc average = 0.24
# End of epoch 2: running error average = 13904.69 running acc average = 0.31
# End of epoch 3: running error average = 9977.86 running acc average = 0.36
# End of epoch 4: running error average = 7857.40 running acc average = 0.41
# End of epoch 5: running error average = 6558.98 running acc average = 0.47
# End of epoch 6: running error average = 5680.51 running acc average = 0.52
# End of epoch 7: running error average = 4940.22 running acc average = 0.59
# End of epoch 8: running error average = 4489.94 running acc average = 0.64
# End of epoch 9: running error average = 4130.23 running acc average = 0.69
# End of epoch 10: running error average = 3865.48 running acc average = 0.74
# End of epoch 11: running error average = 3653.55 running acc average = 0.78
# End of epoch 12: running error average = 3516.92 running acc average = 0.81
# End of epoch 13: running error average = 3392.64 running acc average = 0.84
# End of epoch 14: running error average = 3295.22 running acc average = 0.87
# End of epoch 15: running error average = 3223.20 running acc average = 0.88
# End of epoch 16: running error average = 3160.08 running acc average = 0.90
# End of epoch 17: running error average = 3106.73 running acc average = 0.91
# End of epoch 18: running error average = 3055.65 running acc average = 0.92
# End of epoch 19: running error average = 3002.43 running acc average = 0.93
# End of epoch 20: running error average = 2954.36 running acc average = 0.93
# End of epoch 21: running error average = 2910.28 running acc average = 0.93
# End of epoch 22: running error average = 2855.21 running acc average = 0.94
# End of epoch 23: running error average = 2807.45 running acc average = 0.94
# End of epoch 24: running error average = 2757.84 running acc average = 0.94
# End of epoch 25: running error average = 2705.87 running acc average = 0.95
# End of epoch 26: running error average = 2655.88 running acc average = 0.95
# End of epoch 27: running error average = 2607.04 running acc average = 0.95
# End of epoch 28: running error average = 2553.52 running acc average = 0.95
# End of epoch 29: running error average = 2503.71 running acc average = 0.95
# End of epoch 30: running error average = 2451.15 running acc average = 0.96
# End of epoch 31: running error average = 2399.27 running acc average = 0.96
# End of epoch 32: running error average = 2350.34 running acc average = 0.95
# End of epoch 33: running error average = 2296.91 running acc average = 0.96
# End of epoch 34: running error average = 2248.86 running acc average = 0.96
# End of epoch 35: running error average = 2198.05 running acc average = 0.96
# End of epoch 36: running error average = 2145.79 running acc average = 0.96
# End of epoch 37: running error average = 2096.40 running acc average = 0.96
# End of epoch 38: running error average = 2047.37 running acc average = 0.96
# End of epoch 39: running error average = 1998.79 running acc average = 0.96
# End of epoch 40: running error average = 1949.26 running acc average = 0.96
# End of epoch 41: running error average = 1902.32 running acc average = 0.96
# End of epoch 42: running error average = 1855.41 running acc average = 0.96
# End of epoch 43: running error average = 1805.46 running acc average = 0.97
# End of epoch 44: running error average = 1760.50 running acc average = 0.96
# End of epoch 45: running error average = 1714.13 running acc average = 0.96
# End of epoch 46: running error average = 1668.13 running acc average = 0.96
# End of epoch 47: running error average = 1622.10 running acc average = 0.97
# End of epoch 48: running error average = 1578.60 running acc average = 0.96
# End of epoch 49: running error average = 1535.42 running acc average = 0.96
# End of epoch 50: running error average = 1493.23 running acc average = 0.96
# End of epoch 51: running error average = 1448.68 running acc average = 0.97
# End of epoch 52: running error average = 1406.66 running acc average = 0.97
# End of epoch 53: running error average = 1365.78 running acc average = 0.97
# End of epoch 54: running error average = 1326.29 running acc average = 0.96
# End of epoch 55: running error average = 1288.09 running acc average = 0.96
# End of epoch 56: running error average = 1248.82 running acc average = 0.97
# End of epoch 57: running error average = 1211.38 running acc average = 0.96
# End of epoch 58: running error average = 1173.65 running acc average = 0.96
# End of epoch 59: running error average = 1138.46 running acc average = 0.96
# End of epoch 60: running error average = 1101.42 running acc average = 0.96
# End of epoch 61: running error average = 1068.52 running acc average = 0.96
# End of epoch 62: running error average = 1033.23 running acc average = 0.96
# End of epoch 63: running error average = 999.83 running acc average = 0.96
# End of epoch 64: running error average = 966.65 running acc average = 0.96
# End of epoch 65: running error average = 935.57 running acc average = 0.96
# End of epoch 66: running error average = 903.69 running acc average = 0.96
# End of epoch 67: running error average = 872.63 running acc average = 0.96
# End of epoch 68: running error average = 842.90 running acc average = 0.96
# End of epoch 69: running error average = 812.21 running acc average = 0.96
# End of epoch 70: running error average = 784.79 running acc average = 0.96
# End of epoch 71: running error average = 756.72 running acc average = 0.96
# End of epoch 72: running error average = 729.25 running acc average = 0.96
# End of epoch 73: running error average = 702.52 running acc average = 0.96
# End of epoch 74: running error average = 677.03 running acc average = 0.96
# End of epoch 75: running error average = 650.92 running acc average = 0.96
# End of epoch 76: running error average = 626.21 running acc average = 0.96
# End of epoch 77: running error average = 601.81 running acc average = 0.96
# End of epoch 78: running error average = 577.87 running acc average = 0.96
# End of epoch 79: running error average = 555.80 running acc average = 0.95
# End of epoch 80: running error average = 531.87 running acc average = 0.96
# End of epoch 81: running error average = 509.65 running acc average = 0.96
# End of epoch 82: running error average = 488.76 running acc average = 0.95
# End of epoch 83: running error average = 468.37 running acc average = 0.95
# End of epoch 84: running error average = 448.10 running acc average = 0.95
# End of epoch 85: running error average = 428.38 running acc average = 0.95
# End of epoch 86: running error average = 409.31 running acc average = 0.95
# End of epoch 87: running error average = 390.21 running acc average = 0.95
# End of epoch 88: running error average = 372.43 running acc average = 0.95
# End of epoch 89: running error average = 355.80 running acc average = 0.94
# End of epoch 90: running error average = 338.43 running acc average = 0.94
# End of epoch 91: running error average = 321.46 running acc average = 0.95
# End of epoch 92: running error average = 305.69 running acc average = 0.94
# End of epoch 93: running error average = 290.09 running acc average = 0.94
# End of epoch 94: running error average = 275.23 running acc average = 0.94
# End of epoch 95: running error average = 260.28 running acc average = 0.94
# End of epoch 96: running error average = 246.28 running acc average = 0.93
# End of epoch 97: running error average = 232.07 running acc average = 0.93
# End of epoch 98: running error average = 218.28 running acc average = 0.93
# End of epoch 99: running error average = 205.62 running acc average = 0.93
# End of epoch 100: running error average = 192.84 running acc average = 0.93
# End of epoch 101: running error average = 180.85 running acc average = 0.92
# End of epoch 102: running error average = 168.66 running acc average = 0.92
# End of epoch 103: running error average = 157.02 running acc average = 0.92
# End of epoch 104: running error average = 145.73 running acc average = 0.92
# End of epoch 105: running error average = 135.04 running acc average = 0.91
# End of epoch 106: running error average = 124.93 running acc average = 0.90
# End of epoch 107: running error average = 114.41 running acc average = 0.91
# End of epoch 108: running error average = 105.03 running acc average = 0.90
# End of epoch 109: running error average = 95.74 running acc average = 0.89
# End of epoch 110: running error average = 86.57 running acc average = 0.89
# End of epoch 111: running error average = 77.94 running acc average = 0.88
# End of epoch 112: running error average = 69.64 running acc average = 0.88
# End of epoch 113: running error average = 61.75 running acc average = 0.87
# End of epoch 114: running error average = 54.20 running acc average = 0.86
# End of epoch 115: running error average = 47.04 running acc average = 0.85
# End of epoch 116: running error average = 40.00 running acc average = 0.85
# End of epoch 117: running error average = 33.51 running acc average = 0.84
# End of epoch 118: running error average = 27.34 running acc average = 0.83
# End of epoch 119: running error average = 21.70 running acc average = 0.82
# End of epoch 120: running error average = 16.55 running acc average = 0.81
# End of epoch 121: running error average = 12.18 running acc average = 0.81
# End of epoch 122: running error average = 8.72 running acc average = 0.80
# End of epoch 123: running error average = 6.31 running acc average = 0.76
# End of epoch 124: running error average = 4.70 running acc average = 0.72
# End of epoch 125: running error average = 3.65 running acc average = 0.70
# End of epoch 126: running error average = 2.96 running acc average = 0.69
# End of epoch 127: running error average = 2.54 running acc average = 0.68
# End of epoch 128: running error average = 2.27 running acc average = 0.67
# End of epoch 129: running error average = 2.10 running acc average = 0.66
# End of epoch 130: running error average = 1.97 running acc average = 0.65
# End of epoch 131: running error average = 1.89 running acc average = 0.65
# End of epoch 132: running error average = 1.82 running acc average = 0.65
# End of epoch 133: running error average = 1.76 running acc average = 0.65
# End of epoch 134: running error average = 1.72 running acc average = 0.66
# End of epoch 135: running error average = 1.70 running acc average = 0.65
# End of epoch 136: running error average = 1.67 running acc average = 0.66
# End of epoch 137: running error average = 1.64 running acc average = 0.66
# End of epoch 138: running error average = 1.63 running acc average = 0.67
# End of epoch 139: running error average = 1.62 running acc average = 0.67
# End of epoch 140: running error average = 1.60 running acc average = 0.67
# End of epoch 141: running error average = 1.59 running acc average = 0.67
# End of epoch 142: running error average = 1.58 running acc average = 0.67
# End of epoch 143: running error average = 1.57 running acc average = 0.68
# End of epoch 144: running error average = 1.57 running acc average = 0.68
# End of epoch 145: running error average = 1.56 running acc average = 0.68
# End of epoch 146: running error average = 1.56 running acc average = 0.68
# End of epoch 147: running error average = 1.54 running acc average = 0.69
# End of epoch 148: running error average = 1.55 running acc average = 0.68
# End of epoch 149: running error average = 1.54 running acc average = 0.68
# End of epoch 150: running error average = 1.54 running acc average = 0.69
# End of epoch 151: running error average = 1.52 running acc average = 0.69
# End of epoch 152: running error average = 1.54 running acc average = 0.69
# End of epoch 153: running error average = 1.53 running acc average = 0.69
# End of epoch 154: running error average = 1.53 running acc average = 0.69
# End of epoch 155: running error average = 1.53 running acc average = 0.69
# End of epoch 156: running error average = 1.53 running acc average = 0.69
# End of epoch 157: running error average = 1.53 running acc average = 0.69
# End of epoch 158: running error average = 1.52 running acc average = 0.69
# End of epoch 159: running error average = 1.52 running acc average = 0.69
# End of epoch 160: running error average = 1.53 running acc average = 0.69
# End of epoch 161: running error average = 1.53 running acc average = 0.69
# End of epoch 162: running error average = 1.52 running acc average = 0.70
# End of epoch 163: running error average = 1.53 running acc average = 0.69
# End of epoch 164: running error average = 1.52 running acc average = 0.70
# End of epoch 165: running error average = 1.53 running acc average = 0.69
# End of epoch 166: running error average = 1.52 running acc average = 0.69
# End of epoch 167: running error average = 1.52 running acc average = 0.69
# End of epoch 168: running error average = 1.52 running acc average = 0.70
# End of epoch 169: running error average = 1.51 running acc average = 0.70
# End of epoch 170: running error average = 1.51 running acc average = 0.70
# End of epoch 171: running error average = 1.53 running acc average = 0.69
# End of epoch 172: running error average = 1.51 running acc average = 0.70
# End of epoch 173: running error average = 1.51 running acc average = 0.70
# End of epoch 174: running error average = 1.52 running acc average = 0.70
# End of epoch 175: running error average = 1.51 running acc average = 0.70
# End of epoch 176: running error average = 1.52 running acc average = 0.70
# End of epoch 177: running error average = 1.51 running acc average = 0.70
# End of epoch 178: running error average = 1.51 running acc average = 0.70
# End of epoch 179: running error average = 1.51 running acc average = 0.70
# End of epoch 180: running error average = 1.52 running acc average = 0.69
# End of epoch 181: running error average = 1.50 running acc average = 0.70
# End of epoch 182: running error average = 1.51 running acc average = 0.70
# End of epoch 183: running error average = 1.50 running acc average = 0.70
# End of epoch 184: running error average = 1.51 running acc average = 0.70
# End of epoch 185: running error average = 1.50 running acc average = 0.70
# End of epoch 186: running error average = 1.50 running acc average = 0.70
# End of epoch 187: running error average = 1.50 running acc average = 0.70
# End of epoch 188: running error average = 1.51 running acc average = 0.70
# End of epoch 189: running error average = 1.50 running acc average = 0.70
# End of epoch 190: running error average = 1.50 running acc average = 0.70
# End of epoch 191: running error average = 1.50 running acc average = 0.70
# End of epoch 192: running error average = 1.51 running acc average = 0.69
# End of epoch 193: running error average = 1.50 running acc average = 0.70
# End of epoch 194: running error average = 1.50 running acc average = 0.70
# End of epoch 195: running error average = 1.49 running acc average = 0.71
# End of epoch 196: running error average = 1.49 running acc average = 0.71
# End of epoch 197: running error average = 1.51 running acc average = 0.70
# End of epoch 198: running error average = 1.49 running acc average = 0.70
# End of epoch 199: running error average = 1.49 running acc average = 0.70
# End of epoch 200: running error average = 1.50 running acc average = 0.70

# %%
data = Adam_4layers_200_L2_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2(error).pdf')

# %%
data = Adam_4layers_200_L2_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2(acc).pdf')

# %%
np.save('Adam_4layers_200_L2_200', Adam_4layers_200_L2_200)
