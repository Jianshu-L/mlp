# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 25], 'targets')

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)

import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_100_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 316.88 running acc average = 0.23
# End of epoch 2: running error average = 203.89 running acc average = 0.32
# End of epoch 3: running error average = 154.77 running acc average = 0.35
# End of epoch 4: running error average = 119.86 running acc average = 0.38
# End of epoch 5: running error average = 94.50 running acc average = 0.40
# End of epoch 6: running error average = 73.66 running acc average = 0.43
# End of epoch 7: running error average = 57.71 running acc average = 0.45
# End of epoch 8: running error average = 46.40 running acc average = 0.46
# End of epoch 9: running error average = 36.34 running acc average = 0.48
# End of epoch 10: running error average = 27.92 running acc average = 0.51
# End of epoch 11: running error average = 22.05 running acc average = 0.53
# End of epoch 12: running error average = 17.54 running acc average = 0.54
# End of epoch 13: running error average = 13.78 running acc average = 0.55
# End of epoch 14: running error average = 10.81 running acc average = 0.57
# End of epoch 15: running error average = 8.29 running acc average = 0.58
# End of epoch 16: running error average = 6.47 running acc average = 0.59
# End of epoch 17: running error average = 5.12 running acc average = 0.60
# End of epoch 18: running error average = 3.93 running acc average = 0.61
# End of epoch 19: running error average = 3.09 running acc average = 0.61
# End of epoch 20: running error average = 2.65 running acc average = 0.62
# End of epoch 21: running error average = 2.17 running acc average = 0.64
# End of epoch 22: running error average = 1.87 running acc average = 0.65
# End of epoch 23: running error average = 1.59 running acc average = 0.66
# End of epoch 24: running error average = 1.43 running acc average = 0.67
# End of epoch 25: running error average = 1.28 running acc average = 0.68
# End of epoch 26: running error average = 1.10 running acc average = 0.69
# End of epoch 27: running error average = 1.05 running acc average = 0.70
# End of epoch 28: running error average = 0.98 running acc average = 0.71
# End of epoch 29: running error average = 0.91 running acc average = 0.73
# End of epoch 30: running error average = 0.87 running acc average = 0.73
# End of epoch 31: running error average = 0.79 running acc average = 0.75
# End of epoch 32: running error average = 0.78 running acc average = 0.75
# End of epoch 33: running error average = 0.74 running acc average = 0.77
# End of epoch 34: running error average = 0.70 running acc average = 0.77
# End of epoch 35: running error average = 0.67 running acc average = 0.78
# End of epoch 36: running error average = 0.62 running acc average = 0.80
# End of epoch 37: running error average = 0.61 running acc average = 0.80
# End of epoch 38: running error average = 0.57 running acc average = 0.81
# End of epoch 39: running error average = 0.54 running acc average = 0.82
# End of epoch 40: running error average = 0.52 running acc average = 0.83
# End of epoch 41: running error average = 0.49 running acc average = 0.84
# End of epoch 42: running error average = 0.47 running acc average = 0.85
# End of epoch 43: running error average = 0.44 running acc average = 0.86
# End of epoch 44: running error average = 0.40 running acc average = 0.87
# End of epoch 45: running error average = 0.39 running acc average = 0.87
# End of epoch 46: running error average = 0.35 running acc average = 0.89
# End of epoch 47: running error average = 0.35 running acc average = 0.89
# End of epoch 48: running error average = 0.31 running acc average = 0.90
# End of epoch 49: running error average = 0.28 running acc average = 0.91
# End of epoch 50: running error average = 0.27 running acc average = 0.91

# %%
data = Adam_2layers_100_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_100_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_100_25(error).pdf')

# %%
data = Adam_2layers_100_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_100_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_100_25(acc).pdf')

# %%
n_hidden_1 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_100_L2_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 1740.62 running acc average = 0.22
# End of epoch 2: running error average = 1436.35 running acc average = 0.31
# End of epoch 3: running error average = 1208.03 running acc average = 0.36
# End of epoch 4: running error average = 1010.12 running acc average = 0.39
# End of epoch 5: running error average = 833.73 running acc average = 0.41
# End of epoch 6: running error average = 677.13 running acc average = 0.45
# End of epoch 7: running error average = 539.42 running acc average = 0.48
# End of epoch 8: running error average = 420.46 running acc average = 0.51
# End of epoch 9: running error average = 319.10 running acc average = 0.55
# End of epoch 10: running error average = 234.76 running acc average = 0.59
# End of epoch 11: running error average = 166.87 running acc average = 0.63
# End of epoch 12: running error average = 113.88 running acc average = 0.67
# End of epoch 13: running error average = 74.20 running acc average = 0.71
# End of epoch 14: running error average = 46.08 running acc average = 0.73
# End of epoch 15: running error average = 27.31 running acc average = 0.75
# End of epoch 16: running error average = 15.61 running acc average = 0.76
# End of epoch 17: running error average = 8.92 running acc average = 0.75
# End of epoch 18: running error average = 5.30 running acc average = 0.74
# End of epoch 19: running error average = 3.45 running acc average = 0.74
# End of epoch 20: running error average = 2.60 running acc average = 0.72
# End of epoch 21: running error average = 2.15 running acc average = 0.72
# End of epoch 22: running error average = 1.92 running acc average = 0.71
# End of epoch 23: running error average = 1.78 running acc average = 0.71
# End of epoch 24: running error average = 1.71 running acc average = 0.70
# End of epoch 25: running error average = 1.64 running acc average = 0.70
# End of epoch 26: running error average = 1.61 running acc average = 0.69
# End of epoch 27: running error average = 1.59 running acc average = 0.69
# End of epoch 28: running error average = 1.58 running acc average = 0.69
# End of epoch 29: running error average = 1.58 running acc average = 0.68
# End of epoch 30: running error average = 1.56 running acc average = 0.68
# End of epoch 31: running error average = 1.55 running acc average = 0.68
# End of epoch 32: running error average = 1.55 running acc average = 0.68
# End of epoch 33: running error average = 1.54 running acc average = 0.68
# End of epoch 34: running error average = 1.54 running acc average = 0.68
# End of epoch 35: running error average = 1.53 running acc average = 0.68
# End of epoch 36: running error average = 1.51 running acc average = 0.68
# End of epoch 37: running error average = 1.51 running acc average = 0.68
# End of epoch 38: running error average = 1.50 running acc average = 0.69
# End of epoch 39: running error average = 1.50 running acc average = 0.68
# End of epoch 40: running error average = 1.50 running acc average = 0.69
# End of epoch 41: running error average = 1.49 running acc average = 0.69
# End of epoch 42: running error average = 1.49 running acc average = 0.69
# End of epoch 43: running error average = 1.50 running acc average = 0.69
# End of epoch 44: running error average = 1.49 running acc average = 0.69
# End of epoch 45: running error average = 1.48 running acc average = 0.69
# End of epoch 46: running error average = 1.48 running acc average = 0.68
# End of epoch 47: running error average = 1.46 running acc average = 0.69
# End of epoch 48: running error average = 1.46 running acc average = 0.69
# End of epoch 49: running error average = 1.47 running acc average = 0.69
# End of epoch 50: running error average = 1.46 running acc average = 0.69

# %%
data = Adam_2layers_100_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_100_L2_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_100_L2_25(error).pdf')

# %%
data = Adam_2layers_100_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_100_L2_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_100_L2_25(acc).pdf')
print(data[3])
# Out:
# [ 0.26516667  0.29816667  0.299       0.307       0.30916667  0.305       0.3145
#   0.29583333  0.30683333  0.30966667  0.30633333  0.31183333  0.3075
#   0.31016667  0.3145      0.324       0.34533333  0.36483334  0.37933333
#   0.39566667  0.41583333  0.422       0.43516667  0.44883333  0.42883333
#   0.44266667  0.43566667  0.4445      0.44166666  0.44733333  0.44183333
#   0.4465      0.4455      0.462       0.455       0.462       0.4415      0.461
#   0.45216666  0.467       0.46433333  0.451       0.45133333  0.458
#   0.45666667  0.4395      0.45533333  0.45583333  0.45716667  0.45683333]

# %%
n_hidden_1 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden200(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden200(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_200_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 481.31 running acc average = 0.24
# End of epoch 2: running error average = 303.60 running acc average = 0.34
# End of epoch 3: running error average = 228.75 running acc average = 0.38
# End of epoch 4: running error average = 176.25 running acc average = 0.43
# End of epoch 5: running error average = 144.24 running acc average = 0.46
# End of epoch 6: running error average = 112.41 running acc average = 0.50
# End of epoch 7: running error average = 90.97 running acc average = 0.54
# End of epoch 8: running error average = 74.27 running acc average = 0.56
# End of epoch 9: running error average = 59.00 running acc average = 0.60
# End of epoch 10: running error average = 47.72 running acc average = 0.64
# End of epoch 11: running error average = 38.43 running acc average = 0.66
# End of epoch 12: running error average = 31.14 running acc average = 0.70
# End of epoch 13: running error average = 25.28 running acc average = 0.72
# End of epoch 14: running error average = 20.35 running acc average = 0.75
# End of epoch 15: running error average = 16.29 running acc average = 0.78
# End of epoch 16: running error average = 12.95 running acc average = 0.80
# End of epoch 17: running error average = 10.25 running acc average = 0.82
# End of epoch 18: running error average = 7.84 running acc average = 0.85
# End of epoch 19: running error average = 6.05 running acc average = 0.87
# End of epoch 20: running error average = 4.66 running acc average = 0.88
# End of epoch 21: running error average = 3.78 running acc average = 0.90
# End of epoch 22: running error average = 2.99 running acc average = 0.91
# End of epoch 23: running error average = 2.29 running acc average = 0.92
# End of epoch 24: running error average = 1.82 running acc average = 0.93
# End of epoch 25: running error average = 1.53 running acc average = 0.94
# End of epoch 26: running error average = 1.19 running acc average = 0.94
# End of epoch 27: running error average = 1.17 running acc average = 0.94
# End of epoch 28: running error average = 0.96 running acc average = 0.95
# End of epoch 29: running error average = 0.81 running acc average = 0.95
# End of epoch 30: running error average = 0.78 running acc average = 0.96
# End of epoch 31: running error average = 0.76 running acc average = 0.96
# End of epoch 32: running error average = 0.72 running acc average = 0.96
# End of epoch 33: running error average = 0.63 running acc average = 0.96
# End of epoch 34: running error average = 0.58 running acc average = 0.97
# End of epoch 35: running error average = 0.61 running acc average = 0.97
# End of epoch 36: running error average = 0.57 running acc average = 0.97
# End of epoch 37: running error average = 0.52 running acc average = 0.97
# End of epoch 38: running error average = 0.51 running acc average = 0.97
# End of epoch 39: running error average = 0.49 running acc average = 0.97
# End of epoch 40: running error average = 0.43 running acc average = 0.97
# End of epoch 41: running error average = 0.48 running acc average = 0.97
# End of epoch 42: running error average = 0.48 running acc average = 0.97
# End of epoch 43: running error average = 0.45 running acc average = 0.97
# End of epoch 44: running error average = 0.41 running acc average = 0.98
# End of epoch 45: running error average = 0.38 running acc average = 0.98
# End of epoch 46: running error average = 0.43 running acc average = 0.98
# End of epoch 47: running error average = 0.38 running acc average = 0.98
# End of epoch 48: running error average = 0.34 running acc average = 0.98
# End of epoch 49: running error average = 0.37 running acc average = 0.98
# End of epoch 50: running error average = 0.35 running acc average = 0.98

# %%
data = Adam_2layers_200_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_200_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_200_25(error).pdf')

# %%
data = Adam_2layers_200_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_200_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_200_25(acc).pdf')

# %%
n_hidden_1 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_200_L2_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 3307.42 running acc average = 0.25
# End of epoch 2: running error average = 2770.79 running acc average = 0.35
# End of epoch 3: running error average = 2358.83 running acc average = 0.40
# End of epoch 4: running error average = 1997.95 running acc average = 0.44
# End of epoch 5: running error average = 1679.18 running acc average = 0.48
# End of epoch 6: running error average = 1395.47 running acc average = 0.53
# End of epoch 7: running error average = 1147.58 running acc average = 0.57
# End of epoch 8: running error average = 930.45 running acc average = 0.62
# End of epoch 9: running error average = 743.09 running acc average = 0.66
# End of epoch 10: running error average = 583.47 running acc average = 0.70
# End of epoch 11: running error average = 449.03 running acc average = 0.74
# End of epoch 12: running error average = 338.28 running acc average = 0.77
# End of epoch 13: running error average = 248.84 running acc average = 0.80
# End of epoch 14: running error average = 179.00 running acc average = 0.81
# End of epoch 15: running error average = 126.07 running acc average = 0.81
# End of epoch 16: running error average = 87.52 running acc average = 0.82
# End of epoch 17: running error average = 60.20 running acc average = 0.81
# End of epoch 18: running error average = 41.10 running acc average = 0.81
# End of epoch 19: running error average = 28.09 running acc average = 0.80
# End of epoch 20: running error average = 19.15 running acc average = 0.80
# End of epoch 21: running error average = 13.12 running acc average = 0.79
# End of epoch 22: running error average = 8.92 running acc average = 0.79
# End of epoch 23: running error average = 6.03 running acc average = 0.79
# End of epoch 24: running error average = 4.14 running acc average = 0.78
# End of epoch 25: running error average = 2.91 running acc average = 0.78
# End of epoch 26: running error average = 2.25 running acc average = 0.76
# End of epoch 27: running error average = 1.90 running acc average = 0.75
# End of epoch 28: running error average = 1.75 running acc average = 0.73
# End of epoch 29: running error average = 1.71 running acc average = 0.71
# End of epoch 30: running error average = 1.65 running acc average = 0.70
# End of epoch 31: running error average = 1.65 running acc average = 0.69
# End of epoch 32: running error average = 1.64 running acc average = 0.68
# End of epoch 33: running error average = 1.61 running acc average = 0.68
# End of epoch 34: running error average = 1.60 running acc average = 0.67
# End of epoch 35: running error average = 1.60 running acc average = 0.67
# End of epoch 36: running error average = 1.57 running acc average = 0.67
# End of epoch 37: running error average = 1.56 running acc average = 0.67
# End of epoch 38: running error average = 1.55 running acc average = 0.68
# End of epoch 39: running error average = 1.53 running acc average = 0.68
# End of epoch 40: running error average = 1.53 running acc average = 0.68
# End of epoch 41: running error average = 1.52 running acc average = 0.68
# End of epoch 42: running error average = 1.51 running acc average = 0.68
# End of epoch 43: running error average = 1.51 running acc average = 0.68
# End of epoch 44: running error average = 1.51 running acc average = 0.68
# End of epoch 45: running error average = 1.50 running acc average = 0.68
# End of epoch 46: running error average = 1.50 running acc average = 0.68
# End of epoch 47: running error average = 1.48 running acc average = 0.69
# End of epoch 48: running error average = 1.47 running acc average = 0.69
# End of epoch 49: running error average = 1.48 running acc average = 0.69
# End of epoch 50: running error average = 1.47 running acc average = 0.69

# %%
data = Adam_2layers_200_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_200_L2_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_200_L2_25(error).pdf')

# %%
data = Adam_2layers_200_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_200_L2_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_200_L2_25(acc).pdf')
print(data[3])
# Out:
# [ 0.28183333  0.30133333  0.29366667  0.31416667  0.311       0.31566667
#   0.31166667  0.30183333  0.302       0.31416667  0.329       0.32733334
#   0.30383333  0.30766667  0.3255      0.32616667  0.335       0.34916667
#   0.35733333  0.36333333  0.36233333  0.37583333  0.35533334  0.38416667
#   0.39666667  0.40866667  0.41033333  0.43083333  0.44        0.4385
#   0.44633333  0.43733333  0.45916667  0.45133333  0.448       0.45916667
#   0.44983333  0.4575      0.45883333  0.4585      0.46283333  0.45183333
#   0.44733333  0.45266667  0.45316667  0.44133333  0.46533333  0.44533333
#   0.4525      0.45466667]

# %%
n_hidden_1 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_300_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 570.60 running acc average = 0.26
# End of epoch 2: running error average = 348.80 running acc average = 0.36
# End of epoch 3: running error average = 255.60 running acc average = 0.42
# End of epoch 4: running error average = 192.84 running acc average = 0.47
# End of epoch 5: running error average = 155.28 running acc average = 0.51
# End of epoch 6: running error average = 118.81 running acc average = 0.56
# End of epoch 7: running error average = 92.79 running acc average = 0.60
# End of epoch 8: running error average = 73.51 running acc average = 0.64
# End of epoch 9: running error average = 57.81 running acc average = 0.67
# End of epoch 10: running error average = 44.44 running acc average = 0.71
# End of epoch 11: running error average = 35.04 running acc average = 0.74
# End of epoch 12: running error average = 25.72 running acc average = 0.78
# End of epoch 13: running error average = 19.74 running acc average = 0.81
# End of epoch 14: running error average = 14.88 running acc average = 0.84
# End of epoch 15: running error average = 10.78 running acc average = 0.86
# End of epoch 16: running error average = 8.21 running acc average = 0.88
# End of epoch 17: running error average = 6.16 running acc average = 0.90
# End of epoch 18: running error average = 4.81 running acc average = 0.91
# End of epoch 19: running error average = 3.52 running acc average = 0.92
# End of epoch 20: running error average = 2.84 running acc average = 0.93
# End of epoch 21: running error average = 2.39 running acc average = 0.94
# End of epoch 22: running error average = 2.08 running acc average = 0.94
# End of epoch 23: running error average = 1.61 running acc average = 0.95
# End of epoch 24: running error average = 1.43 running acc average = 0.96
# End of epoch 25: running error average = 1.30 running acc average = 0.96
# End of epoch 26: running error average = 1.33 running acc average = 0.96
# End of epoch 27: running error average = 1.16 running acc average = 0.96
# End of epoch 28: running error average = 1.09 running acc average = 0.96
# End of epoch 29: running error average = 1.04 running acc average = 0.96
# End of epoch 30: running error average = 0.94 running acc average = 0.97
# End of epoch 31: running error average = 0.94 running acc average = 0.97
# End of epoch 32: running error average = 0.93 running acc average = 0.97
# End of epoch 33: running error average = 0.91 running acc average = 0.97
# End of epoch 34: running error average = 0.81 running acc average = 0.97
# End of epoch 35: running error average = 0.88 running acc average = 0.97
# End of epoch 36: running error average = 0.84 running acc average = 0.97
# End of epoch 37: running error average = 0.71 running acc average = 0.98
# End of epoch 38: running error average = 0.77 running acc average = 0.98
# End of epoch 39: running error average = 0.78 running acc average = 0.98
# End of epoch 40: running error average = 0.66 running acc average = 0.98
# End of epoch 41: running error average = 0.69 running acc average = 0.98
# End of epoch 42: running error average = 0.73 running acc average = 0.98
# End of epoch 43: running error average = 0.67 running acc average = 0.98
# End of epoch 44: running error average = 0.67 running acc average = 0.98
# End of epoch 45: running error average = 0.62 running acc average = 0.98
# End of epoch 46: running error average = 0.61 running acc average = 0.98
# End of epoch 47: running error average = 0.62 running acc average = 0.98
# End of epoch 48: running error average = 0.55 running acc average = 0.98
# End of epoch 49: running error average = 0.63 running acc average = 0.98
# End of epoch 50: running error average = 0.50 running acc average = 0.98

# %%
data = Adam_2layers_300_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_300_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_300_25(error).pdf')

# %%
data = Adam_2layers_300_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_300_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_300_25(acc).pdf')

# %%
n_hidden_1 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.matmul(layer_1, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_2layers_300_L2_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 4811.42 running acc average = 0.26
# End of epoch 2: running error average = 4100.90 running acc average = 0.36
# End of epoch 3: running error average = 3523.17 running acc average = 0.42
# End of epoch 4: running error average = 3009.89 running acc average = 0.48
# End of epoch 5: running error average = 2556.01 running acc average = 0.52
# End of epoch 6: running error average = 2147.55 running acc average = 0.58
# End of epoch 7: running error average = 1786.06 running acc average = 0.63
# End of epoch 8: running error average = 1466.99 running acc average = 0.68
# End of epoch 9: running error average = 1187.72 running acc average = 0.72
# End of epoch 10: running error average = 945.29 running acc average = 0.76
# End of epoch 11: running error average = 738.68 running acc average = 0.79
# End of epoch 12: running error average = 565.95 running acc average = 0.82
# End of epoch 13: running error average = 425.39 running acc average = 0.83
# End of epoch 14: running error average = 313.97 running acc average = 0.84
# End of epoch 15: running error average = 228.58 running acc average = 0.84
# End of epoch 16: running error average = 165.14 running acc average = 0.84
# End of epoch 17: running error average = 118.91 running acc average = 0.83
# End of epoch 18: running error average = 85.33 running acc average = 0.83
# End of epoch 19: running error average = 61.51 running acc average = 0.82
# End of epoch 20: running error average = 44.18 running acc average = 0.82
# End of epoch 21: running error average = 31.89 running acc average = 0.81
# End of epoch 22: running error average = 23.02 running acc average = 0.81
# End of epoch 23: running error average = 16.56 running acc average = 0.80
# End of epoch 24: running error average = 11.85 running acc average = 0.79
# End of epoch 25: running error average = 8.38 running acc average = 0.79
# End of epoch 26: running error average = 5.82 running acc average = 0.79
# End of epoch 27: running error average = 4.02 running acc average = 0.78
# End of epoch 28: running error average = 2.80 running acc average = 0.79
# End of epoch 29: running error average = 2.19 running acc average = 0.76
# End of epoch 30: running error average = 1.86 running acc average = 0.75
# End of epoch 31: running error average = 1.76 running acc average = 0.73
# End of epoch 32: running error average = 1.71 running acc average = 0.71
# End of epoch 33: running error average = 1.67 running acc average = 0.69
# End of epoch 34: running error average = 1.67 running acc average = 0.67
# End of epoch 35: running error average = 1.66 running acc average = 0.67
# End of epoch 36: running error average = 1.63 running acc average = 0.67
# End of epoch 37: running error average = 1.62 running acc average = 0.67
# End of epoch 38: running error average = 1.60 running acc average = 0.67
# End of epoch 39: running error average = 1.58 running acc average = 0.67
# End of epoch 40: running error average = 1.58 running acc average = 0.67
# End of epoch 41: running error average = 1.56 running acc average = 0.67
# End of epoch 42: running error average = 1.54 running acc average = 0.67
# End of epoch 43: running error average = 1.55 running acc average = 0.67
# End of epoch 44: running error average = 1.53 running acc average = 0.68
# End of epoch 45: running error average = 1.53 running acc average = 0.68
# End of epoch 46: running error average = 1.51 running acc average = 0.68
# End of epoch 47: running error average = 1.50 running acc average = 0.68
# End of epoch 48: running error average = 1.49 running acc average = 0.68
# End of epoch 49: running error average = 1.50 running acc average = 0.68
# End of epoch 50: running error average = 1.49 running acc average = 0.68

# %%
data = Adam_2layers_300_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_300_L2_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_300_L2_25(error).pdf')

# %%
data = Adam_2layers_300_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_2layers_300_L2_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_2layers_300_L2_25(acc).pdf')
print(data[3])
# Out:
# [ 0.29583333  0.3135      0.31166667  0.31266667  0.32066667  0.32183333
#   0.31816667  0.32966667  0.32516667  0.3185      0.32366667  0.33633333
#   0.3305      0.34666667  0.32966667  0.34016667  0.3425      0.35483333
#   0.35833333  0.35566667  0.36483333  0.35366667  0.37533333  0.39133333
#   0.36633333  0.37916667  0.376       0.39616666  0.41166667  0.44316667
#   0.44166667  0.43616667  0.45433333  0.45333333  0.44633333  0.45483333
#   0.45883333  0.45233333  0.456       0.4655      0.47466667  0.45116667
#   0.456       0.456       0.46566667  0.4465      0.46083333  0.45683333
#   0.4525      0.46266667]

# %%
np.save('Adam_2layers_100_25', Adam_2layers_100_25)
np.save('Adam_2layers_100_L2_25', Adam_2layers_100_L2_25)
np.save('Adam_2layers_200_25', Adam_2layers_200_25)
np.save('Adam_2layers_200_L2_25', Adam_2layers_200_L2_25)
np.save('Adam_2layers_300_25', Adam_2layers_300_25)
np.save('Adam_2layers_300_L2_25', Adam_2layers_300_L2_25)
