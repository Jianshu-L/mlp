# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 25], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s16/s1607197/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
n_hidden_2 = 100
n_hidden_3 = 100
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_100_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 10373.42 running acc average = 0.18
# End of epoch 2: running error average = 3566.84 running acc average = 0.24
# End of epoch 3: running error average = 2137.82 running acc average = 0.27
# End of epoch 4: running error average = 1405.14 running acc average = 0.30
# End of epoch 5: running error average = 987.54 running acc average = 0.31
# End of epoch 6: running error average = 705.60 running acc average = 0.33
# End of epoch 7: running error average = 518.35 running acc average = 0.35
# End of epoch 8: running error average = 376.31 running acc average = 0.37
# End of epoch 9: running error average = 284.24 running acc average = 0.39
# End of epoch 10: running error average = 215.83 running acc average = 0.41
# End of epoch 11: running error average = 167.49 running acc average = 0.44
# End of epoch 12: running error average = 127.65 running acc average = 0.46
# End of epoch 13: running error average = 100.36 running acc average = 0.49
# End of epoch 14: running error average = 77.73 running acc average = 0.52
# End of epoch 15: running error average = 61.15 running acc average = 0.54
# End of epoch 16: running error average = 50.62 running acc average = 0.56
# End of epoch 17: running error average = 41.36 running acc average = 0.58
# End of epoch 18: running error average = 34.15 running acc average = 0.60
# End of epoch 19: running error average = 28.19 running acc average = 0.62
# End of epoch 20: running error average = 24.74 running acc average = 0.63
# End of epoch 21: running error average = 20.22 running acc average = 0.66
# End of epoch 22: running error average = 18.31 running acc average = 0.66
# End of epoch 23: running error average = 16.05 running acc average = 0.68
# End of epoch 24: running error average = 14.17 running acc average = 0.69
# End of epoch 25: running error average = 12.54 running acc average = 0.70
# End of epoch 26: running error average = 11.28 running acc average = 0.71
# End of epoch 27: running error average = 10.36 running acc average = 0.72
# End of epoch 28: running error average = 9.08 running acc average = 0.73
# End of epoch 29: running error average = 8.67 running acc average = 0.74
# End of epoch 30: running error average = 7.76 running acc average = 0.75
# End of epoch 31: running error average = 7.25 running acc average = 0.75
# End of epoch 32: running error average = 7.00 running acc average = 0.76
# End of epoch 33: running error average = 6.28 running acc average = 0.77
# End of epoch 34: running error average = 6.09 running acc average = 0.77
# End of epoch 35: running error average = 5.84 running acc average = 0.78
# End of epoch 36: running error average = 5.46 running acc average = 0.78
# End of epoch 37: running error average = 4.82 running acc average = 0.80
# End of epoch 38: running error average = 4.83 running acc average = 0.80
# End of epoch 39: running error average = 4.81 running acc average = 0.80
# End of epoch 40: running error average = 4.58 running acc average = 0.80
# End of epoch 41: running error average = 4.35 running acc average = 0.81
# End of epoch 42: running error average = 4.06 running acc average = 0.81
# End of epoch 43: running error average = 4.14 running acc average = 0.81
# End of epoch 44: running error average = 3.74 running acc average = 0.82
# End of epoch 45: running error average = 3.77 running acc average = 0.82
# End of epoch 46: running error average = 3.37 running acc average = 0.83
# End of epoch 47: running error average = 3.54 running acc average = 0.83
# End of epoch 48: running error average = 3.39 running acc average = 0.83
# End of epoch 49: running error average = 3.58 running acc average = 0.82
# End of epoch 50: running error average = 3.10 running acc average = 0.84

# %%
data = Adam_4layers_100_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_25(error).pdf')

# %%
data = Adam_4layers_100_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_25(acc).pdf')

# %%
n_hidden_1 = 100
n_hidden_2 = 100
n_hidden_3 = 100
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_100_L2_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 9882.73 running acc average = 0.18
# End of epoch 2: running error average = 4306.02 running acc average = 0.22
# End of epoch 3: running error average = 2787.23 running acc average = 0.22
# End of epoch 4: running error average = 2071.07 running acc average = 0.20
# End of epoch 5: running error average = 1634.13 running acc average = 0.13
# End of epoch 6: running error average = 1534.72 running acc average = 0.11
# End of epoch 7: running error average = 1499.51 running acc average = 0.11
# End of epoch 8: running error average = 1458.88 running acc average = 0.11
# End of epoch 9: running error average = 1405.46 running acc average = 0.12
# End of epoch 10: running error average = 1334.45 running acc average = 0.11
# End of epoch 11: running error average = 1241.30 running acc average = 0.12
# End of epoch 12: running error average = 1122.86 running acc average = 0.12
# End of epoch 13: running error average = 977.31 running acc average = 0.12
# End of epoch 14: running error average = 807.93 running acc average = 0.12
# End of epoch 15: running error average = 625.36 running acc average = 0.13
# End of epoch 16: running error average = 445.71 running acc average = 0.14
# End of epoch 17: running error average = 288.22 running acc average = 0.16
# End of epoch 18: running error average = 170.41 running acc average = 0.17
# End of epoch 19: running error average = 96.16 running acc average = 0.18
# End of epoch 20: running error average = 54.20 running acc average = 0.19
# End of epoch 21: running error average = 31.58 running acc average = 0.20
# End of epoch 22: running error average = 19.00 running acc average = 0.23
# End of epoch 23: running error average = 11.47 running acc average = 0.35
# End of epoch 24: running error average = 6.92 running acc average = 0.48
# End of epoch 25: running error average = 4.29 running acc average = 0.54
# End of epoch 26: running error average = 2.92 running acc average = 0.56
# End of epoch 27: running error average = 2.25 running acc average = 0.57
# End of epoch 28: running error average = 1.93 running acc average = 0.58
# End of epoch 29: running error average = 1.77 running acc average = 0.59
# End of epoch 30: running error average = 1.69 running acc average = 0.60
# End of epoch 31: running error average = 1.65 running acc average = 0.61
# End of epoch 32: running error average = 1.63 running acc average = 0.61
# End of epoch 33: running error average = 1.60 running acc average = 0.62
# End of epoch 34: running error average = 1.60 running acc average = 0.62
# End of epoch 35: running error average = 1.59 running acc average = 0.62
# End of epoch 36: running error average = 1.56 running acc average = 0.63
# End of epoch 37: running error average = 1.56 running acc average = 0.64
# End of epoch 38: running error average = 1.56 running acc average = 0.64
# End of epoch 39: running error average = 1.54 running acc average = 0.65
# End of epoch 40: running error average = 1.55 running acc average = 0.65
# End of epoch 41: running error average = 1.53 running acc average = 0.65
# End of epoch 42: running error average = 1.53 running acc average = 0.65
# End of epoch 43: running error average = 1.54 running acc average = 0.65
# End of epoch 44: running error average = 1.53 running acc average = 0.66
# End of epoch 45: running error average = 1.53 running acc average = 0.66
# End of epoch 46: running error average = 1.53 running acc average = 0.66
# End of epoch 47: running error average = 1.51 running acc average = 0.66
# End of epoch 48: running error average = 1.51 running acc average = 0.66
# End of epoch 49: running error average = 1.52 running acc average = 0.66
# End of epoch 50: running error average = 1.51 running acc average = 0.67

# %%
data = Adam_4layers_100_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_L2_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_L2_25(error).pdf')

# %%
data = Adam_4layers_100_L2_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_L2_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_L2_25(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
n_hidden_3 = 200
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_200_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 23362.80 running acc average = 0.23
# End of epoch 2: running error average = 9356.34 running acc average = 0.31
# End of epoch 3: running error average = 5779.40 running acc average = 0.35
# End of epoch 4: running error average = 3922.57 running acc average = 0.40
# End of epoch 5: running error average = 2807.24 running acc average = 0.45
# End of epoch 6: running error average = 1996.72 running acc average = 0.51
# End of epoch 7: running error average = 1441.13 running acc average = 0.56
# End of epoch 8: running error average = 1049.56 running acc average = 0.61
# End of epoch 9: running error average = 751.17 running acc average = 0.67
# End of epoch 10: running error average = 539.52 running acc average = 0.71
# End of epoch 11: running error average = 403.29 running acc average = 0.75
# End of epoch 12: running error average = 284.45 running acc average = 0.79
# End of epoch 13: running error average = 208.30 running acc average = 0.82
# End of epoch 14: running error average = 154.48 running acc average = 0.85
# End of epoch 15: running error average = 120.03 running acc average = 0.87
# End of epoch 16: running error average = 95.01 running acc average = 0.88
# End of epoch 17: running error average = 77.49 running acc average = 0.89
# End of epoch 18: running error average = 61.23 running acc average = 0.91
# End of epoch 19: running error average = 54.59 running acc average = 0.91
# End of epoch 20: running error average = 49.07 running acc average = 0.92
# End of epoch 21: running error average = 40.18 running acc average = 0.93
# End of epoch 22: running error average = 39.77 running acc average = 0.93
# End of epoch 23: running error average = 35.17 running acc average = 0.94
# End of epoch 24: running error average = 31.27 running acc average = 0.94
# End of epoch 25: running error average = 28.90 running acc average = 0.94
# End of epoch 26: running error average = 27.97 running acc average = 0.95
# End of epoch 27: running error average = 26.77 running acc average = 0.95
# End of epoch 28: running error average = 24.42 running acc average = 0.95
# End of epoch 29: running error average = 22.98 running acc average = 0.95
# End of epoch 30: running error average = 22.96 running acc average = 0.95
# End of epoch 31: running error average = 23.90 running acc average = 0.96
# End of epoch 32: running error average = 22.58 running acc average = 0.96
# End of epoch 33: running error average = 20.37 running acc average = 0.96
# End of epoch 34: running error average = 20.36 running acc average = 0.96
# End of epoch 35: running error average = 20.31 running acc average = 0.96
# End of epoch 36: running error average = 19.13 running acc average = 0.96
# End of epoch 37: running error average = 18.21 running acc average = 0.96
# End of epoch 38: running error average = 19.16 running acc average = 0.96
# End of epoch 39: running error average = 15.20 running acc average = 0.97
# End of epoch 40: running error average = 15.62 running acc average = 0.97
# End of epoch 41: running error average = 16.83 running acc average = 0.97
# End of epoch 42: running error average = 18.12 running acc average = 0.97
# End of epoch 43: running error average = 15.45 running acc average = 0.97
# End of epoch 44: running error average = 15.93 running acc average = 0.97
# End of epoch 45: running error average = 15.18 running acc average = 0.97
# End of epoch 46: running error average = 16.30 running acc average = 0.97
# End of epoch 47: running error average = 15.47 running acc average = 0.97
# End of epoch 48: running error average = 13.51 running acc average = 0.97
# End of epoch 49: running error average = 14.07 running acc average = 0.97
# End of epoch 50: running error average = 15.26 running acc average = 0.97

# %%
data = Adam_4layers_200_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_25(error).pdf')

# %%
data = Adam_4layers_200_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_25(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
n_hidden_3 = 200
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_200_L2_25_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 28380.81 running acc average = 0.24
# End of epoch 2: running error average = 13650.74 running acc average = 0.32
# End of epoch 3: running error average = 9810.81 running acc average = 0.37
# End of epoch 4: running error average = 7777.43 running acc average = 0.42
# End of epoch 5: running error average = 6496.22 running acc average = 0.47
# End of epoch 6: running error average = 5548.86 running acc average = 0.53
# End of epoch 7: running error average = 4925.46 running acc average = 0.59
# End of epoch 8: running error average = 4475.62 running acc average = 0.64
# End of epoch 9: running error average = 4101.06 running acc average = 0.70
# End of epoch 10: running error average = 3844.03 running acc average = 0.75
# End of epoch 11: running error average = 3664.56 running acc average = 0.78
# End of epoch 12: running error average = 3514.02 running acc average = 0.82
# End of epoch 13: running error average = 3407.60 running acc average = 0.85
# End of epoch 14: running error average = 3314.22 running acc average = 0.87
# End of epoch 15: running error average = 3245.86 running acc average = 0.88
# End of epoch 16: running error average = 3185.43 running acc average = 0.90
# End of epoch 17: running error average = 3129.30 running acc average = 0.91
# End of epoch 18: running error average = 3079.21 running acc average = 0.92
# End of epoch 19: running error average = 3029.13 running acc average = 0.92
# End of epoch 20: running error average = 2984.00 running acc average = 0.93
# End of epoch 21: running error average = 2930.86 running acc average = 0.94
# End of epoch 22: running error average = 2884.07 running acc average = 0.94
# End of epoch 23: running error average = 2833.94 running acc average = 0.94
# End of epoch 24: running error average = 2786.97 running acc average = 0.94
# End of epoch 25: running error average = 2738.61 running acc average = 0.94
# End of epoch 26: running error average = 2687.14 running acc average = 0.95
# End of epoch 27: running error average = 2640.11 running acc average = 0.95
# End of epoch 28: running error average = 2589.98 running acc average = 0.95
# End of epoch 29: running error average = 2538.18 running acc average = 0.95
# End of epoch 30: running error average = 2491.83 running acc average = 0.95
# End of epoch 31: running error average = 2439.28 running acc average = 0.96
# End of epoch 32: running error average = 2394.95 running acc average = 0.95
# End of epoch 33: running error average = 2343.18 running acc average = 0.96
# End of epoch 34: running error average = 2294.52 running acc average = 0.96
# End of epoch 35: running error average = 2245.56 running acc average = 0.96
# End of epoch 36: running error average = 2196.29 running acc average = 0.96
# End of epoch 37: running error average = 2148.62 running acc average = 0.96
# End of epoch 38: running error average = 2098.86 running acc average = 0.96
# End of epoch 39: running error average = 2049.97 running acc average = 0.96
# End of epoch 40: running error average = 2003.75 running acc average = 0.96
# End of epoch 41: running error average = 1957.00 running acc average = 0.96
# End of epoch 42: running error average = 1912.92 running acc average = 0.96
# End of epoch 43: running error average = 1864.88 running acc average = 0.96
# End of epoch 44: running error average = 1818.96 running acc average = 0.97
# End of epoch 45: running error average = 1773.80 running acc average = 0.96
# End of epoch 46: running error average = 1728.91 running acc average = 0.96
# End of epoch 47: running error average = 1685.41 running acc average = 0.96
# End of epoch 48: running error average = 1640.35 running acc average = 0.97
# End of epoch 49: running error average = 1598.83 running acc average = 0.96
# End of epoch 50: running error average = 1558.19 running acc average = 0.96
# End of epoch 51: running error average = 1515.77 running acc average = 0.97
# End of epoch 52: running error average = 1476.13 running acc average = 0.96
# End of epoch 53: running error average = 1435.22 running acc average = 0.96
# End of epoch 54: running error average = 1394.30 running acc average = 0.97
# End of epoch 55: running error average = 1356.26 running acc average = 0.97
# End of epoch 56: running error average = 1317.26 running acc average = 0.97
# End of epoch 57: running error average = 1279.24 running acc average = 0.96
# End of epoch 58: running error average = 1242.00 running acc average = 0.96
# End of epoch 59: running error average = 1206.35 running acc average = 0.96
# End of epoch 60: running error average = 1170.78 running acc average = 0.96
# End of epoch 61: running error average = 1137.40 running acc average = 0.96
# End of epoch 62: running error average = 1103.62 running acc average = 0.96
# End of epoch 63: running error average = 1069.85 running acc average = 0.96
# End of epoch 64: running error average = 1037.64 running acc average = 0.96
# End of epoch 65: running error average = 1005.81 running acc average = 0.96
# End of epoch 66: running error average = 974.61 running acc average = 0.96
# End of epoch 67: running error average = 943.07 running acc average = 0.96
# End of epoch 68: running error average = 912.76 running acc average = 0.96
# End of epoch 69: running error average = 883.47 running acc average = 0.96
# End of epoch 70: running error average = 854.34 running acc average = 0.96
# End of epoch 71: running error average = 825.70 running acc average = 0.96
# End of epoch 72: running error average = 798.81 running acc average = 0.96
# End of epoch 73: running error average = 771.34 running acc average = 0.96
# End of epoch 74: running error average = 744.65 running acc average = 0.96
# End of epoch 75: running error average = 719.45 running acc average = 0.96
# End of epoch 76: running error average = 694.69 running acc average = 0.96
# End of epoch 77: running error average = 670.86 running acc average = 0.96
# End of epoch 78: running error average = 646.19 running acc average = 0.96
# End of epoch 79: running error average = 622.83 running acc average = 0.96
# End of epoch 80: running error average = 601.12 running acc average = 0.96
# End of epoch 81: running error average = 578.72 running acc average = 0.95
# End of epoch 82: running error average = 557.26 running acc average = 0.95
# End of epoch 83: running error average = 536.00 running acc average = 0.96
# End of epoch 84: running error average = 514.76 running acc average = 0.96
# End of epoch 85: running error average = 494.79 running acc average = 0.95
# End of epoch 86: running error average = 475.13 running acc average = 0.95
# End of epoch 87: running error average = 455.22 running acc average = 0.95
# End of epoch 88: running error average = 436.44 running acc average = 0.95
# End of epoch 89: running error average = 417.80 running acc average = 0.95
# End of epoch 90: running error average = 400.38 running acc average = 0.95
# End of epoch 91: running error average = 383.03 running acc average = 0.95
# End of epoch 92: running error average = 366.13 running acc average = 0.95
# End of epoch 93: running error average = 349.33 running acc average = 0.95
# End of epoch 94: running error average = 334.00 running acc average = 0.94
# End of epoch 95: running error average = 318.49 running acc average = 0.94
# End of epoch 96: running error average = 302.64 running acc average = 0.95
# End of epoch 97: running error average = 288.19 running acc average = 0.94
# End of epoch 98: running error average = 273.90 running acc average = 0.94
# End of epoch 99: running error average = 260.54 running acc average = 0.93
# End of epoch 100: running error average = 246.42 running acc average = 0.94

# %%
data = Adam_4layers_200_L2_25_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2_25_100(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2_25_100(error).pdf')

# %%
data = Adam_4layers_200_L2_25_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2_25_100(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2_25_100(acc).pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
n_hidden_3 = 300
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_300_25 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 39131.28 running acc average = 0.26
# End of epoch 2: running error average = 16186.92 running acc average = 0.35
# End of epoch 3: running error average = 10081.10 running acc average = 0.42
# End of epoch 4: running error average = 6678.73 running acc average = 0.50
# End of epoch 5: running error average = 4638.69 running acc average = 0.57
# End of epoch 6: running error average = 3085.88 running acc average = 0.64
# End of epoch 7: running error average = 2063.56 running acc average = 0.71
# End of epoch 8: running error average = 1404.87 running acc average = 0.77
# End of epoch 9: running error average = 925.06 running acc average = 0.81
# End of epoch 10: running error average = 605.95 running acc average = 0.85
# End of epoch 11: running error average = 425.40 running acc average = 0.88
# End of epoch 12: running error average = 296.06 running acc average = 0.90
# End of epoch 13: running error average = 228.95 running acc average = 0.91
# End of epoch 14: running error average = 183.32 running acc average = 0.92
# End of epoch 15: running error average = 157.82 running acc average = 0.93
# End of epoch 16: running error average = 131.68 running acc average = 0.94
# End of epoch 17: running error average = 126.62 running acc average = 0.94
# End of epoch 18: running error average = 112.64 running acc average = 0.94
# End of epoch 19: running error average = 102.33 running acc average = 0.95
# End of epoch 20: running error average = 89.67 running acc average = 0.95
# End of epoch 21: running error average = 91.01 running acc average = 0.95
# End of epoch 22: running error average = 89.54 running acc average = 0.95
# End of epoch 23: running error average = 90.02 running acc average = 0.96
# End of epoch 24: running error average = 76.02 running acc average = 0.96
# End of epoch 25: running error average = 71.08 running acc average = 0.96
# End of epoch 26: running error average = 63.46 running acc average = 0.97
# End of epoch 27: running error average = 72.09 running acc average = 0.97
# End of epoch 28: running error average = 67.36 running acc average = 0.97
# End of epoch 29: running error average = 63.07 running acc average = 0.97
# End of epoch 30: running error average = 63.16 running acc average = 0.97
# End of epoch 31: running error average = 61.29 running acc average = 0.97
# End of epoch 32: running error average = 53.80 running acc average = 0.97
# End of epoch 33: running error average = 60.94 running acc average = 0.97
# End of epoch 34: running error average = 53.77 running acc average = 0.97
# End of epoch 35: running error average = 53.26 running acc average = 0.97
# End of epoch 36: running error average = 52.63 running acc average = 0.97
# End of epoch 37: running error average = 48.79 running acc average = 0.97
# End of epoch 38: running error average = 50.19 running acc average = 0.98
# End of epoch 39: running error average = 48.49 running acc average = 0.98
# End of epoch 40: running error average = 43.63 running acc average = 0.98
# End of epoch 41: running error average = 46.59 running acc average = 0.98
# End of epoch 42: running error average = 46.95 running acc average = 0.98
# End of epoch 43: running error average = 48.92 running acc average = 0.98
# End of epoch 44: running error average = 43.02 running acc average = 0.98
# End of epoch 45: running error average = 46.51 running acc average = 0.98
# End of epoch 46: running error average = 44.20 running acc average = 0.98
# End of epoch 47: running error average = 43.26 running acc average = 0.98
# End of epoch 48: running error average = 42.64 running acc average = 0.98
# End of epoch 49: running error average = 38.17 running acc average = 0.98
# End of epoch 50: running error average = 37.46 running acc average = 0.98

# %%
data = Adam_4layers_300_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_25(error).pdf')

# %%
data = Adam_4layers_300_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_25(acc).pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
n_hidden_3 = 300
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_300_L2_25_100= [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 47930.99 running acc average = 0.26
# End of epoch 2: running error average = 22527.47 running acc average = 0.35
# End of epoch 3: running error average = 16020.94 running acc average = 0.42
# End of epoch 4: running error average = 12271.43 running acc average = 0.50
# End of epoch 5: running error average = 10068.38 running acc average = 0.57
# End of epoch 6: running error average = 8522.89 running acc average = 0.64
# End of epoch 7: running error average = 7392.01 running acc average = 0.72
# End of epoch 8: running error average = 6738.03 running acc average = 0.76
# End of epoch 9: running error average = 6235.01 running acc average = 0.81
# End of epoch 10: running error average = 5901.41 running acc average = 0.85
# End of epoch 11: running error average = 5668.55 running acc average = 0.88
# End of epoch 12: running error average = 5516.38 running acc average = 0.90
# End of epoch 13: running error average = 5404.67 running acc average = 0.91
# End of epoch 14: running error average = 5329.28 running acc average = 0.92
# End of epoch 15: running error average = 5256.02 running acc average = 0.93
# End of epoch 16: running error average = 5201.64 running acc average = 0.94
# End of epoch 17: running error average = 5152.31 running acc average = 0.94
# End of epoch 18: running error average = 5111.93 running acc average = 0.94
# End of epoch 19: running error average = 5055.46 running acc average = 0.95
# End of epoch 20: running error average = 5000.80 running acc average = 0.95
# End of epoch 21: running error average = 4952.40 running acc average = 0.95
# End of epoch 22: running error average = 4895.05 running acc average = 0.96
# End of epoch 23: running error average = 4855.25 running acc average = 0.96
# End of epoch 24: running error average = 4799.15 running acc average = 0.96
# End of epoch 25: running error average = 4743.68 running acc average = 0.96
# End of epoch 26: running error average = 4691.80 running acc average = 0.96
# End of epoch 27: running error average = 4638.87 running acc average = 0.96
# End of epoch 28: running error average = 4590.91 running acc average = 0.96
# End of epoch 29: running error average = 4533.99 running acc average = 0.97
# End of epoch 30: running error average = 4491.06 running acc average = 0.96
# End of epoch 31: running error average = 4425.58 running acc average = 0.97
# End of epoch 32: running error average = 4371.89 running acc average = 0.97
# End of epoch 33: running error average = 4324.24 running acc average = 0.97
# End of epoch 34: running error average = 4270.61 running acc average = 0.97
# End of epoch 35: running error average = 4209.98 running acc average = 0.97
# End of epoch 36: running error average = 4159.63 running acc average = 0.97
# End of epoch 37: running error average = 4107.58 running acc average = 0.97
# End of epoch 38: running error average = 4045.13 running acc average = 0.97
# End of epoch 39: running error average = 3990.90 running acc average = 0.97
# End of epoch 40: running error average = 3939.17 running acc average = 0.97
# End of epoch 41: running error average = 3881.98 running acc average = 0.97
# End of epoch 42: running error average = 3828.65 running acc average = 0.97
# End of epoch 43: running error average = 3769.79 running acc average = 0.97
# End of epoch 44: running error average = 3718.70 running acc average = 0.97
# End of epoch 45: running error average = 3663.37 running acc average = 0.97
# End of epoch 46: running error average = 3612.05 running acc average = 0.98
# End of epoch 47: running error average = 3558.39 running acc average = 0.97
# End of epoch 48: running error average = 3502.77 running acc average = 0.97
# End of epoch 49: running error average = 3450.97 running acc average = 0.98
# End of epoch 50: running error average = 3394.26 running acc average = 0.98
# End of epoch 51: running error average = 3350.52 running acc average = 0.97
# End of epoch 52: running error average = 3291.92 running acc average = 0.97
# End of epoch 53: running error average = 3237.97 running acc average = 0.98
# End of epoch 54: running error average = 3181.78 running acc average = 0.98
# End of epoch 55: running error average = 3136.83 running acc average = 0.97
# End of epoch 56: running error average = 3083.33 running acc average = 0.98
# End of epoch 57: running error average = 3031.89 running acc average = 0.98
# End of epoch 58: running error average = 2977.97 running acc average = 0.98
# End of epoch 59: running error average = 2927.51 running acc average = 0.98
# End of epoch 60: running error average = 2884.26 running acc average = 0.97
# End of epoch 61: running error average = 2826.47 running acc average = 0.98
# End of epoch 62: running error average = 2780.33 running acc average = 0.98
# End of epoch 63: running error average = 2731.07 running acc average = 0.98
# End of epoch 64: running error average = 2681.31 running acc average = 0.98
# End of epoch 65: running error average = 2631.87 running acc average = 0.98
# End of epoch 66: running error average = 2588.84 running acc average = 0.98
# End of epoch 67: running error average = 2536.12 running acc average = 0.98
# End of epoch 68: running error average = 2492.99 running acc average = 0.98
# End of epoch 69: running error average = 2439.63 running acc average = 0.98
# End of epoch 70: running error average = 2395.01 running acc average = 0.98
# End of epoch 71: running error average = 2350.34 running acc average = 0.98
# End of epoch 72: running error average = 2306.38 running acc average = 0.98
# End of epoch 73: running error average = 2258.90 running acc average = 0.98
# End of epoch 74: running error average = 2218.39 running acc average = 0.98
# End of epoch 75: running error average = 2171.66 running acc average = 0.98
# End of epoch 76: running error average = 2128.25 running acc average = 0.98
# End of epoch 77: running error average = 2087.99 running acc average = 0.98
# End of epoch 78: running error average = 2043.83 running acc average = 0.98
# End of epoch 79: running error average = 2000.69 running acc average = 0.98
# End of epoch 80: running error average = 1960.12 running acc average = 0.98
# End of epoch 81: running error average = 1922.44 running acc average = 0.97
# End of epoch 82: running error average = 1882.38 running acc average = 0.98
# End of epoch 83: running error average = 1840.37 running acc average = 0.98
# End of epoch 84: running error average = 1800.42 running acc average = 0.98
# End of epoch 85: running error average = 1761.99 running acc average = 0.98
# End of epoch 86: running error average = 1725.73 running acc average = 0.97
# End of epoch 87: running error average = 1683.99 running acc average = 0.98
# End of epoch 88: running error average = 1650.02 running acc average = 0.97
# End of epoch 89: running error average = 1611.61 running acc average = 0.97
# End of epoch 90: running error average = 1574.31 running acc average = 0.98
# End of epoch 91: running error average = 1541.58 running acc average = 0.97
# End of epoch 92: running error average = 1505.34 running acc average = 0.98
# End of epoch 93: running error average = 1469.44 running acc average = 0.98
# End of epoch 94: running error average = 1432.97 running acc average = 0.98
# End of epoch 95: running error average = 1402.39 running acc average = 0.97
# End of epoch 96: running error average = 1366.48 running acc average = 0.98
# End of epoch 97: running error average = 1332.88 running acc average = 0.98
# End of epoch 98: running error average = 1299.09 running acc average = 0.97
# End of epoch 99: running error average = 1270.01 running acc average = 0.97
# End of epoch 100: running error average = 1236.39 running acc average = 0.97

# %%
data = Adam_4layers_300_L2_25_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_25_100(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_25_100(error).pdf')

# %%
data = Adam_4layers_300_L2_25_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_25_100(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_25_100(acc).pdf')

# %%
np.save('Adam_4layers_100_25', Adam_4layers_100_25)
np.save('Adam_4layers_100_L2_25', Adam_4layers_100_L2_25)
np.save('Adam_4layers_200_25', Adam_4layers_200_25)
np.save('Adam_4layers_200_L2_25', Adam_4layers_200_L2_25)
np.save('Adam_4layers_300_25', Adam_4layers_300_25)
np.save('Adam_4layers_300_L2_25', Adam_4layers_300_L2_25)

# %%
np.save('Adam_4layers_200_L2_25_100', Adam_4layers_200_L2_25_100)
np.save('Adam_4layers_300_L2_25_100', Adam_4layers_300_L2_25_100)
