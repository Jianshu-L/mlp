# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 200
n_hidden_2 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_200_L2_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 6324.06 running acc average = 0.25
# End of epoch 2: running error average = 4718.55 running acc average = 0.33
# End of epoch 3: running error average = 4131.62 running acc average = 0.39
# End of epoch 4: running error average = 3772.05 running acc average = 0.43
# End of epoch 5: running error average = 3505.03 running acc average = 0.48
# End of epoch 6: running error average = 3261.16 running acc average = 0.54
# End of epoch 7: running error average = 3069.01 running acc average = 0.59
# End of epoch 8: running error average = 2899.80 running acc average = 0.64
# End of epoch 9: running error average = 2740.67 running acc average = 0.69
# End of epoch 10: running error average = 2585.18 running acc average = 0.74
# End of epoch 11: running error average = 2444.94 running acc average = 0.78
# End of epoch 12: running error average = 2303.09 running acc average = 0.81
# End of epoch 13: running error average = 2160.37 running acc average = 0.85
# End of epoch 14: running error average = 2020.38 running acc average = 0.87
# End of epoch 15: running error average = 1878.78 running acc average = 0.89
# End of epoch 16: running error average = 1736.23 running acc average = 0.90
# End of epoch 17: running error average = 1595.45 running acc average = 0.91
# End of epoch 18: running error average = 1457.18 running acc average = 0.92
# End of epoch 19: running error average = 1322.38 running acc average = 0.92
# End of epoch 20: running error average = 1194.43 running acc average = 0.93
# End of epoch 21: running error average = 1074.25 running acc average = 0.93
# End of epoch 22: running error average = 962.33 running acc average = 0.93
# End of epoch 23: running error average = 858.73 running acc average = 0.93
# End of epoch 24: running error average = 764.59 running acc average = 0.93
# End of epoch 25: running error average = 678.17 running acc average = 0.93
# End of epoch 26: running error average = 599.87 running acc average = 0.93
# End of epoch 27: running error average = 528.91 running acc average = 0.93
# End of epoch 28: running error average = 465.24 running acc average = 0.93
# End of epoch 29: running error average = 408.52 running acc average = 0.92
# End of epoch 30: running error average = 357.52 running acc average = 0.93
# End of epoch 31: running error average = 311.88 running acc average = 0.93
# End of epoch 32: running error average = 271.31 running acc average = 0.92
# End of epoch 33: running error average = 235.45 running acc average = 0.92
# End of epoch 34: running error average = 203.62 running acc average = 0.91
# End of epoch 35: running error average = 175.65 running acc average = 0.91
# End of epoch 36: running error average = 150.53 running acc average = 0.91
# End of epoch 37: running error average = 128.40 running acc average = 0.90
# End of epoch 38: running error average = 109.19 running acc average = 0.89
# End of epoch 39: running error average = 92.29 running acc average = 0.89
# End of epoch 40: running error average = 77.52 running acc average = 0.88
# End of epoch 41: running error average = 64.58 running acc average = 0.88
# End of epoch 42: running error average = 53.46 running acc average = 0.87
# End of epoch 43: running error average = 43.79 running acc average = 0.86
# End of epoch 44: running error average = 35.39 running acc average = 0.85
# End of epoch 45: running error average = 28.17 running acc average = 0.84
# End of epoch 46: running error average = 22.08 running acc average = 0.82
# End of epoch 47: running error average = 16.91 running acc average = 0.81
# End of epoch 48: running error average = 12.63 running acc average = 0.81
# End of epoch 49: running error average = 9.23 running acc average = 0.80
# End of epoch 50: running error average = 6.63 running acc average = 0.79
# End of epoch 51: running error average = 4.84 running acc average = 0.78
# End of epoch 52: running error average = 3.73 running acc average = 0.74
# End of epoch 53: running error average = 3.03 running acc average = 0.72
# End of epoch 54: running error average = 2.57 running acc average = 0.71
# End of epoch 55: running error average = 2.27 running acc average = 0.70
# End of epoch 56: running error average = 2.08 running acc average = 0.68
# End of epoch 57: running error average = 1.95 running acc average = 0.68
# End of epoch 58: running error average = 1.86 running acc average = 0.67
# End of epoch 59: running error average = 1.79 running acc average = 0.66
# End of epoch 60: running error average = 1.74 running acc average = 0.66
# End of epoch 61: running error average = 1.71 running acc average = 0.65
# End of epoch 62: running error average = 1.67 running acc average = 0.66
# End of epoch 63: running error average = 1.65 running acc average = 0.66
# End of epoch 64: running error average = 1.64 running acc average = 0.65
# End of epoch 65: running error average = 1.62 running acc average = 0.66
# End of epoch 66: running error average = 1.60 running acc average = 0.66
# End of epoch 67: running error average = 1.58 running acc average = 0.67
# End of epoch 68: running error average = 1.58 running acc average = 0.66
# End of epoch 69: running error average = 1.57 running acc average = 0.66
# End of epoch 70: running error average = 1.56 running acc average = 0.67
# End of epoch 71: running error average = 1.54 running acc average = 0.68
# End of epoch 72: running error average = 1.54 running acc average = 0.67
# End of epoch 73: running error average = 1.53 running acc average = 0.68
# End of epoch 74: running error average = 1.52 running acc average = 0.68
# End of epoch 75: running error average = 1.52 running acc average = 0.69
# End of epoch 76: running error average = 1.52 running acc average = 0.68
# End of epoch 77: running error average = 1.51 running acc average = 0.68
# End of epoch 78: running error average = 1.51 running acc average = 0.68
# End of epoch 79: running error average = 1.50 running acc average = 0.69
# End of epoch 80: running error average = 1.51 running acc average = 0.69
# End of epoch 81: running error average = 1.50 running acc average = 0.69
# End of epoch 82: running error average = 1.49 running acc average = 0.69
# End of epoch 83: running error average = 1.50 running acc average = 0.69
# End of epoch 84: running error average = 1.50 running acc average = 0.69
# End of epoch 85: running error average = 1.48 running acc average = 0.69
# End of epoch 86: running error average = 1.49 running acc average = 0.69
# End of epoch 87: running error average = 1.49 running acc average = 0.69
# End of epoch 88: running error average = 1.48 running acc average = 0.69
# End of epoch 89: running error average = 1.49 running acc average = 0.70
# End of epoch 90: running error average = 1.48 running acc average = 0.69
# End of epoch 91: running error average = 1.49 running acc average = 0.70
# End of epoch 92: running error average = 1.48 running acc average = 0.70
# End of epoch 93: running error average = 1.48 running acc average = 0.69
# End of epoch 94: running error average = 1.48 running acc average = 0.70
# End of epoch 95: running error average = 1.48 running acc average = 0.70
# End of epoch 96: running error average = 1.47 running acc average = 0.70
# End of epoch 97: running error average = 1.48 running acc average = 0.70
# End of epoch 98: running error average = 1.48 running acc average = 0.70
# End of epoch 99: running error average = 1.48 running acc average = 0.69
# End of epoch 100: running error average = 1.48 running acc average = 0.70

# %%
data = Adam_3layers_200_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_L2(error)_100.pdf')

# %%
data = Adam_3layers_200_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_L2(acc)_100.pdf')
print(data[3])
# Out:
# [ 0.26816667  0.28533333  0.27216667  0.29266667  0.28466667  0.286
#   0.27633333  0.2795      0.26233333  0.28566667  0.28716667  0.28766667
#   0.287       0.28066667  0.28583333  0.2865      0.293       0.29816667
#   0.29183333  0.285       0.29966667  0.29        0.29766667  0.303
#   0.29783333  0.3125      0.28866667  0.28916667  0.29416667  0.313       0.3165
#   0.319       0.30733333  0.308       0.31416667  0.318       0.32383333
#   0.31816667  0.309       0.33416667  0.31616667  0.343       0.32616667
#   0.33933333  0.33083333  0.336       0.3525      0.344       0.35583333
#   0.38483334  0.39183333  0.43383333  0.427       0.45066667  0.43466666
#   0.45283333  0.44616667  0.4505      0.45916667  0.46733333  0.45166667
#   0.46016666  0.45516666  0.482       0.45683333  0.46883333  0.466
#   0.47333333  0.46833333  0.46233333  0.46083333  0.45733333  0.44766667
#   0.44133333  0.48        0.45416667  0.452       0.449       0.46933333
#   0.48066666  0.45733333  0.44483333  0.44283333  0.45416667  0.46183333
#   0.44566667  0.44783333  0.43583333  0.46083333  0.46566667  0.46533333
#   0.44516666  0.45416666  0.45783333  0.47516667  0.44983333  0.46466667
#   0.45666667  0.44883333  0.4615    ]

# %%
n_hidden_1 = 300
n_hidden_2 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_300_L2_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 9371.75 running acc average = 0.28
# End of epoch 2: running error average = 7103.34 running acc average = 0.36
# End of epoch 3: running error average = 6231.76 running acc average = 0.42
# End of epoch 4: running error average = 5690.01 running acc average = 0.48
# End of epoch 5: running error average = 5314.86 running acc average = 0.55
# End of epoch 6: running error average = 5002.91 running acc average = 0.61
# End of epoch 7: running error average = 4726.21 running acc average = 0.68
# End of epoch 8: running error average = 4502.23 running acc average = 0.73
# End of epoch 9: running error average = 4285.78 running acc average = 0.79
# End of epoch 10: running error average = 4085.10 running acc average = 0.83
# End of epoch 11: running error average = 3891.60 running acc average = 0.86
# End of epoch 12: running error average = 3695.00 running acc average = 0.89
# End of epoch 13: running error average = 3494.35 running acc average = 0.91
# End of epoch 14: running error average = 3287.30 running acc average = 0.92
# End of epoch 15: running error average = 3075.29 running acc average = 0.93
# End of epoch 16: running error average = 2863.46 running acc average = 0.93
# End of epoch 17: running error average = 2652.23 running acc average = 0.94
# End of epoch 18: running error average = 2446.18 running acc average = 0.94
# End of epoch 19: running error average = 2246.06 running acc average = 0.95
# End of epoch 20: running error average = 2055.87 running acc average = 0.94
# End of epoch 21: running error average = 1875.61 running acc average = 0.95
# End of epoch 22: running error average = 1707.64 running acc average = 0.94
# End of epoch 23: running error average = 1550.57 running acc average = 0.95
# End of epoch 24: running error average = 1403.80 running acc average = 0.95
# End of epoch 25: running error average = 1267.90 running acc average = 0.95
# End of epoch 26: running error average = 1141.43 running acc average = 0.95
# End of epoch 27: running error average = 1024.60 running acc average = 0.94
# End of epoch 28: running error average = 916.40 running acc average = 0.95
# End of epoch 29: running error average = 817.91 running acc average = 0.94
# End of epoch 30: running error average = 728.12 running acc average = 0.94
# End of epoch 31: running error average = 645.79 running acc average = 0.94
# End of epoch 32: running error average = 570.89 running acc average = 0.94
# End of epoch 33: running error average = 502.84 running acc average = 0.94
# End of epoch 34: running error average = 441.57 running acc average = 0.93
# End of epoch 35: running error average = 386.54 running acc average = 0.93
# End of epoch 36: running error average = 336.76 running acc average = 0.93
# End of epoch 37: running error average = 291.47 running acc average = 0.93
# End of epoch 38: running error average = 251.13 running acc average = 0.92
# End of epoch 39: running error average = 215.12 running acc average = 0.91
# End of epoch 40: running error average = 182.91 running acc average = 0.91
# End of epoch 41: running error average = 154.51 running acc average = 0.91
# End of epoch 42: running error average = 129.04 running acc average = 0.90
# End of epoch 43: running error average = 106.74 running acc average = 0.89
# End of epoch 44: running error average = 87.05 running acc average = 0.88
# End of epoch 45: running error average = 70.07 running acc average = 0.88
# End of epoch 46: running error average = 55.38 running acc average = 0.87
# End of epoch 47: running error average = 42.60 running acc average = 0.86
# End of epoch 48: running error average = 31.87 running acc average = 0.85
# End of epoch 49: running error average = 22.89 running acc average = 0.84
# End of epoch 50: running error average = 15.66 running acc average = 0.83
# End of epoch 51: running error average = 10.10 running acc average = 0.83
# End of epoch 52: running error average = 6.34 running acc average = 0.81
# End of epoch 53: running error average = 4.13 running acc average = 0.77
# End of epoch 54: running error average = 2.94 running acc average = 0.74
# End of epoch 55: running error average = 2.36 running acc average = 0.70
# End of epoch 56: running error average = 2.06 running acc average = 0.68
# End of epoch 57: running error average = 1.92 running acc average = 0.66
# End of epoch 58: running error average = 1.83 running acc average = 0.64
# End of epoch 59: running error average = 1.77 running acc average = 0.64
# End of epoch 60: running error average = 1.72 running acc average = 0.64
# End of epoch 61: running error average = 1.71 running acc average = 0.63
# End of epoch 62: running error average = 1.66 running acc average = 0.64
# End of epoch 63: running error average = 1.65 running acc average = 0.64
# End of epoch 64: running error average = 1.64 running acc average = 0.64
# End of epoch 65: running error average = 1.62 running acc average = 0.64
# End of epoch 66: running error average = 1.59 running acc average = 0.65
# End of epoch 67: running error average = 1.58 running acc average = 0.65
# End of epoch 68: running error average = 1.57 running acc average = 0.65
# End of epoch 69: running error average = 1.56 running acc average = 0.66
# End of epoch 70: running error average = 1.55 running acc average = 0.66
# End of epoch 71: running error average = 1.53 running acc average = 0.67
# End of epoch 72: running error average = 1.53 running acc average = 0.67
# End of epoch 73: running error average = 1.52 running acc average = 0.67
# End of epoch 74: running error average = 1.52 running acc average = 0.67
# End of epoch 75: running error average = 1.51 running acc average = 0.67
# End of epoch 76: running error average = 1.51 running acc average = 0.68
# End of epoch 77: running error average = 1.50 running acc average = 0.68
# End of epoch 78: running error average = 1.50 running acc average = 0.68
# End of epoch 79: running error average = 1.49 running acc average = 0.68
# End of epoch 80: running error average = 1.49 running acc average = 0.68
# End of epoch 81: running error average = 1.49 running acc average = 0.69
# End of epoch 82: running error average = 1.49 running acc average = 0.69
# End of epoch 83: running error average = 1.49 running acc average = 0.69
# End of epoch 84: running error average = 1.49 running acc average = 0.69
# End of epoch 85: running error average = 1.48 running acc average = 0.69
# End of epoch 86: running error average = 1.49 running acc average = 0.69
# End of epoch 87: running error average = 1.48 running acc average = 0.69
# End of epoch 88: running error average = 1.48 running acc average = 0.69
# End of epoch 89: running error average = 1.48 running acc average = 0.69
# End of epoch 90: running error average = 1.47 running acc average = 0.69
# End of epoch 91: running error average = 1.48 running acc average = 0.69
# End of epoch 92: running error average = 1.48 running acc average = 0.69
# End of epoch 93: running error average = 1.48 running acc average = 0.69
# End of epoch 94: running error average = 1.47 running acc average = 0.69
# End of epoch 95: running error average = 1.48 running acc average = 0.69
# End of epoch 96: running error average = 1.48 running acc average = 0.69
# End of epoch 97: running error average = 1.47 running acc average = 0.69
# End of epoch 98: running error average = 1.47 running acc average = 0.70
# End of epoch 99: running error average = 1.48 running acc average = 0.70
# End of epoch 100: running error average = 1.47 running acc average = 0.70

# %%
data = Adam_3layers_300_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_L2(error)_100.pdf')

# %%
data = Adam_3layers_300_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_L2(acc)_100.pdf')
print(data[1])
print(data[3])
# Out:
# [ 0.27594118  0.35944118  0.41932353  0.484       0.5475      0.61144118
#   0.67629412  0.73120588  0.78682353  0.83223529  0.86020588  0.89032353
#   0.90617647  0.91855882  0.92723529  0.93352941  0.938       0.94191176
#   0.94523529  0.94129412  0.94617647  0.94273529  0.94597059  0.94547059
#   0.94611765  0.9485      0.94488235  0.94752941  0.94352941  0.9412647
#   0.94414706  0.93935294  0.93820588  0.93317647  0.92961764  0.93261764
#   0.93114706  0.91970588  0.91397059  0.9135      0.90720588  0.90379411
#   0.89291176  0.88464705  0.87505882  0.86585294  0.8572647   0.84867646
#   0.83905882  0.83244117  0.83011764  0.80894117  0.77132353  0.73770588
#   0.69935294  0.67852942  0.65741177  0.64497059  0.63694118  0.63611765
#   0.62932353  0.63620589  0.63982353  0.63841177  0.64038236  0.64935295
#   0.65302942  0.65476471  0.66117648  0.65805883  0.66714706  0.66608824
#   0.67291177  0.67367648  0.67326471  0.67588236  0.67861765  0.681
#   0.68432353  0.68441177  0.68714706  0.68602942  0.68747059  0.68779412
#   0.69058824  0.68635295  0.69211765  0.69311765  0.69305883  0.6935
#   0.6915      0.69247059  0.69394118  0.6945      0.69279412  0.69097059
#   0.69155883  0.69661765  0.69667647  0.70064706]
# [ 0.2805      0.2785      0.277       0.28466667  0.29566667  0.29233333
#   0.27633333  0.28933333  0.29066667  0.2875      0.2905      0.2915      0.289
#   0.27883333  0.3         0.29433333  0.30366667  0.2995      0.2985
#   0.29283333  0.31616667  0.30166667  0.292       0.31383333  0.31133333
#   0.305       0.319       0.30333333  0.3185      0.31483333  0.31616667
#   0.321       0.323       0.31983334  0.3085      0.326       0.33583333
#   0.34116667  0.33266667  0.3325      0.33866667  0.33366667  0.3305      0.346
#   0.34866667  0.34616667  0.35133333  0.353       0.34716667  0.37366667
#   0.36616667  0.42666667  0.42216666  0.45366667  0.446       0.4475
#   0.45866666  0.45116667  0.4675      0.4655      0.454       0.4645
#   0.4705      0.48066667  0.45866666  0.46216667  0.47366667  0.47316667
#   0.46183333  0.45883333  0.47283333  0.46166667  0.45433333  0.425       0.4805
#   0.46083333  0.44383333  0.4655      0.46416666  0.4685      0.4575
#   0.44116667  0.44716667  0.4465      0.45866667  0.45        0.45733333
#   0.44933333  0.46283333  0.47283333  0.46966667  0.46366667  0.4545      0.451
#   0.46516667  0.447       0.45483333  0.465       0.45616667  0.4615    ]

# %%
np.save('Adam_3layers_200_L2_100', Adam_3layers_200_L2_100)
np.save('Adam_3layers_300_L2_100', Adam_3layers_300_L2_100)
