# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
n_hidden_2 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 1584.42 running acc average = 0.23
# End of epoch 2: running error average = 812.48 running acc average = 0.29
# End of epoch 3: running error average = 526.82 running acc average = 0.31
# End of epoch 4: running error average = 377.96 running acc average = 0.33
# End of epoch 5: running error average = 270.57 running acc average = 0.33
# End of epoch 6: running error average = 189.52 running acc average = 0.35
# End of epoch 7: running error average = 133.68 running acc average = 0.36
# End of epoch 8: running error average = 89.78 running acc average = 0.35
# End of epoch 9: running error average = 54.75 running acc average = 0.33
# End of epoch 10: running error average = 30.13 running acc average = 0.31
# End of epoch 11: running error average = 15.25 running acc average = 0.29
# End of epoch 12: running error average = 7.84 running acc average = 0.27
# End of epoch 13: running error average = 4.61 running acc average = 0.25
# End of epoch 14: running error average = 3.27 running acc average = 0.24
# End of epoch 15: running error average = 2.63 running acc average = 0.25
# End of epoch 16: running error average = 2.30 running acc average = 0.25
# End of epoch 17: running error average = 2.15 running acc average = 0.26
# End of epoch 18: running error average = 2.08 running acc average = 0.27
# End of epoch 19: running error average = 2.00 running acc average = 0.27
# End of epoch 20: running error average = 1.96 running acc average = 0.29
# End of epoch 21: running error average = 1.92 running acc average = 0.30
# End of epoch 22: running error average = 1.91 running acc average = 0.30
# End of epoch 23: running error average = 1.90 running acc average = 0.31
# End of epoch 24: running error average = 1.88 running acc average = 0.32
# End of epoch 25: running error average = 1.85 running acc average = 0.33
# End of epoch 26: running error average = 1.81 running acc average = 0.34
# End of epoch 27: running error average = 1.79 running acc average = 0.34
# End of epoch 28: running error average = 1.77 running acc average = 0.34
# End of epoch 29: running error average = 1.77 running acc average = 0.35
# End of epoch 30: running error average = 1.76 running acc average = 0.35
# End of epoch 31: running error average = 1.75 running acc average = 0.36
# End of epoch 32: running error average = 1.72 running acc average = 0.37
# End of epoch 33: running error average = 1.69 running acc average = 0.37
# End of epoch 34: running error average = 1.69 running acc average = 0.38
# End of epoch 35: running error average = 1.70 running acc average = 0.38
# End of epoch 36: running error average = 1.66 running acc average = 0.39
# End of epoch 37: running error average = 1.65 running acc average = 0.39
# End of epoch 38: running error average = 1.64 running acc average = 0.40
# End of epoch 39: running error average = 1.62 running acc average = 0.39
# End of epoch 40: running error average = 1.60 running acc average = 0.40
# End of epoch 41: running error average = 1.59 running acc average = 0.41
# End of epoch 42: running error average = 1.58 running acc average = 0.41
# End of epoch 43: running error average = 1.58 running acc average = 0.42
# End of epoch 44: running error average = 1.56 running acc average = 0.42
# End of epoch 45: running error average = 1.54 running acc average = 0.43
# End of epoch 46: running error average = 1.53 running acc average = 0.43
# End of epoch 47: running error average = 1.51 running acc average = 0.44
# End of epoch 48: running error average = 1.52 running acc average = 0.44
# End of epoch 49: running error average = 1.50 running acc average = 0.44
# End of epoch 50: running error average = 1.49 running acc average = 0.45

# %%
data = Adam_3layers_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')
print(data[1])
print(data[3])
# Out:
# [ 0.23152941  0.28985294  0.3145      0.327       0.33444118  0.34644118
#   0.35647059  0.3507353   0.33061765  0.312       0.29085294  0.26691176
#   0.25391176  0.24305882  0.24538235  0.24714706  0.25682353  0.27135294
#   0.27470588  0.28691176  0.30479412  0.30482353  0.31123529  0.31897059
#   0.32714706  0.33505882  0.3405      0.34452941  0.34635294  0.3532353
#   0.36014706  0.36511765  0.37476471  0.37705882  0.37729412  0.38976471
#   0.39064706  0.39670588  0.39467647  0.40176471  0.40932353  0.41105882
#   0.41635294  0.42061765  0.42726471  0.42779412  0.43805882  0.43811765
#   0.44341176  0.44623529]
# [ 0.25216667  0.2625      0.2565      0.2555      0.25        0.23933333
#   0.234       0.23466667  0.219       0.19066667  0.208       0.21383333
#   0.2095      0.20183333  0.20983333  0.22216667  0.23066667  0.25316667
#   0.25983333  0.25166667  0.27766667  0.26716667  0.27033333  0.2855
#   0.28683333  0.2835      0.292       0.27983333  0.311       0.31483333
#   0.3015      0.31216667  0.308       0.3115      0.326       0.32066667
#   0.3295      0.32416667  0.32316667  0.33133333  0.32283333  0.32783333
#   0.32666667  0.33483333  0.31966667  0.32483334  0.32533333  0.33183333
#   0.3315      0.3445    ]

# %%
n_hidden_1 = 100
n_hidden_2 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_100_L2 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 2996.79 running acc average = 0.23
# End of epoch 2: running error average = 2189.24 running acc average = 0.28
# End of epoch 3: running error average = 1866.64 running acc average = 0.30
# End of epoch 4: running error average = 1651.82 running acc average = 0.31
# End of epoch 5: running error average = 1485.00 running acc average = 0.30
# End of epoch 6: running error average = 1334.64 running acc average = 0.27
# End of epoch 7: running error average = 1206.27 running acc average = 0.21
# End of epoch 8: running error average = 1087.00 running acc average = 0.18
# End of epoch 9: running error average = 954.87 running acc average = 0.17
# End of epoch 10: running error average = 804.56 running acc average = 0.18
# End of epoch 11: running error average = 639.98 running acc average = 0.18
# End of epoch 12: running error average = 471.52 running acc average = 0.18
# End of epoch 13: running error average = 315.65 running acc average = 0.21
# End of epoch 14: running error average = 189.46 running acc average = 0.25
# End of epoch 15: running error average = 102.83 running acc average = 0.28
# End of epoch 16: running error average = 52.71 running acc average = 0.31
# End of epoch 17: running error average = 27.17 running acc average = 0.37
# End of epoch 18: running error average = 14.66 running acc average = 0.44
# End of epoch 19: running error average = 8.36 running acc average = 0.49
# End of epoch 20: running error average = 5.02 running acc average = 0.54
# End of epoch 21: running error average = 3.21 running acc average = 0.57
# End of epoch 22: running error average = 2.32 running acc average = 0.59
# End of epoch 23: running error average = 1.91 running acc average = 0.61
# End of epoch 24: running error average = 1.75 running acc average = 0.61
# End of epoch 25: running error average = 1.67 running acc average = 0.62
# End of epoch 26: running error average = 1.63 running acc average = 0.62
# End of epoch 27: running error average = 1.61 running acc average = 0.62
# End of epoch 28: running error average = 1.60 running acc average = 0.62
# End of epoch 29: running error average = 1.58 running acc average = 0.63
# End of epoch 30: running error average = 1.57 running acc average = 0.63
# End of epoch 31: running error average = 1.56 running acc average = 0.63
# End of epoch 32: running error average = 1.55 running acc average = 0.64
# End of epoch 33: running error average = 1.53 running acc average = 0.64
# End of epoch 34: running error average = 1.54 running acc average = 0.64
# End of epoch 35: running error average = 1.53 running acc average = 0.64
# End of epoch 36: running error average = 1.52 running acc average = 0.65
# End of epoch 37: running error average = 1.52 running acc average = 0.65
# End of epoch 38: running error average = 1.51 running acc average = 0.66
# End of epoch 39: running error average = 1.50 running acc average = 0.66
# End of epoch 40: running error average = 1.51 running acc average = 0.66
# End of epoch 41: running error average = 1.49 running acc average = 0.66
# End of epoch 42: running error average = 1.49 running acc average = 0.66
# End of epoch 43: running error average = 1.50 running acc average = 0.66
# End of epoch 44: running error average = 1.49 running acc average = 0.67
# End of epoch 45: running error average = 1.49 running acc average = 0.67
# End of epoch 46: running error average = 1.49 running acc average = 0.67
# End of epoch 47: running error average = 1.47 running acc average = 0.67
# End of epoch 48: running error average = 1.47 running acc average = 0.67
# End of epoch 49: running error average = 1.48 running acc average = 0.67
# End of epoch 50: running error average = 1.47 running acc average = 0.67

# %%
data = Adam_3layers_100_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_L2(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_100_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_L2(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_200 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 3133.10 running acc average = 0.25
# End of epoch 2: running error average = 1524.17 running acc average = 0.33
# End of epoch 3: running error average = 993.57 running acc average = 0.37
# End of epoch 4: running error average = 691.27 running acc average = 0.41
# End of epoch 5: running error average = 520.26 running acc average = 0.45
# End of epoch 6: running error average = 376.51 running acc average = 0.50
# End of epoch 7: running error average = 279.39 running acc average = 0.55
# End of epoch 8: running error average = 208.48 running acc average = 0.60
# End of epoch 9: running error average = 151.87 running acc average = 0.65
# End of epoch 10: running error average = 110.26 running acc average = 0.70
# End of epoch 11: running error average = 82.41 running acc average = 0.74
# End of epoch 12: running error average = 57.69 running acc average = 0.78
# End of epoch 13: running error average = 42.14 running acc average = 0.81
# End of epoch 14: running error average = 29.85 running acc average = 0.84
# End of epoch 15: running error average = 20.88 running acc average = 0.87
# End of epoch 16: running error average = 15.81 running acc average = 0.88
# End of epoch 17: running error average = 12.97 running acc average = 0.90
# End of epoch 18: running error average = 9.62 running acc average = 0.91
# End of epoch 19: running error average = 7.62 running acc average = 0.92
# End of epoch 20: running error average = 6.35 running acc average = 0.93
# End of epoch 21: running error average = 4.82 running acc average = 0.94
# End of epoch 22: running error average = 4.29 running acc average = 0.94
# End of epoch 23: running error average = 3.66 running acc average = 0.95
# End of epoch 24: running error average = 3.28 running acc average = 0.95
# End of epoch 25: running error average = 2.88 running acc average = 0.96
# End of epoch 26: running error average = 2.69 running acc average = 0.96
# End of epoch 27: running error average = 2.73 running acc average = 0.96
# End of epoch 28: running error average = 2.65 running acc average = 0.96
# End of epoch 29: running error average = 2.53 running acc average = 0.96
# End of epoch 30: running error average = 2.48 running acc average = 0.96
# End of epoch 31: running error average = 2.15 running acc average = 0.97
# End of epoch 32: running error average = 2.28 running acc average = 0.97
# End of epoch 33: running error average = 1.96 running acc average = 0.97
# End of epoch 34: running error average = 2.06 running acc average = 0.97
# End of epoch 35: running error average = 1.92 running acc average = 0.97
# End of epoch 36: running error average = 1.91 running acc average = 0.97
# End of epoch 37: running error average = 1.76 running acc average = 0.97
# End of epoch 38: running error average = 1.65 running acc average = 0.97
# End of epoch 39: running error average = 1.85 running acc average = 0.97
# End of epoch 40: running error average = 1.60 running acc average = 0.98
# End of epoch 41: running error average = 1.68 running acc average = 0.98
# End of epoch 42: running error average = 1.72 running acc average = 0.98
# End of epoch 43: running error average = 1.61 running acc average = 0.98
# End of epoch 44: running error average = 1.66 running acc average = 0.98
# End of epoch 45: running error average = 1.43 running acc average = 0.98
# End of epoch 46: running error average = 1.39 running acc average = 0.98
# End of epoch 47: running error average = 1.38 running acc average = 0.98
# End of epoch 48: running error average = 1.23 running acc average = 0.98
# End of epoch 49: running error average = 1.37 running acc average = 0.98
# End of epoch 50: running error average = 1.36 running acc average = 0.98

# %%
data = Adam_3layers_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_200_L2 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 6151.28 running acc average = 0.25
# End of epoch 2: running error average = 4624.56 running acc average = 0.33
# End of epoch 3: running error average = 4056.92 running acc average = 0.38
# End of epoch 4: running error average = 3693.67 running acc average = 0.42
# End of epoch 5: running error average = 3433.66 running acc average = 0.47
# End of epoch 6: running error average = 3210.80 running acc average = 0.52
# End of epoch 7: running error average = 3012.62 running acc average = 0.58
# End of epoch 8: running error average = 2839.84 running acc average = 0.62
# End of epoch 9: running error average = 2676.90 running acc average = 0.67
# End of epoch 10: running error average = 2519.55 running acc average = 0.72
# End of epoch 11: running error average = 2364.52 running acc average = 0.76
# End of epoch 12: running error average = 2213.47 running acc average = 0.80
# End of epoch 13: running error average = 2060.03 running acc average = 0.83
# End of epoch 14: running error average = 1905.37 running acc average = 0.86
# End of epoch 15: running error average = 1749.83 running acc average = 0.87
# End of epoch 16: running error average = 1594.77 running acc average = 0.89
# End of epoch 17: running error average = 1441.91 running acc average = 0.90
# End of epoch 18: running error average = 1295.30 running acc average = 0.90
# End of epoch 19: running error average = 1155.69 running acc average = 0.91
# End of epoch 20: running error average = 1024.17 running acc average = 0.92
# End of epoch 21: running error average = 901.88 running acc average = 0.92
# End of epoch 22: running error average = 789.91 running acc average = 0.92
# End of epoch 23: running error average = 688.30 running acc average = 0.92
# End of epoch 24: running error average = 597.50 running acc average = 0.92
# End of epoch 25: running error average = 516.46 running acc average = 0.92
# End of epoch 26: running error average = 444.99 running acc average = 0.92
# End of epoch 27: running error average = 381.85 running acc average = 0.91
# End of epoch 28: running error average = 326.46 running acc average = 0.91
# End of epoch 29: running error average = 277.56 running acc average = 0.91
# End of epoch 30: running error average = 234.60 running acc average = 0.91
# End of epoch 31: running error average = 197.28 running acc average = 0.90
# End of epoch 32: running error average = 164.61 running acc average = 0.90
# End of epoch 33: running error average = 136.67 running acc average = 0.89
# End of epoch 34: running error average = 112.49 running acc average = 0.88
# End of epoch 35: running error average = 91.80 running acc average = 0.87
# End of epoch 36: running error average = 74.07 running acc average = 0.87
# End of epoch 37: running error average = 58.82 running acc average = 0.86
# End of epoch 38: running error average = 45.99 running acc average = 0.85
# End of epoch 39: running error average = 35.29 running acc average = 0.84
# End of epoch 40: running error average = 26.39 running acc average = 0.83
# End of epoch 41: running error average = 19.07 running acc average = 0.82
# End of epoch 42: running error average = 13.32 running acc average = 0.81
# End of epoch 43: running error average = 8.99 running acc average = 0.79
# End of epoch 44: running error average = 5.97 running acc average = 0.79
# End of epoch 45: running error average = 4.14 running acc average = 0.76
# End of epoch 46: running error average = 3.12 running acc average = 0.72
# End of epoch 47: running error average = 2.51 running acc average = 0.70
# End of epoch 48: running error average = 2.18 running acc average = 0.68
# End of epoch 49: running error average = 2.00 running acc average = 0.67
# End of epoch 50: running error average = 1.89 running acc average = 0.66

# %%
data = Adam_3layers_200_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_200_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')
print(data[3])
# Out:
# [ 0.26633333  0.28133333  0.27483333  0.28416667  0.2745      0.27716667
#   0.29116667  0.2945      0.2745      0.28166667  0.295       0.28583333
#   0.28216667  0.2815      0.284       0.285       0.27966667  0.29116667
#   0.29666667  0.27616667  0.293       0.291       0.31        0.28733333
#   0.30033333  0.311       0.30283334  0.2975      0.29266667  0.3095
#   0.3265      0.31033333  0.31883333  0.31        0.3345      0.33516667
#   0.343       0.3305      0.33883333  0.3575      0.35683333  0.354
#   0.37533333  0.3975      0.42916666  0.41583333  0.43766667  0.45666667
#   0.46        0.463     ]

# %%
n_hidden_1 = 300
n_hidden_2 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_300 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 4278.59 running acc average = 0.28
# End of epoch 2: running error average = 2153.17 running acc average = 0.36
# End of epoch 3: running error average = 1425.08 running acc average = 0.42
# End of epoch 4: running error average = 1003.33 running acc average = 0.48
# End of epoch 5: running error average = 728.30 running acc average = 0.54
# End of epoch 6: running error average = 511.84 running acc average = 0.61
# End of epoch 7: running error average = 355.43 running acc average = 0.67
# End of epoch 8: running error average = 248.50 running acc average = 0.73
# End of epoch 9: running error average = 165.57 running acc average = 0.78
# End of epoch 10: running error average = 112.65 running acc average = 0.83
# End of epoch 11: running error average = 78.18 running acc average = 0.86
# End of epoch 12: running error average = 52.04 running acc average = 0.89
# End of epoch 13: running error average = 34.78 running acc average = 0.91
# End of epoch 14: running error average = 25.61 running acc average = 0.92
# End of epoch 15: running error average = 17.80 running acc average = 0.93
# End of epoch 16: running error average = 14.40 running acc average = 0.94
# End of epoch 17: running error average = 12.52 running acc average = 0.95
# End of epoch 18: running error average = 10.75 running acc average = 0.95
# End of epoch 19: running error average = 9.61 running acc average = 0.96
# End of epoch 20: running error average = 8.68 running acc average = 0.96
# End of epoch 21: running error average = 8.32 running acc average = 0.96
# End of epoch 22: running error average = 8.60 running acc average = 0.96
# End of epoch 23: running error average = 7.26 running acc average = 0.96
# End of epoch 24: running error average = 6.74 running acc average = 0.97
# End of epoch 25: running error average = 6.48 running acc average = 0.97
# End of epoch 26: running error average = 6.31 running acc average = 0.97
# End of epoch 27: running error average = 5.81 running acc average = 0.97
# End of epoch 28: running error average = 6.01 running acc average = 0.97
# End of epoch 29: running error average = 5.48 running acc average = 0.97
# End of epoch 30: running error average = 5.56 running acc average = 0.97
# End of epoch 31: running error average = 5.27 running acc average = 0.98
# End of epoch 32: running error average = 5.12 running acc average = 0.98
# End of epoch 33: running error average = 4.24 running acc average = 0.98
# End of epoch 34: running error average = 5.18 running acc average = 0.98
# End of epoch 35: running error average = 5.01 running acc average = 0.98
# End of epoch 36: running error average = 4.29 running acc average = 0.98
# End of epoch 37: running error average = 4.12 running acc average = 0.98
# End of epoch 38: running error average = 4.52 running acc average = 0.98
# End of epoch 39: running error average = 4.16 running acc average = 0.98
# End of epoch 40: running error average = 4.09 running acc average = 0.98
# End of epoch 41: running error average = 3.50 running acc average = 0.98
# End of epoch 42: running error average = 3.98 running acc average = 0.98
# End of epoch 43: running error average = 4.04 running acc average = 0.98
# End of epoch 44: running error average = 4.22 running acc average = 0.98
# End of epoch 45: running error average = 3.51 running acc average = 0.98
# End of epoch 46: running error average = 3.46 running acc average = 0.98
# End of epoch 47: running error average = 3.03 running acc average = 0.99
# End of epoch 48: running error average = 3.27 running acc average = 0.99
# End of epoch 49: running error average = 4.10 running acc average = 0.98
# End of epoch 50: running error average = 3.58 running acc average = 0.98

# %%
data = Adam_3layers_300

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_300

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_300_L2 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 9226.93 running acc average = 0.28
# End of epoch 2: running error average = 7038.13 running acc average = 0.37
# End of epoch 3: running error average = 6226.95 running acc average = 0.43
# End of epoch 4: running error average = 5674.82 running acc average = 0.50
# End of epoch 5: running error average = 5316.39 running acc average = 0.55
# End of epoch 6: running error average = 4987.40 running acc average = 0.62
# End of epoch 7: running error average = 4729.42 running acc average = 0.68
# End of epoch 8: running error average = 4501.52 running acc average = 0.74
# End of epoch 9: running error average = 4290.72 running acc average = 0.79
# End of epoch 10: running error average = 4096.09 running acc average = 0.83
# End of epoch 11: running error average = 3904.67 running acc average = 0.86
# End of epoch 12: running error average = 3711.62 running acc average = 0.89
# End of epoch 13: running error average = 3519.35 running acc average = 0.91
# End of epoch 14: running error average = 3316.80 running acc average = 0.92
# End of epoch 15: running error average = 3111.37 running acc average = 0.93
# End of epoch 16: running error average = 2903.40 running acc average = 0.94
# End of epoch 17: running error average = 2697.93 running acc average = 0.94
# End of epoch 18: running error average = 2497.79 running acc average = 0.94
# End of epoch 19: running error average = 2304.99 running acc average = 0.94
# End of epoch 20: running error average = 2119.19 running acc average = 0.94
# End of epoch 21: running error average = 1942.98 running acc average = 0.95
# End of epoch 22: running error average = 1777.09 running acc average = 0.95
# End of epoch 23: running error average = 1618.94 running acc average = 0.95
# End of epoch 24: running error average = 1472.18 running acc average = 0.95
# End of epoch 25: running error average = 1336.39 running acc average = 0.95
# End of epoch 26: running error average = 1211.69 running acc average = 0.95
# End of epoch 27: running error average = 1096.13 running acc average = 0.95
# End of epoch 28: running error average = 988.46 running acc average = 0.95
# End of epoch 29: running error average = 888.22 running acc average = 0.95
# End of epoch 30: running error average = 796.29 running acc average = 0.94
# End of epoch 31: running error average = 712.99 running acc average = 0.94
# End of epoch 32: running error average = 637.10 running acc average = 0.94
# End of epoch 33: running error average = 567.20 running acc average = 0.94
# End of epoch 34: running error average = 503.65 running acc average = 0.94
# End of epoch 35: running error average = 445.34 running acc average = 0.94
# End of epoch 36: running error average = 392.74 running acc average = 0.94
# End of epoch 37: running error average = 344.77 running acc average = 0.93
# End of epoch 38: running error average = 302.13 running acc average = 0.93
# End of epoch 39: running error average = 263.33 running acc average = 0.93
# End of epoch 40: running error average = 228.73 running acc average = 0.92
# End of epoch 41: running error average = 197.61 running acc average = 0.92
# End of epoch 42: running error average = 169.74 running acc average = 0.91
# End of epoch 43: running error average = 145.31 running acc average = 0.90
# End of epoch 44: running error average = 123.29 running acc average = 0.90
# End of epoch 45: running error average = 103.78 running acc average = 0.90
# End of epoch 46: running error average = 86.50 running acc average = 0.89
# End of epoch 47: running error average = 71.42 running acc average = 0.88
# End of epoch 48: running error average = 58.09 running acc average = 0.87
# End of epoch 49: running error average = 46.56 running acc average = 0.86
# End of epoch 50: running error average = 36.60 running acc average = 0.85

# %%
data = Adam_3layers_300_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2(error))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')

# %%
data = Adam_3layers_300_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2(acc))', fontsize = 14)
plt.tight_layout()
#fig_1.savefig('.pdf')
