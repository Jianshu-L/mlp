# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s16/s1607197/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 300
n_hidden_2 = 300
n_hidden_3 = 300
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 200
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_300_L2_200 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 45944.03 running acc average = 0.27
# End of epoch 2: running error average = 22688.75 running acc average = 0.36
# End of epoch 3: running error average = 15868.69 running acc average = 0.42
# End of epoch 4: running error average = 12198.46 running acc average = 0.50
# End of epoch 5: running error average = 10089.22 running acc average = 0.57
# End of epoch 6: running error average = 8433.77 running acc average = 0.64
# End of epoch 7: running error average = 7364.16 running acc average = 0.71
# End of epoch 8: running error average = 6664.27 running acc average = 0.76
# End of epoch 9: running error average = 6167.77 running acc average = 0.81
# End of epoch 10: running error average = 5820.80 running acc average = 0.85
# End of epoch 11: running error average = 5598.54 running acc average = 0.88
# End of epoch 12: running error average = 5470.77 running acc average = 0.90
# End of epoch 13: running error average = 5352.02 running acc average = 0.91
# End of epoch 14: running error average = 5283.94 running acc average = 0.92
# End of epoch 15: running error average = 5222.40 running acc average = 0.93
# End of epoch 16: running error average = 5166.59 running acc average = 0.94
# End of epoch 17: running error average = 5119.10 running acc average = 0.94
# End of epoch 18: running error average = 5066.01 running acc average = 0.95
# End of epoch 19: running error average = 5022.45 running acc average = 0.95
# End of epoch 20: running error average = 4972.99 running acc average = 0.95
# End of epoch 21: running error average = 4919.38 running acc average = 0.95
# End of epoch 22: running error average = 4875.76 running acc average = 0.95
# End of epoch 23: running error average = 4828.06 running acc average = 0.96
# End of epoch 24: running error average = 4765.42 running acc average = 0.96
# End of epoch 25: running error average = 4720.58 running acc average = 0.96
# End of epoch 26: running error average = 4667.62 running acc average = 0.96
# End of epoch 27: running error average = 4613.66 running acc average = 0.96
# End of epoch 28: running error average = 4559.30 running acc average = 0.97
# End of epoch 29: running error average = 4511.29 running acc average = 0.96
# End of epoch 30: running error average = 4450.48 running acc average = 0.97
# End of epoch 31: running error average = 4404.78 running acc average = 0.97
# End of epoch 32: running error average = 4350.84 running acc average = 0.97
# End of epoch 33: running error average = 4291.65 running acc average = 0.97
# End of epoch 34: running error average = 4236.10 running acc average = 0.97
# End of epoch 35: running error average = 4190.21 running acc average = 0.97
# End of epoch 36: running error average = 4130.46 running acc average = 0.97
# End of epoch 37: running error average = 4071.72 running acc average = 0.97
# End of epoch 38: running error average = 4022.86 running acc average = 0.97
# End of epoch 39: running error average = 3965.49 running acc average = 0.97
# End of epoch 40: running error average = 3912.84 running acc average = 0.97
# End of epoch 41: running error average = 3859.80 running acc average = 0.97
# End of epoch 42: running error average = 3799.16 running acc average = 0.98
# End of epoch 43: running error average = 3746.62 running acc average = 0.97
# End of epoch 44: running error average = 3689.18 running acc average = 0.98
# End of epoch 45: running error average = 3634.68 running acc average = 0.97
# End of epoch 46: running error average = 3588.33 running acc average = 0.97
# End of epoch 47: running error average = 3526.33 running acc average = 0.98
# End of epoch 48: running error average = 3473.32 running acc average = 0.98
# End of epoch 49: running error average = 3425.29 running acc average = 0.97
# End of epoch 50: running error average = 3367.73 running acc average = 0.98
# End of epoch 51: running error average = 3310.05 running acc average = 0.98
# End of epoch 52: running error average = 3263.88 running acc average = 0.98
# End of epoch 53: running error average = 3208.85 running acc average = 0.98
# End of epoch 54: running error average = 3159.42 running acc average = 0.97
# End of epoch 55: running error average = 3107.65 running acc average = 0.98
# End of epoch 56: running error average = 3051.91 running acc average = 0.98
# End of epoch 57: running error average = 3003.15 running acc average = 0.98
# End of epoch 58: running error average = 2948.72 running acc average = 0.98
# End of epoch 59: running error average = 2898.13 running acc average = 0.98
# End of epoch 60: running error average = 2856.85 running acc average = 0.97
# End of epoch 61: running error average = 2804.80 running acc average = 0.98
# End of epoch 62: running error average = 2751.68 running acc average = 0.98
# End of epoch 63: running error average = 2701.29 running acc average = 0.98
# End of epoch 64: running error average = 2658.02 running acc average = 0.98
# End of epoch 65: running error average = 2607.59 running acc average = 0.98
# End of epoch 66: running error average = 2560.50 running acc average = 0.98
# End of epoch 67: running error average = 2516.68 running acc average = 0.98
# End of epoch 68: running error average = 2467.86 running acc average = 0.98
# End of epoch 69: running error average = 2420.34 running acc average = 0.98
# End of epoch 70: running error average = 2375.01 running acc average = 0.98
# End of epoch 71: running error average = 2325.76 running acc average = 0.98
# End of epoch 72: running error average = 2286.06 running acc average = 0.98
# End of epoch 73: running error average = 2240.93 running acc average = 0.98
# End of epoch 74: running error average = 2193.30 running acc average = 0.98
# End of epoch 75: running error average = 2153.72 running acc average = 0.98
# End of epoch 76: running error average = 2109.27 running acc average = 0.98
# End of epoch 77: running error average = 2065.45 running acc average = 0.98
# End of epoch 78: running error average = 2023.46 running acc average = 0.98
# End of epoch 79: running error average = 1985.61 running acc average = 0.97
# End of epoch 80: running error average = 1943.05 running acc average = 0.98
# End of epoch 81: running error average = 1904.50 running acc average = 0.98
# End of epoch 82: running error average = 1864.73 running acc average = 0.97
# End of epoch 83: running error average = 1821.61 running acc average = 0.98
# End of epoch 84: running error average = 1782.89 running acc average = 0.98
# End of epoch 85: running error average = 1742.76 running acc average = 0.98
# End of epoch 86: running error average = 1707.06 running acc average = 0.98
# End of epoch 87: running error average = 1668.78 running acc average = 0.97
# End of epoch 88: running error average = 1630.59 running acc average = 0.98
# End of epoch 89: running error average = 1594.44 running acc average = 0.98
# End of epoch 90: running error average = 1558.51 running acc average = 0.98
# End of epoch 91: running error average = 1522.46 running acc average = 0.98
# End of epoch 92: running error average = 1489.77 running acc average = 0.97
# End of epoch 93: running error average = 1452.38 running acc average = 0.98
# End of epoch 94: running error average = 1417.47 running acc average = 0.98
# End of epoch 95: running error average = 1383.35 running acc average = 0.97
# End of epoch 96: running error average = 1348.74 running acc average = 0.98
# End of epoch 97: running error average = 1318.69 running acc average = 0.97
# End of epoch 98: running error average = 1282.06 running acc average = 0.98
# End of epoch 99: running error average = 1252.15 running acc average = 0.97
# End of epoch 100: running error average = 1221.31 running acc average = 0.97
# End of epoch 101: running error average = 1188.93 running acc average = 0.97
# End of epoch 102: running error average = 1160.05 running acc average = 0.97
# End of epoch 103: running error average = 1130.26 running acc average = 0.97
# End of epoch 104: running error average = 1098.36 running acc average = 0.97
# End of epoch 105: running error average = 1068.53 running acc average = 0.97
# End of epoch 106: running error average = 1042.38 running acc average = 0.97
# End of epoch 107: running error average = 1011.12 running acc average = 0.97
# End of epoch 108: running error average = 984.93 running acc average = 0.97
# End of epoch 109: running error average = 957.89 running acc average = 0.97
# End of epoch 110: running error average = 930.25 running acc average = 0.97
# End of epoch 111: running error average = 901.42 running acc average = 0.97
# End of epoch 112: running error average = 877.39 running acc average = 0.97
# End of epoch 113: running error average = 850.51 running acc average = 0.97
# End of epoch 114: running error average = 823.93 running acc average = 0.97
# End of epoch 115: running error average = 799.51 running acc average = 0.97
# End of epoch 116: running error average = 777.28 running acc average = 0.96
# End of epoch 117: running error average = 751.24 running acc average = 0.97
# End of epoch 118: running error average = 726.56 running acc average = 0.97
# End of epoch 119: running error average = 703.80 running acc average = 0.97
# End of epoch 120: running error average = 681.18 running acc average = 0.97
# End of epoch 121: running error average = 658.11 running acc average = 0.97
# End of epoch 122: running error average = 636.37 running acc average = 0.96
# End of epoch 123: running error average = 613.61 running acc average = 0.96
# End of epoch 124: running error average = 592.30 running acc average = 0.96
# End of epoch 125: running error average = 573.97 running acc average = 0.96
# End of epoch 126: running error average = 551.31 running acc average = 0.96
# End of epoch 127: running error average = 532.65 running acc average = 0.96
# End of epoch 128: running error average = 512.00 running acc average = 0.96
# End of epoch 129: running error average = 491.93 running acc average = 0.96
# End of epoch 130: running error average = 472.43 running acc average = 0.96
# End of epoch 131: running error average = 453.57 running acc average = 0.96
# End of epoch 132: running error average = 435.44 running acc average = 0.96
# End of epoch 133: running error average = 415.01 running acc average = 0.96
# End of epoch 134: running error average = 398.46 running acc average = 0.95
# End of epoch 135: running error average = 380.40 running acc average = 0.95
# End of epoch 136: running error average = 363.87 running acc average = 0.95
# End of epoch 137: running error average = 346.76 running acc average = 0.95
# End of epoch 138: running error average = 329.86 running acc average = 0.95
# End of epoch 139: running error average = 313.96 running acc average = 0.95
# End of epoch 140: running error average = 299.73 running acc average = 0.94
# End of epoch 141: running error average = 283.93 running acc average = 0.94
# End of epoch 142: running error average = 268.00 running acc average = 0.95
# End of epoch 143: running error average = 252.57 running acc average = 0.95
# End of epoch 144: running error average = 238.27 running acc average = 0.94
# End of epoch 145: running error average = 224.21 running acc average = 0.93
# End of epoch 146: running error average = 210.04 running acc average = 0.93
# End of epoch 147: running error average = 196.15 running acc average = 0.93
# End of epoch 148: running error average = 183.18 running acc average = 0.93
# End of epoch 149: running error average = 170.46 running acc average = 0.92
# End of epoch 150: running error average = 157.22 running acc average = 0.92
# End of epoch 151: running error average = 144.39 running acc average = 0.92
# End of epoch 152: running error average = 132.57 running acc average = 0.91
# End of epoch 153: running error average = 120.72 running acc average = 0.91
# End of epoch 154: running error average = 109.09 running acc average = 0.91
# End of epoch 155: running error average = 98.11 running acc average = 0.90
# End of epoch 156: running error average = 87.23 running acc average = 0.89
# End of epoch 157: running error average = 76.74 running acc average = 0.88
# End of epoch 158: running error average = 66.57 running acc average = 0.88
# End of epoch 159: running error average = 56.75 running acc average = 0.88
# End of epoch 160: running error average = 47.51 running acc average = 0.86
# End of epoch 161: running error average = 38.47 running acc average = 0.86
# End of epoch 162: running error average = 30.21 running acc average = 0.85
# End of epoch 163: running error average = 22.57 running acc average = 0.84
# End of epoch 164: running error average = 15.97 running acc average = 0.84
# End of epoch 165: running error average = 10.74 running acc average = 0.83
# End of epoch 166: running error average = 7.14 running acc average = 0.79
# End of epoch 167: running error average = 4.90 running acc average = 0.74
# End of epoch 168: running error average = 3.55 running acc average = 0.71
# End of epoch 169: running error average = 2.75 running acc average = 0.69
# End of epoch 170: running error average = 2.33 running acc average = 0.67
# End of epoch 171: running error average = 2.09 running acc average = 0.66
# End of epoch 172: running error average = 1.95 running acc average = 0.65
# End of epoch 173: running error average = 1.85 running acc average = 0.65
# End of epoch 174: running error average = 1.82 running acc average = 0.64
# End of epoch 175: running error average = 1.77 running acc average = 0.64
# End of epoch 176: running error average = 1.74 running acc average = 0.64
# End of epoch 177: running error average = 1.69 running acc average = 0.65
# End of epoch 178: running error average = 1.67 running acc average = 0.65
# End of epoch 179: running error average = 1.65 running acc average = 0.66
# End of epoch 180: running error average = 1.64 running acc average = 0.65
# End of epoch 181: running error average = 1.62 running acc average = 0.66
# End of epoch 182: running error average = 1.61 running acc average = 0.66
# End of epoch 183: running error average = 1.59 running acc average = 0.67
# End of epoch 184: running error average = 1.59 running acc average = 0.67
# End of epoch 185: running error average = 1.58 running acc average = 0.68
# End of epoch 186: running error average = 1.57 running acc average = 0.68
# End of epoch 187: running error average = 1.56 running acc average = 0.68
# End of epoch 188: running error average = 1.56 running acc average = 0.68
# End of epoch 189: running error average = 1.56 running acc average = 0.68
# End of epoch 190: running error average = 1.55 running acc average = 0.69
# End of epoch 191: running error average = 1.55 running acc average = 0.68
# End of epoch 192: running error average = 1.56 running acc average = 0.68
# End of epoch 193: running error average = 1.54 running acc average = 0.69
# End of epoch 194: running error average = 1.54 running acc average = 0.69
# End of epoch 195: running error average = 1.53 running acc average = 0.69
# End of epoch 196: running error average = 1.53 running acc average = 0.69
# End of epoch 197: running error average = 1.54 running acc average = 0.69
# End of epoch 198: running error average = 1.52 running acc average = 0.69
# End of epoch 199: running error average = 1.52 running acc average = 0.69
# End of epoch 200: running error average = 1.53 running acc average = 0.69

# %%
data = Adam_4layers_300_L2_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_200(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_200(error).pdf')

# %%
data = Adam_4layers_300_L2_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_200(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_200(acc).pdf')

# %%
np.save('Adam_4layers_100', Adam_4layers_100)
np.save('Adam_4layers_100_L2', Adam_4layers_100_L2)
np.save('Adam_4layers_200', Adam_4layers_200)
np.save('Adam_4layers_200_L2', Adam_4layers_200_L2)
np.save('Adam_4layers_300', Adam_4layers_300)
np.save('Adam_4layers_300_L2', Adam_4layers_300_L2)

# %%
np.save('Adam_4layers_300_L2_200', Adam_4layers_300_L2_200)
