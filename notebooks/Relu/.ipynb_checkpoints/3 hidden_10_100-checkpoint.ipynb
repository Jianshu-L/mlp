# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s16/s1607197/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
n_hidden_2 = 100
n_hidden_3 = 100
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 8602.73 running acc average = 0.21
# End of epoch 2: running error average = 3452.50 running acc average = 0.26
# End of epoch 3: running error average = 2085.35 running acc average = 0.28
# End of epoch 4: running error average = 1361.54 running acc average = 0.29
# End of epoch 5: running error average = 890.80 running acc average = 0.30
# End of epoch 6: running error average = 568.39 running acc average = 0.28
# End of epoch 7: running error average = 263.95 running acc average = 0.23
# End of epoch 8: running error average = 35.64 running acc average = 0.14
# End of epoch 9: running error average = 9.62 running acc average = 0.12
# End of epoch 10: running error average = 4.78 running acc average = 0.12
# End of epoch 11: running error average = 3.52 running acc average = 0.11
# End of epoch 12: running error average = 2.80 running acc average = 0.12
# End of epoch 13: running error average = 2.53 running acc average = 0.11
# End of epoch 14: running error average = 2.43 running acc average = 0.12
# End of epoch 15: running error average = 2.38 running acc average = 0.12
# End of epoch 16: running error average = 2.33 running acc average = 0.11
# End of epoch 17: running error average = 2.33 running acc average = 0.11
# End of epoch 18: running error average = 2.32 running acc average = 0.11
# End of epoch 19: running error average = 2.30 running acc average = 0.11
# End of epoch 20: running error average = 2.30 running acc average = 0.11
# End of epoch 21: running error average = 2.30 running acc average = 0.10
# End of epoch 22: running error average = 2.34 running acc average = 0.11
# End of epoch 23: running error average = 2.32 running acc average = 0.10
# End of epoch 24: running error average = 2.37 running acc average = 0.11
# End of epoch 25: running error average = 2.55 running acc average = 0.10
# End of epoch 26: running error average = 2.37 running acc average = 0.10
# End of epoch 27: running error average = 2.32 running acc average = 0.11
# End of epoch 28: running error average = 2.30 running acc average = 0.10
# End of epoch 29: running error average = 2.30 running acc average = 0.11
# End of epoch 30: running error average = 2.31 running acc average = 0.11
# End of epoch 31: running error average = 2.30 running acc average = 0.10
# End of epoch 32: running error average = 2.30 running acc average = 0.10
# End of epoch 33: running error average = 2.30 running acc average = 0.10
# End of epoch 34: running error average = 2.30 running acc average = 0.10
# End of epoch 35: running error average = 2.30 running acc average = 0.10
# End of epoch 36: running error average = 2.31 running acc average = 0.10
# End of epoch 37: running error average = 2.30 running acc average = 0.10
# End of epoch 38: running error average = 2.30 running acc average = 0.11
# End of epoch 39: running error average = 2.32 running acc average = 0.10
# End of epoch 40: running error average = 2.31 running acc average = 0.11
# End of epoch 41: running error average = 2.30 running acc average = 0.10
# End of epoch 42: running error average = 2.30 running acc average = 0.10
# End of epoch 43: running error average = 2.30 running acc average = 0.10
# End of epoch 44: running error average = 2.30 running acc average = 0.10
# End of epoch 45: running error average = 2.31 running acc average = 0.10
# End of epoch 46: running error average = 2.30 running acc average = 0.10
# End of epoch 47: running error average = 2.30 running acc average = 0.10
# End of epoch 48: running error average = 2.30 running acc average = 0.10
# End of epoch 49: running error average = 2.30 running acc average = 0.10
# End of epoch 50: running error average = 2.30 running acc average = 0.10

# %%
data = Adam_4layers_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100(error).pdf')

# %%
data = Adam_4layers_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100(acc).pdf')

# %%
n_hidden_1 = 100
n_hidden_2 = 100
n_hidden_3 = 100
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_100_L2 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 9607.96 running acc average = 0.20
# End of epoch 2: running error average = 4650.85 running acc average = 0.25
# End of epoch 3: running error average = 3307.36 running acc average = 0.27
# End of epoch 4: running error average = 2647.65 running acc average = 0.28
# End of epoch 5: running error average = 2265.72 running acc average = 0.28
# End of epoch 6: running error average = 1998.03 running acc average = 0.29
# End of epoch 7: running error average = 1810.56 running acc average = 0.30
# End of epoch 8: running error average = 1680.36 running acc average = 0.29
# End of epoch 9: running error average = 1568.91 running acc average = 0.29
# End of epoch 10: running error average = 1468.93 running acc average = 0.28
# End of epoch 11: running error average = 1371.29 running acc average = 0.24
# End of epoch 12: running error average = 1275.23 running acc average = 0.20
# End of epoch 13: running error average = 1179.35 running acc average = 0.19
# End of epoch 14: running error average = 1064.07 running acc average = 0.19
# End of epoch 15: running error average = 925.24 running acc average = 0.20
# End of epoch 16: running error average = 764.80 running acc average = 0.20
# End of epoch 17: running error average = 591.85 running acc average = 0.22
# End of epoch 18: running error average = 421.83 running acc average = 0.23
# End of epoch 19: running error average = 274.28 running acc average = 0.25
# End of epoch 20: running error average = 162.89 running acc average = 0.28
# End of epoch 21: running error average = 90.32 running acc average = 0.31
# End of epoch 22: running error average = 48.89 running acc average = 0.37
# End of epoch 23: running error average = 27.22 running acc average = 0.43
# End of epoch 24: running error average = 16.17 running acc average = 0.51
# End of epoch 25: running error average = 10.27 running acc average = 0.56
# End of epoch 26: running error average = 6.86 running acc average = 0.58
# End of epoch 27: running error average = 4.82 running acc average = 0.58
# End of epoch 28: running error average = 3.65 running acc average = 0.59
# End of epoch 29: running error average = 3.01 running acc average = 0.59
# End of epoch 30: running error average = 2.64 running acc average = 0.60
# End of epoch 31: running error average = 2.41 running acc average = 0.60
# End of epoch 32: running error average = 2.25 running acc average = 0.61
# End of epoch 33: running error average = 2.11 running acc average = 0.61
# End of epoch 34: running error average = 2.02 running acc average = 0.62
# End of epoch 35: running error average = 1.94 running acc average = 0.62
# End of epoch 36: running error average = 1.86 running acc average = 0.63
# End of epoch 37: running error average = 1.81 running acc average = 0.64
# End of epoch 38: running error average = 1.76 running acc average = 0.65
# End of epoch 39: running error average = 1.73 running acc average = 0.65
# End of epoch 40: running error average = 1.71 running acc average = 0.65
# End of epoch 41: running error average = 1.68 running acc average = 0.65
# End of epoch 42: running error average = 1.66 running acc average = 0.66
# End of epoch 43: running error average = 1.65 running acc average = 0.65
# End of epoch 44: running error average = 1.63 running acc average = 0.66
# End of epoch 45: running error average = 1.62 running acc average = 0.66
# End of epoch 46: running error average = 1.60 running acc average = 0.66
# End of epoch 47: running error average = 1.58 running acc average = 0.67
# End of epoch 48: running error average = 1.58 running acc average = 0.67
# End of epoch 49: running error average = 1.58 running acc average = 0.67
# End of epoch 50: running error average = 1.56 running acc average = 0.67

# %%
data = Adam_4layers_100_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_L2(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_L2(error).pdf')

# %%
data = Adam_4layers_100_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_100_L2(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_100_L2(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
n_hidden_3 = 200
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_200 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 23501.06 running acc average = 0.24
# End of epoch 2: running error average = 9805.41 running acc average = 0.31
# End of epoch 3: running error average = 6157.24 running acc average = 0.36
# End of epoch 4: running error average = 4163.78 running acc average = 0.41
# End of epoch 5: running error average = 3029.27 running acc average = 0.47
# End of epoch 6: running error average = 2185.49 running acc average = 0.52
# End of epoch 7: running error average = 1547.14 running acc average = 0.59
# End of epoch 8: running error average = 1129.60 running acc average = 0.64
# End of epoch 9: running error average = 800.08 running acc average = 0.69
# End of epoch 10: running error average = 596.60 running acc average = 0.74
# End of epoch 11: running error average = 428.68 running acc average = 0.77
# End of epoch 12: running error average = 308.54 running acc average = 0.81
# End of epoch 13: running error average = 225.66 running acc average = 0.84
# End of epoch 14: running error average = 168.00 running acc average = 0.87
# End of epoch 15: running error average = 129.30 running acc average = 0.88
# End of epoch 16: running error average = 99.41 running acc average = 0.90
# End of epoch 17: running error average = 83.09 running acc average = 0.90
# End of epoch 18: running error average = 70.44 running acc average = 0.92
# End of epoch 19: running error average = 61.48 running acc average = 0.92
# End of epoch 20: running error average = 52.19 running acc average = 0.93
# End of epoch 21: running error average = 47.79 running acc average = 0.93
# End of epoch 22: running error average = 44.02 running acc average = 0.94
# End of epoch 23: running error average = 41.93 running acc average = 0.94
# End of epoch 24: running error average = 40.92 running acc average = 0.94
# End of epoch 25: running error average = 36.33 running acc average = 0.95
# End of epoch 26: running error average = 33.95 running acc average = 0.95
# End of epoch 27: running error average = 34.14 running acc average = 0.95
# End of epoch 28: running error average = 32.09 running acc average = 0.95
# End of epoch 29: running error average = 31.11 running acc average = 0.96
# End of epoch 30: running error average = 28.36 running acc average = 0.96
# End of epoch 31: running error average = 28.43 running acc average = 0.96
# End of epoch 32: running error average = 27.42 running acc average = 0.96
# End of epoch 33: running error average = 24.85 running acc average = 0.96
# End of epoch 34: running error average = 23.45 running acc average = 0.97
# End of epoch 35: running error average = 26.53 running acc average = 0.96
# End of epoch 36: running error average = 25.59 running acc average = 0.96
# End of epoch 37: running error average = 22.47 running acc average = 0.97
# End of epoch 38: running error average = 22.08 running acc average = 0.97
# End of epoch 39: running error average = 22.65 running acc average = 0.97
# End of epoch 40: running error average = 19.45 running acc average = 0.97
# End of epoch 41: running error average = 20.50 running acc average = 0.97
# End of epoch 42: running error average = 21.68 running acc average = 0.97
# End of epoch 43: running error average = 20.31 running acc average = 0.97
# End of epoch 44: running error average = 20.00 running acc average = 0.97
# End of epoch 45: running error average = 18.13 running acc average = 0.97
# End of epoch 46: running error average = 19.01 running acc average = 0.97
# End of epoch 47: running error average = 18.39 running acc average = 0.97
# End of epoch 48: running error average = 18.14 running acc average = 0.97
# End of epoch 49: running error average = 18.74 running acc average = 0.97
# End of epoch 50: running error average = 16.79 running acc average = 0.98

# %%
data = Adam_4layers_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200(error).pdf')

# %%
data = Adam_4layers_200

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
n_hidden_3 = 200
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_200_L2 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 26215.03 running acc average = 0.24
# End of epoch 2: running error average = 13471.06 running acc average = 0.31
# End of epoch 3: running error average = 9739.86 running acc average = 0.36
# End of epoch 4: running error average = 7654.67 running acc average = 0.41
# End of epoch 5: running error average = 6433.40 running acc average = 0.46
# End of epoch 6: running error average = 5550.89 running acc average = 0.52
# End of epoch 7: running error average = 4909.68 running acc average = 0.59
# End of epoch 8: running error average = 4442.11 running acc average = 0.64
# End of epoch 9: running error average = 4084.34 running acc average = 0.69
# End of epoch 10: running error average = 3822.50 running acc average = 0.74
# End of epoch 11: running error average = 3648.53 running acc average = 0.78
# End of epoch 12: running error average = 3507.78 running acc average = 0.81
# End of epoch 13: running error average = 3389.66 running acc average = 0.84
# End of epoch 14: running error average = 3300.24 running acc average = 0.86
# End of epoch 15: running error average = 3226.60 running acc average = 0.88
# End of epoch 16: running error average = 3163.37 running acc average = 0.89
# End of epoch 17: running error average = 3108.10 running acc average = 0.91
# End of epoch 18: running error average = 3051.29 running acc average = 0.92
# End of epoch 19: running error average = 2998.29 running acc average = 0.92
# End of epoch 20: running error average = 2949.82 running acc average = 0.93
# End of epoch 21: running error average = 2895.71 running acc average = 0.93
# End of epoch 22: running error average = 2843.34 running acc average = 0.94
# End of epoch 23: running error average = 2791.81 running acc average = 0.94
# End of epoch 24: running error average = 2738.43 running acc average = 0.94
# End of epoch 25: running error average = 2686.33 running acc average = 0.95
# End of epoch 26: running error average = 2632.63 running acc average = 0.95
# End of epoch 27: running error average = 2578.13 running acc average = 0.95
# End of epoch 28: running error average = 2522.92 running acc average = 0.95
# End of epoch 29: running error average = 2473.77 running acc average = 0.95
# End of epoch 30: running error average = 2418.54 running acc average = 0.95
# End of epoch 31: running error average = 2364.29 running acc average = 0.95
# End of epoch 32: running error average = 2311.33 running acc average = 0.96
# End of epoch 33: running error average = 2256.17 running acc average = 0.96
# End of epoch 34: running error average = 2204.81 running acc average = 0.95
# End of epoch 35: running error average = 2151.53 running acc average = 0.96
# End of epoch 36: running error average = 2098.21 running acc average = 0.96
# End of epoch 37: running error average = 2047.74 running acc average = 0.96
# End of epoch 38: running error average = 1996.11 running acc average = 0.96
# End of epoch 39: running error average = 1944.62 running acc average = 0.96
# End of epoch 40: running error average = 1893.84 running acc average = 0.96
# End of epoch 41: running error average = 1843.85 running acc average = 0.96
# End of epoch 42: running error average = 1794.74 running acc average = 0.96
# End of epoch 43: running error average = 1744.46 running acc average = 0.96
# End of epoch 44: running error average = 1697.98 running acc average = 0.96
# End of epoch 45: running error average = 1650.77 running acc average = 0.96
# End of epoch 46: running error average = 1602.04 running acc average = 0.96
# End of epoch 47: running error average = 1555.86 running acc average = 0.96
# End of epoch 48: running error average = 1511.38 running acc average = 0.96
# End of epoch 49: running error average = 1468.04 running acc average = 0.96
# End of epoch 50: running error average = 1422.50 running acc average = 0.96

# %%
data = Adam_4layers_200_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2(error).pdf')

# %%
data = Adam_4layers_200_L2

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_200_L2(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_200_L2(acc).pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
n_hidden_3 = 300
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_300 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 41472.66 running acc average = 0.26
# End of epoch 2: running error average = 17938.31 running acc average = 0.35
# End of epoch 3: running error average = 11090.62 running acc average = 0.43
# End of epoch 4: running error average = 7200.20 running acc average = 0.50
# End of epoch 5: running error average = 4909.45 running acc average = 0.58
# End of epoch 6: running error average = 3333.24 running acc average = 0.65
# End of epoch 7: running error average = 2210.87 running acc average = 0.72
# End of epoch 8: running error average = 1502.41 running acc average = 0.77
# End of epoch 9: running error average = 986.68 running acc average = 0.82
# End of epoch 10: running error average = 664.19 running acc average = 0.85
# End of epoch 11: running error average = 440.43 running acc average = 0.88
# End of epoch 12: running error average = 317.34 running acc average = 0.90
# End of epoch 13: running error average = 238.36 running acc average = 0.92
# End of epoch 14: running error average = 204.17 running acc average = 0.92
# End of epoch 15: running error average = 162.58 running acc average = 0.93
# End of epoch 16: running error average = 145.23 running acc average = 0.94
# End of epoch 17: running error average = 137.73 running acc average = 0.94
# End of epoch 18: running error average = 125.69 running acc average = 0.94
# End of epoch 19: running error average = 110.08 running acc average = 0.95
# End of epoch 20: running error average = 105.17 running acc average = 0.95
# End of epoch 21: running error average = 107.37 running acc average = 0.95
# End of epoch 22: running error average = 89.76 running acc average = 0.96
# End of epoch 23: running error average = 82.65 running acc average = 0.96
# End of epoch 24: running error average = 88.49 running acc average = 0.96
# End of epoch 25: running error average = 84.44 running acc average = 0.96
# End of epoch 26: running error average = 76.21 running acc average = 0.97
# End of epoch 27: running error average = 71.58 running acc average = 0.97
# End of epoch 28: running error average = 78.47 running acc average = 0.96
# End of epoch 29: running error average = 67.94 running acc average = 0.97
# End of epoch 30: running error average = 67.54 running acc average = 0.97
# End of epoch 31: running error average = 63.17 running acc average = 0.97
# End of epoch 32: running error average = 63.32 running acc average = 0.97
# End of epoch 33: running error average = 70.83 running acc average = 0.97
# End of epoch 34: running error average = 64.10 running acc average = 0.97
# End of epoch 35: running error average = 53.28 running acc average = 0.97
# End of epoch 36: running error average = 56.65 running acc average = 0.97
# End of epoch 37: running error average = 64.33 running acc average = 0.97
# End of epoch 38: running error average = 61.84 running acc average = 0.97
# End of epoch 39: running error average = 50.88 running acc average = 0.98
# End of epoch 40: running error average = 50.71 running acc average = 0.98
# End of epoch 41: running error average = 50.50 running acc average = 0.98
# End of epoch 42: running error average = 56.29 running acc average = 0.98
# End of epoch 43: running error average = 53.35 running acc average = 0.98
# End of epoch 44: running error average = 43.38 running acc average = 0.98
# End of epoch 45: running error average = 39.91 running acc average = 0.98
# End of epoch 46: running error average = 52.66 running acc average = 0.98
# End of epoch 47: running error average = 49.52 running acc average = 0.98
# End of epoch 48: running error average = 38.40 running acc average = 0.98
# End of epoch 49: running error average = 44.42 running acc average = 0.98
# End of epoch 50: running error average = 44.62 running acc average = 0.98

# %%
data = Adam_4layers_300

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300(error).pdf')

# %%
data = Adam_4layers_300

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300(acc).pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
n_hidden_3 = 300
beta = 0.01

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'out': tf.Variable(tf.random_normal([n_hidden_3, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.relu(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.relu(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    layer_3 = tf.nn.relu(tf.matmul(layer_2, weights['h3']) + biases['b3'])
    out_layer = tf.matmul(layer_3, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1']) + tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['h3'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_4layers_300_L2_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 43780.15 running acc average = 0.27
# End of epoch 2: running error average = 21787.17 running acc average = 0.36
# End of epoch 3: running error average = 15530.04 running acc average = 0.43
# End of epoch 4: running error average = 12075.13 running acc average = 0.50
# End of epoch 5: running error average = 9904.44 running acc average = 0.57
# End of epoch 6: running error average = 8353.77 running acc average = 0.65
# End of epoch 7: running error average = 7350.07 running acc average = 0.72
# End of epoch 8: running error average = 6677.06 running acc average = 0.77
# End of epoch 9: running error average = 6134.61 running acc average = 0.82
# End of epoch 10: running error average = 5847.34 running acc average = 0.85
# End of epoch 11: running error average = 5630.81 running acc average = 0.88
# End of epoch 12: running error average = 5444.05 running acc average = 0.90
# End of epoch 13: running error average = 5368.51 running acc average = 0.91
# End of epoch 14: running error average = 5299.67 running acc average = 0.92
# End of epoch 15: running error average = 5237.05 running acc average = 0.93
# End of epoch 16: running error average = 5170.62 running acc average = 0.94
# End of epoch 17: running error average = 5141.83 running acc average = 0.94
# End of epoch 18: running error average = 5092.41 running acc average = 0.94
# End of epoch 19: running error average = 5028.71 running acc average = 0.95
# End of epoch 20: running error average = 4977.34 running acc average = 0.95
# End of epoch 21: running error average = 4931.12 running acc average = 0.95
# End of epoch 22: running error average = 4877.89 running acc average = 0.96
# End of epoch 23: running error average = 4828.63 running acc average = 0.96
# End of epoch 24: running error average = 4776.08 running acc average = 0.96
# End of epoch 25: running error average = 4727.36 running acc average = 0.96
# End of epoch 26: running error average = 4672.30 running acc average = 0.96
# End of epoch 27: running error average = 4624.04 running acc average = 0.96
# End of epoch 28: running error average = 4572.39 running acc average = 0.96
# End of epoch 29: running error average = 4518.45 running acc average = 0.97
# End of epoch 30: running error average = 4464.88 running acc average = 0.97
# End of epoch 31: running error average = 4410.33 running acc average = 0.97
# End of epoch 32: running error average = 4360.64 running acc average = 0.97
# End of epoch 33: running error average = 4305.56 running acc average = 0.97
# End of epoch 34: running error average = 4249.02 running acc average = 0.97
# End of epoch 35: running error average = 4187.75 running acc average = 0.97
# End of epoch 36: running error average = 4135.85 running acc average = 0.97
# End of epoch 37: running error average = 4081.07 running acc average = 0.97
# End of epoch 38: running error average = 4031.42 running acc average = 0.97
# End of epoch 39: running error average = 3970.08 running acc average = 0.97
# End of epoch 40: running error average = 3914.69 running acc average = 0.97
# End of epoch 41: running error average = 3861.52 running acc average = 0.97
# End of epoch 42: running error average = 3809.25 running acc average = 0.97
# End of epoch 43: running error average = 3754.45 running acc average = 0.97
# End of epoch 44: running error average = 3697.68 running acc average = 0.97
# End of epoch 45: running error average = 3643.67 running acc average = 0.98
# End of epoch 46: running error average = 3589.66 running acc average = 0.97
# End of epoch 47: running error average = 3538.55 running acc average = 0.98
# End of epoch 48: running error average = 3483.02 running acc average = 0.97
# End of epoch 49: running error average = 3433.29 running acc average = 0.98
# End of epoch 50: running error average = 3380.74 running acc average = 0.98
# End of epoch 51: running error average = 3326.80 running acc average = 0.98
# End of epoch 52: running error average = 3270.57 running acc average = 0.98
# End of epoch 53: running error average = 3222.85 running acc average = 0.98
# End of epoch 54: running error average = 3171.67 running acc average = 0.98
# End of epoch 55: running error average = 3121.74 running acc average = 0.97
# End of epoch 56: running error average = 3066.82 running acc average = 0.98
# End of epoch 57: running error average = 3019.12 running acc average = 0.98
# End of epoch 58: running error average = 2965.13 running acc average = 0.98
# End of epoch 59: running error average = 2915.70 running acc average = 0.98
# End of epoch 60: running error average = 2867.78 running acc average = 0.98
# End of epoch 61: running error average = 2818.02 running acc average = 0.98
# End of epoch 62: running error average = 2767.25 running acc average = 0.98
# End of epoch 63: running error average = 2721.70 running acc average = 0.98
# End of epoch 64: running error average = 2672.39 running acc average = 0.98
# End of epoch 65: running error average = 2624.53 running acc average = 0.98
# End of epoch 66: running error average = 2570.56 running acc average = 0.98
# End of epoch 67: running error average = 2532.50 running acc average = 0.98
# End of epoch 68: running error average = 2481.56 running acc average = 0.98
# End of epoch 69: running error average = 2433.10 running acc average = 0.98
# End of epoch 70: running error average = 2389.62 running acc average = 0.98
# End of epoch 71: running error average = 2343.36 running acc average = 0.98
# End of epoch 72: running error average = 2300.84 running acc average = 0.98
# End of epoch 73: running error average = 2255.55 running acc average = 0.98
# End of epoch 74: running error average = 2211.94 running acc average = 0.98
# End of epoch 75: running error average = 2165.30 running acc average = 0.98
# End of epoch 76: running error average = 2121.13 running acc average = 0.98
# End of epoch 77: running error average = 2081.39 running acc average = 0.98
# End of epoch 78: running error average = 2038.80 running acc average = 0.98
# End of epoch 79: running error average = 1996.96 running acc average = 0.98
# End of epoch 80: running error average = 1956.58 running acc average = 0.98
# End of epoch 81: running error average = 1914.52 running acc average = 0.98
# End of epoch 82: running error average = 1877.31 running acc average = 0.98
# End of epoch 83: running error average = 1837.30 running acc average = 0.98
# End of epoch 84: running error average = 1798.05 running acc average = 0.98
# End of epoch 85: running error average = 1760.50 running acc average = 0.98
# End of epoch 86: running error average = 1724.98 running acc average = 0.97
# End of epoch 87: running error average = 1682.51 running acc average = 0.98
# End of epoch 88: running error average = 1642.88 running acc average = 0.98
# End of epoch 89: running error average = 1606.17 running acc average = 0.98
# End of epoch 90: running error average = 1571.99 running acc average = 0.97
# End of epoch 91: running error average = 1535.89 running acc average = 0.97
# End of epoch 92: running error average = 1501.67 running acc average = 0.97
# End of epoch 93: running error average = 1467.25 running acc average = 0.97
# End of epoch 94: running error average = 1430.26 running acc average = 0.98
# End of epoch 95: running error average = 1396.86 running acc average = 0.98
# End of epoch 96: running error average = 1363.83 running acc average = 0.98
# End of epoch 97: running error average = 1330.81 running acc average = 0.97
# End of epoch 98: running error average = 1299.77 running acc average = 0.97
# End of epoch 99: running error average = 1265.25 running acc average = 0.98
# End of epoch 100: running error average = 1235.86 running acc average = 0.97

# %%
data = Adam_4layers_300_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_100(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_100(error).pdf')

# %%
data = Adam_4layers_300_L2_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_4layers_300_L2_100(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_4layers_300_L2_100(acc).pdf')

# %%
np.save('Adam_4layers_100', Adam_4layers_100)
np.save('Adam_4layers_100_L2', Adam_4layers_100_L2)
np.save('Adam_4layers_200', Adam_4layers_200)
np.save('Adam_4layers_200_L2', Adam_4layers_200_L2)
np.save('Adam_4layers_300', Adam_4layers_300)
np.save('Adam_4layers_300_L2', Adam_4layers_300_L2)

# %%
np.save('Adam_4layers_300_L2_100', Adam_4layers_300_L2_100)
