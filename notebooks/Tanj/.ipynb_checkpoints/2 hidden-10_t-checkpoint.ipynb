# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
n_hidden_2 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_100_t = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 10.59 running acc average = 0.16
# End of epoch 2: running error average = 6.59 running acc average = 0.22
# End of epoch 3: running error average = 4.75 running acc average = 0.26
# End of epoch 4: running error average = 3.69 running acc average = 0.30
# End of epoch 5: running error average = 3.01 running acc average = 0.33
# End of epoch 6: running error average = 2.51 running acc average = 0.36
# End of epoch 7: running error average = 2.16 running acc average = 0.39
# End of epoch 8: running error average = 1.95 running acc average = 0.41
# End of epoch 9: running error average = 1.77 running acc average = 0.44
# End of epoch 10: running error average = 1.65 running acc average = 0.47
# End of epoch 11: running error average = 1.58 running acc average = 0.48
# End of epoch 12: running error average = 1.54 running acc average = 0.49
# End of epoch 13: running error average = 1.48 running acc average = 0.50
# End of epoch 14: running error average = 1.44 running acc average = 0.52
# End of epoch 15: running error average = 1.42 running acc average = 0.52
# End of epoch 16: running error average = 1.40 running acc average = 0.53
# End of epoch 17: running error average = 1.37 running acc average = 0.54
# End of epoch 18: running error average = 1.34 running acc average = 0.55
# End of epoch 19: running error average = 1.31 running acc average = 0.56
# End of epoch 20: running error average = 1.29 running acc average = 0.57
# End of epoch 21: running error average = 1.26 running acc average = 0.58
# End of epoch 22: running error average = 1.24 running acc average = 0.59
# End of epoch 23: running error average = 1.22 running acc average = 0.60
# End of epoch 24: running error average = 1.20 running acc average = 0.61
# End of epoch 25: running error average = 1.17 running acc average = 0.61
# End of epoch 26: running error average = 1.16 running acc average = 0.62
# End of epoch 27: running error average = 1.14 running acc average = 0.62
# End of epoch 28: running error average = 1.11 running acc average = 0.63
# End of epoch 29: running error average = 1.08 running acc average = 0.64
# End of epoch 30: running error average = 1.08 running acc average = 0.65
# End of epoch 31: running error average = 1.07 running acc average = 0.65
# End of epoch 32: running error average = 1.04 running acc average = 0.66
# End of epoch 33: running error average = 1.00 running acc average = 0.68
# End of epoch 34: running error average = 1.00 running acc average = 0.68
# End of epoch 35: running error average = 1.00 running acc average = 0.68
# End of epoch 36: running error average = 0.96 running acc average = 0.69
# End of epoch 37: running error average = 0.95 running acc average = 0.70
# End of epoch 38: running error average = 0.94 running acc average = 0.70
# End of epoch 39: running error average = 0.93 running acc average = 0.70
# End of epoch 40: running error average = 0.90 running acc average = 0.71
# End of epoch 41: running error average = 0.89 running acc average = 0.72
# End of epoch 42: running error average = 0.90 running acc average = 0.71
# End of epoch 43: running error average = 0.88 running acc average = 0.72
# End of epoch 44: running error average = 0.86 running acc average = 0.72
# End of epoch 45: running error average = 0.83 running acc average = 0.74
# End of epoch 46: running error average = 0.84 running acc average = 0.73
# End of epoch 47: running error average = 0.82 running acc average = 0.74
# End of epoch 48: running error average = 0.82 running acc average = 0.74
# End of epoch 49: running error average = 0.80 running acc average = 0.75
# End of epoch 50: running error average = 0.79 running acc average = 0.75

# %%
data = Adam_3layers_100_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_100_t(error).pdf')

# %%
data = Adam_3layers_100_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_100_t(acc).pdf')
print(data[1])
print(data[3])
# Out:
# [ 0.15811765  0.22208824  0.26323529  0.29888235  0.32776471  0.35647059
#   0.39432353  0.41417647  0.4402647   0.46529412  0.47835294  0.49076471
#   0.50020588  0.51658823  0.5235      0.53258824  0.53764706  0.55208824
#   0.56452941  0.56888236  0.58185294  0.58914706  0.59691177  0.60614706
#   0.61420589  0.61867647  0.62164706  0.6342353   0.64370589  0.64588236
#   0.64944118  0.66264706  0.67664706  0.67711765  0.67691177  0.69138236
#   0.69738236  0.69952942  0.70147059  0.71111765  0.71588236  0.71129412
#   0.719       0.72485294  0.73547059  0.73008824  0.73547059  0.73726471
#   0.74511765  0.74817647]
# [ 0.16316667  0.19433333  0.20516667  0.21516667  0.21583333  0.228
#   0.21633333  0.2275      0.24033333  0.2365      0.24183333  0.25733333
#   0.27        0.2595      0.249       0.25966667  0.2565      0.25916667
#   0.25366667  0.248       0.25583333  0.24683333  0.26116667  0.25766667
#   0.26183333  0.24933333  0.25116667  0.25016667  0.23616667  0.23983333
#   0.24516667  0.24716667  0.23066667  0.24166667  0.24166667  0.241
#   0.25633333  0.24416667  0.24716667  0.24383333  0.23916667  0.241
#   0.23816667  0.2515      0.25066667  0.23616667  0.242       0.24283333
#   0.2445      0.24266667]

# %%
n_hidden_1 = 100
n_hidden_2 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_100_L2_t = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 1314.33 running acc average = 0.16
# End of epoch 2: running error average = 891.73 running acc average = 0.23
# End of epoch 3: running error average = 560.95 running acc average = 0.29
# End of epoch 4: running error average = 319.41 running acc average = 0.34
# End of epoch 5: running error average = 160.15 running acc average = 0.39
# End of epoch 6: running error average = 68.63 running acc average = 0.44
# End of epoch 7: running error average = 24.78 running acc average = 0.48
# End of epoch 8: running error average = 8.04 running acc average = 0.52
# End of epoch 9: running error average = 3.13 running acc average = 0.55
# End of epoch 10: running error average = 2.01 running acc average = 0.57
# End of epoch 11: running error average = 1.79 running acc average = 0.58
# End of epoch 12: running error average = 1.73 running acc average = 0.59
# End of epoch 13: running error average = 1.72 running acc average = 0.59
# End of epoch 14: running error average = 1.72 running acc average = 0.59
# End of epoch 15: running error average = 1.71 running acc average = 0.60
# End of epoch 16: running error average = 1.70 running acc average = 0.60
# End of epoch 17: running error average = 1.71 running acc average = 0.60
# End of epoch 18: running error average = 1.69 running acc average = 0.61
# End of epoch 19: running error average = 1.68 running acc average = 0.61
# End of epoch 20: running error average = 1.69 running acc average = 0.62
# End of epoch 21: running error average = 1.67 running acc average = 0.62
# End of epoch 22: running error average = 1.68 running acc average = 0.62
# End of epoch 23: running error average = 1.67 running acc average = 0.62
# End of epoch 24: running error average = 1.67 running acc average = 0.63
# End of epoch 25: running error average = 1.66 running acc average = 0.63
# End of epoch 26: running error average = 1.66 running acc average = 0.64
# End of epoch 27: running error average = 1.66 running acc average = 0.64
# End of epoch 28: running error average = 1.66 running acc average = 0.63
# End of epoch 29: running error average = 1.66 running acc average = 0.63
# End of epoch 30: running error average = 1.65 running acc average = 0.64
# End of epoch 31: running error average = 1.65 running acc average = 0.64
# End of epoch 32: running error average = 1.65 running acc average = 0.64
# End of epoch 33: running error average = 1.64 running acc average = 0.64
# End of epoch 34: running error average = 1.65 running acc average = 0.64
# End of epoch 35: running error average = 1.65 running acc average = 0.64
# End of epoch 36: running error average = 1.64 running acc average = 0.65
# End of epoch 37: running error average = 1.64 running acc average = 0.64
# End of epoch 38: running error average = 1.63 running acc average = 0.65
# End of epoch 39: running error average = 1.64 running acc average = 0.65
# End of epoch 40: running error average = 1.64 running acc average = 0.65
# End of epoch 41: running error average = 1.63 running acc average = 0.65
# End of epoch 42: running error average = 1.64 running acc average = 0.65
# End of epoch 43: running error average = 1.64 running acc average = 0.65
# End of epoch 44: running error average = 1.64 running acc average = 0.65
# End of epoch 45: running error average = 1.64 running acc average = 0.65
# End of epoch 46: running error average = 1.63 running acc average = 0.65
# End of epoch 47: running error average = 1.63 running acc average = 0.65
# End of epoch 48: running error average = 1.62 running acc average = 0.65
# End of epoch 49: running error average = 1.63 running acc average = 0.65
# End of epoch 50: running error average = 1.63 running acc average = 0.65

# %%
data = Adam_3layers_100_L2_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_L2_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_100_L2_t(error).pdf')

# %%
data = Adam_3layers_100_L2_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_100_L2_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_100_L2_t(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_200_t = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 14.94 running acc average = 0.18
# End of epoch 2: running error average = 9.84 running acc average = 0.25
# End of epoch 3: running error average = 7.24 running acc average = 0.31
# End of epoch 4: running error average = 5.70 running acc average = 0.35
# End of epoch 5: running error average = 4.71 running acc average = 0.37
# End of epoch 6: running error average = 3.87 running acc average = 0.40
# End of epoch 7: running error average = 3.34 running acc average = 0.42
# End of epoch 8: running error average = 2.85 running acc average = 0.45
# End of epoch 9: running error average = 2.46 running acc average = 0.48
# End of epoch 10: running error average = 2.16 running acc average = 0.51
# End of epoch 11: running error average = 1.88 running acc average = 0.54
# End of epoch 12: running error average = 1.69 running acc average = 0.56
# End of epoch 13: running error average = 1.54 running acc average = 0.58
# End of epoch 14: running error average = 1.42 running acc average = 0.59
# End of epoch 15: running error average = 1.29 running acc average = 0.62
# End of epoch 16: running error average = 1.19 running acc average = 0.64
# End of epoch 17: running error average = 1.15 running acc average = 0.65
# End of epoch 18: running error average = 1.08 running acc average = 0.66
# End of epoch 19: running error average = 1.01 running acc average = 0.68
# End of epoch 20: running error average = 0.98 running acc average = 0.69
# End of epoch 21: running error average = 0.93 running acc average = 0.70
# End of epoch 22: running error average = 0.91 running acc average = 0.71
# End of epoch 23: running error average = 0.86 running acc average = 0.72
# End of epoch 24: running error average = 0.84 running acc average = 0.73
# End of epoch 25: running error average = 0.81 running acc average = 0.74
# End of epoch 26: running error average = 0.78 running acc average = 0.75
# End of epoch 27: running error average = 0.77 running acc average = 0.75
# End of epoch 28: running error average = 0.74 running acc average = 0.77
# End of epoch 29: running error average = 0.73 running acc average = 0.76
# End of epoch 30: running error average = 0.72 running acc average = 0.77
# End of epoch 31: running error average = 0.68 running acc average = 0.79
# End of epoch 32: running error average = 0.66 running acc average = 0.79
# End of epoch 33: running error average = 0.65 running acc average = 0.79
# End of epoch 34: running error average = 0.64 running acc average = 0.79
# End of epoch 35: running error average = 0.61 running acc average = 0.81
# End of epoch 36: running error average = 0.58 running acc average = 0.81
# End of epoch 37: running error average = 0.60 running acc average = 0.81
# End of epoch 38: running error average = 0.56 running acc average = 0.82
# End of epoch 39: running error average = 0.56 running acc average = 0.82
# End of epoch 40: running error average = 0.55 running acc average = 0.82
# End of epoch 41: running error average = 0.53 running acc average = 0.83
# End of epoch 42: running error average = 0.53 running acc average = 0.83
# End of epoch 43: running error average = 0.51 running acc average = 0.84
# End of epoch 44: running error average = 0.51 running acc average = 0.84
# End of epoch 45: running error average = 0.48 running acc average = 0.85
# End of epoch 46: running error average = 0.46 running acc average = 0.85
# End of epoch 47: running error average = 0.47 running acc average = 0.85
# End of epoch 48: running error average = 0.47 running acc average = 0.85
# End of epoch 49: running error average = 0.46 running acc average = 0.85
# End of epoch 50: running error average = 0.45 running acc average = 0.86

# %%
data = Adam_3layers_200_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_t(error).pdf')

# %%
data = Adam_3layers_200_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_t(acc).pdf')

# %%
n_hidden_1 = 200
n_hidden_2 = 200
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_200_L2_t = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 2796.21 running acc average = 0.17

# %%
data = Adam_3layers_200_L2_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_L2_t(error).pdf')

# %%
data = Adam_3layers_200_L2_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_200_L2_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_200_L2_t(acc).pdf')
print(data[3])
# Out:
# [ 0.17966667  0.21166667  0.23916667  0.2345      0.24716667  0.27583333
#   0.31716667  0.38816667  0.422       0.43733333  0.4455      0.4375
#   0.46233333  0.44783333  0.45033333  0.46183333  0.459       0.461       0.469
#   0.45166667  0.4665      0.4605      0.4635      0.47783333  0.45933333
#   0.4535      0.44833333  0.4545      0.45733333  0.47016667  0.46933333
#   0.4545      0.46483333  0.459       0.45616667  0.46833333  0.45666667
#   0.45683333  0.45933333  0.475       0.47066666  0.46116667  0.45633333
#   0.46716667  0.469       0.44316666  0.4605      0.454       0.463
#   0.45683333  0.45566666  0.4575      0.46516667  0.46466667  0.45283333
#   0.46833333  0.46066667  0.457       0.45766667  0.46666667  0.44233333
#   0.45983333  0.46216666  0.45916667  0.45866666  0.459       0.4675
#   0.46133333  0.46783333  0.459       0.458       0.45533333  0.44716667
#   0.4525      0.46633333  0.446       0.44616666  0.45883333  0.47133333
#   0.47083333  0.45433333  0.454       0.4545      0.45966666  0.4565
#   0.44466667  0.45833333  0.46266667  0.46283333  0.47616667  0.46233333
#   0.4605      0.45783333  0.457       0.46916666  0.45033333  0.45433333
#   0.46133333  0.44966667  0.45566667]

# %%
n_hidden_1 = 300
n_hidden_2 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
#regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
#error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 50
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_300_t = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 18.41 running acc average = 0.20
# End of epoch 2: running error average = 12.32 running acc average = 0.28
# End of epoch 3: running error average = 9.44 running acc average = 0.33
# End of epoch 4: running error average = 7.53 running acc average = 0.37
# End of epoch 5: running error average = 6.26 running acc average = 0.40
# End of epoch 6: running error average = 5.34 running acc average = 0.42
# End of epoch 7: running error average = 4.55 running acc average = 0.44
# End of epoch 8: running error average = 4.00 running acc average = 0.46
# End of epoch 9: running error average = 3.57 running acc average = 0.48
# End of epoch 10: running error average = 3.15 running acc average = 0.50
# End of epoch 11: running error average = 2.82 running acc average = 0.52
# End of epoch 12: running error average = 2.50 running acc average = 0.54
# End of epoch 13: running error average = 2.29 running acc average = 0.55
# End of epoch 14: running error average = 2.14 running acc average = 0.56
# End of epoch 15: running error average = 1.91 running acc average = 0.58
# End of epoch 16: running error average = 1.79 running acc average = 0.59
# End of epoch 17: running error average = 1.67 running acc average = 0.61
# End of epoch 18: running error average = 1.49 running acc average = 0.62
# End of epoch 19: running error average = 1.37 running acc average = 0.64
# End of epoch 20: running error average = 1.25 running acc average = 0.66
# End of epoch 21: running error average = 1.19 running acc average = 0.66
# End of epoch 22: running error average = 1.11 running acc average = 0.68
# End of epoch 23: running error average = 1.08 running acc average = 0.68
# End of epoch 24: running error average = 0.99 running acc average = 0.71
# End of epoch 25: running error average = 0.91 running acc average = 0.72
# End of epoch 26: running error average = 0.89 running acc average = 0.73
# End of epoch 27: running error average = 0.86 running acc average = 0.73
# End of epoch 28: running error average = 0.82 running acc average = 0.74
# End of epoch 29: running error average = 0.77 running acc average = 0.75
# End of epoch 30: running error average = 0.76 running acc average = 0.75
# End of epoch 31: running error average = 0.74 running acc average = 0.76
# End of epoch 32: running error average = 0.71 running acc average = 0.77
# End of epoch 33: running error average = 0.67 running acc average = 0.78
# End of epoch 34: running error average = 0.67 running acc average = 0.78
# End of epoch 35: running error average = 0.66 running acc average = 0.78
# End of epoch 36: running error average = 0.62 running acc average = 0.80
# End of epoch 37: running error average = 0.61 running acc average = 0.80
# End of epoch 38: running error average = 0.60 running acc average = 0.80
# End of epoch 39: running error average = 0.60 running acc average = 0.80
# End of epoch 40: running error average = 0.56 running acc average = 0.81
# End of epoch 41: running error average = 0.54 running acc average = 0.82
# End of epoch 42: running error average = 0.53 running acc average = 0.83
# End of epoch 43: running error average = 0.53 running acc average = 0.82
# End of epoch 44: running error average = 0.52 running acc average = 0.83
# End of epoch 45: running error average = 0.52 running acc average = 0.83
# End of epoch 46: running error average = 0.52 running acc average = 0.83
# End of epoch 47: running error average = 0.51 running acc average = 0.83
# End of epoch 48: running error average = 0.49 running acc average = 0.84
# End of epoch 49: running error average = 0.49 running acc average = 0.84
# End of epoch 50: running error average = 0.47 running acc average = 0.84

# %%
data = Adam_3layers_300_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_t(error).pdf')

# %%
data = Adam_3layers_300_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_t(acc).pdf')

# %%
n_hidden_1 = 300
n_hidden_2 = 300
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_3hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    layer_2 = tf.nn.tanh(tf.matmul(layer_1, weights['h2']) + biases['b2'])
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    return out_layer
out_layer = multilayer_3hidden100(inputs)

per_datapoint_errors = tf.nn.softmax_cross_entropy_with_logits(logits=out_layer, labels=targets)
error = tf.reduce_mean(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['h2'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)
import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
Adam_3layers_300_L2_t_100 = [error_train, acc_train, error_valid, acc_valid]
# Out:
# End of epoch 1: running error average = 4339.23 running acc average = 0.18
# End of epoch 2: running error average = 3203.28 running acc average = 0.30
# End of epoch 3: running error average = 2237.11 running acc average = 0.37
# End of epoch 4: running error average = 1452.48 running acc average = 0.44
# End of epoch 5: running error average = 856.78 running acc average = 0.52
# End of epoch 6: running error average = 445.17 running acc average = 0.58
# End of epoch 7: running error average = 196.14 running acc average = 0.62
# End of epoch 8: running error average = 70.59 running acc average = 0.62
# End of epoch 9: running error average = 20.70 running acc average = 0.61
# End of epoch 10: running error average = 5.89 running acc average = 0.59
# End of epoch 11: running error average = 2.58 running acc average = 0.58
# End of epoch 12: running error average = 1.95 running acc average = 0.58
# End of epoch 13: running error average = 1.84 running acc average = 0.57
# End of epoch 14: running error average = 1.82 running acc average = 0.56
# End of epoch 15: running error average = 1.82 running acc average = 0.56
# End of epoch 16: running error average = 1.82 running acc average = 0.56
# End of epoch 17: running error average = 1.84 running acc average = 0.55
# End of epoch 18: running error average = 1.83 running acc average = 0.56
# End of epoch 19: running error average = 1.82 running acc average = 0.56
# End of epoch 20: running error average = 1.83 running acc average = 0.56
# End of epoch 21: running error average = 1.81 running acc average = 0.57
# End of epoch 22: running error average = 1.82 running acc average = 0.57
# End of epoch 23: running error average = 1.81 running acc average = 0.58
# End of epoch 24: running error average = 1.81 running acc average = 0.58
# End of epoch 25: running error average = 1.79 running acc average = 0.59
# End of epoch 26: running error average = 1.79 running acc average = 0.59
# End of epoch 27: running error average = 1.79 running acc average = 0.60
# End of epoch 28: running error average = 1.79 running acc average = 0.59
# End of epoch 29: running error average = 1.78 running acc average = 0.60
# End of epoch 30: running error average = 1.78 running acc average = 0.60
# End of epoch 31: running error average = 1.78 running acc average = 0.61
# End of epoch 32: running error average = 1.77 running acc average = 0.61
# End of epoch 33: running error average = 1.76 running acc average = 0.61
# End of epoch 34: running error average = 1.77 running acc average = 0.61
# End of epoch 35: running error average = 1.77 running acc average = 0.61
# End of epoch 36: running error average = 1.75 running acc average = 0.62
# End of epoch 37: running error average = 1.76 running acc average = 0.62
# End of epoch 38: running error average = 1.76 running acc average = 0.62
# End of epoch 39: running error average = 1.74 running acc average = 0.63
# End of epoch 40: running error average = 1.76 running acc average = 0.62
# End of epoch 41: running error average = 1.75 running acc average = 0.63
# End of epoch 42: running error average = 1.75 running acc average = 0.62
# End of epoch 43: running error average = 1.76 running acc average = 0.62
# End of epoch 44: running error average = 1.75 running acc average = 0.63
# End of epoch 45: running error average = 1.75 running acc average = 0.63
# End of epoch 46: running error average = 1.75 running acc average = 0.63
# End of epoch 47: running error average = 1.73 running acc average = 0.64
# End of epoch 48: running error average = 1.73 running acc average = 0.63
# End of epoch 49: running error average = 1.73 running acc average = 0.63
# End of epoch 50: running error average = 1.74 running acc average = 0.63
# End of epoch 51: running error average = 1.75 running acc average = 0.63
# End of epoch 52: running error average = 1.74 running acc average = 0.64
# End of epoch 53: running error average = 1.73 running acc average = 0.64
# End of epoch 54: running error average = 1.73 running acc average = 0.64
# End of epoch 55: running error average = 1.74 running acc average = 0.64
# End of epoch 56: running error average = 1.72 running acc average = 0.64
# End of epoch 57: running error average = 1.73 running acc average = 0.64
# End of epoch 58: running error average = 1.73 running acc average = 0.64
# End of epoch 59: running error average = 1.71 running acc average = 0.64
# End of epoch 60: running error average = 1.72 running acc average = 0.64
# End of epoch 61: running error average = 1.73 running acc average = 0.64
# End of epoch 62: running error average = 1.71 running acc average = 0.64
# End of epoch 63: running error average = 1.73 running acc average = 0.64
# End of epoch 64: running error average = 1.74 running acc average = 0.64
# End of epoch 65: running error average = 1.72 running acc average = 0.64
# End of epoch 66: running error average = 1.72 running acc average = 0.64
# End of epoch 67: running error average = 1.70 running acc average = 0.65
# End of epoch 68: running error average = 1.72 running acc average = 0.64
# End of epoch 69: running error average = 1.72 running acc average = 0.64
# End of epoch 70: running error average = 1.72 running acc average = 0.64
# End of epoch 71: running error average = 1.71 running acc average = 0.65
# End of epoch 72: running error average = 1.71 running acc average = 0.64
# End of epoch 73: running error average = 1.72 running acc average = 0.64
# End of epoch 74: running error average = 1.72 running acc average = 0.64
# End of epoch 75: running error average = 1.71 running acc average = 0.64
# End of epoch 76: running error average = 1.72 running acc average = 0.64
# End of epoch 77: running error average = 1.72 running acc average = 0.64
# End of epoch 78: running error average = 1.72 running acc average = 0.64
# End of epoch 79: running error average = 1.71 running acc average = 0.65
# End of epoch 80: running error average = 1.71 running acc average = 0.65
# End of epoch 81: running error average = 1.72 running acc average = 0.65
# End of epoch 82: running error average = 1.72 running acc average = 0.64
# End of epoch 83: running error average = 1.73 running acc average = 0.64
# End of epoch 84: running error average = 1.73 running acc average = 0.64
# End of epoch 85: running error average = 1.70 running acc average = 0.65
# End of epoch 86: running error average = 1.72 running acc average = 0.64
# End of epoch 87: running error average = 1.71 running acc average = 0.65
# End of epoch 88: running error average = 1.72 running acc average = 0.64
# End of epoch 89: running error average = 1.71 running acc average = 0.65
# End of epoch 90: running error average = 1.71 running acc average = 0.65
# End of epoch 91: running error average = 1.71 running acc average = 0.65
# End of epoch 92: running error average = 1.71 running acc average = 0.65
# End of epoch 93: running error average = 1.71 running acc average = 0.65
# End of epoch 94: running error average = 1.71 running acc average = 0.65
# End of epoch 95: running error average = 1.71 running acc average = 0.65
# End of epoch 96: running error average = 1.72 running acc average = 0.64
# End of epoch 97: running error average = 1.72 running acc average = 0.64
# End of epoch 98: running error average = 1.71 running acc average = 0.64
# End of epoch 99: running error average = 1.72 running acc average = 0.64
# End of epoch 100: running error average = 1.72 running acc average = 0.65

# %%
data = Adam_3layers_300_L2_t_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2_t_100(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_L2_t_100(error).pdf')

# %%
data = Adam_3layers_300_L2_t_100

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('Adam_3layers_300_L2_t_100(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('Adam_3layers_300_L2_t_100(acc).pdf')

# %%
np.save('Adam_3layers_100_t', Adam_3layers_100_t)
np.save('Adam_3layers_100_L2_t', Adam_3layers_100_L2_t)
np.save('Adam_3layers_200_t', Adam_3layers_200_t)
np.save('Adam_3layers_200_L2_t_100', Adam_3layers_200_L2_t_100)
np.save('Adam_3layers_300_t', Adam_3layers_300_t)
np.save('Adam_3layers_300_L2_t_100', Adam_3layers_300_L2_t_100)
