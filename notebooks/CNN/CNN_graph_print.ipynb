# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None,120,25,1], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
def conv2d(x, w):
    return tf.nn.conv2d(x, w, strides = [1, 1, 1, 1], padding = 'VALID')
def pool(x, m, n):
    """
    
    Args:
        x: outputs of the last layer
        m: Raw of the max_pooling
        n: Column of the max_pooling
    
    """
    return tf.nn.max_pool(x, ksize = [1, m, n, 1], strides = [1, m, n, 1], padding = 'VALID')

# %%
data = np.load('CNN_2layers.npy')
data1 = np.load('CNN_3layers.npy')

fig_1 = plt.figure(figsize=(10,20))

ax_1 = fig_1.add_subplot(411)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = '2layers')
ax_1.plot(np.arange(data1[0].shape[0]), data1[0], label = '3layers')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Training set error', fontsize = 12, fontweight = 1000)


ax_2 = fig_1.add_subplot(412)
ax_2.plot(np.arange(data[2].shape[0]), data[2], label = '2layers')
ax_2.plot(np.arange(data1[2].shape[0]), data1[2], label = '3layers')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_2.set_ylabel('Validation set error', fontsize = 12, fontweight = 1000)

ax_3 = fig_1.add_subplot(413)
ax_3.plot(np.arange(data[1].shape[0]), data[1], label = '2layers')
ax_3.plot(np.arange(data1[1].shape[0]), data1[1], label = '3layers')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_3.set_ylabel('Training set ACC', fontsize = 12, fontweight = 1000)


ax_4 = fig_1.add_subplot(414)
ax_4.plot(np.arange(data[3].shape[0]), data[3], label = '2layers')
ax_4.plot(np.arange(data1[3].shape[0]), data1[3], label = '3layers')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_4.set_ylabel('Validation set ACC', fontsize = 12, fontweight = 1000)

plt.tight_layout()
fig_1.savefig('CNN_layers_10.pdf')

print(data[2][-1], data[3][-1])
print(data1[2][-1], data1[3][-1])
print(data2[2][-1], data2[3][-1])
# Out:
# 2.03416368365 0.228833332906
# 1.96878059804 0.273166666366
# 1.79633826911 0.345000000174

# %%
data = np.load('CNN_2layers_25.npy')
data1 = np.load('CNN_3layers_25.npy')
data2 = np.load('CNN_3cnn_2d_25.npy')

fig_1 = plt.figure(figsize=(10,20))

ax_1 = fig_1.add_subplot(411)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = '2layers')
ax_1.plot(np.arange(data1[0].shape[0]), data1[0], label = '3layers')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Training set error', fontsize = 12, fontweight = 1000)


ax_2 = fig_1.add_subplot(412)
ax_2.plot(np.arange(data[2].shape[0]), data[2], label = '2layers')
ax_2.plot(np.arange(data1[2].shape[0]), data1[2], label = '3layers')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_2.set_ylabel('Validation set error', fontsize = 12, fontweight = 1000)

ax_3 = fig_1.add_subplot(413)
ax_3.plot(np.arange(data[1].shape[0]), data[1], label = '2layers')
ax_3.plot(np.arange(data1[1].shape[0]), data1[1], label = '3layers')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_3.set_ylabel('Training set ACC', fontsize = 12, fontweight = 1000)


ax_4 = fig_1.add_subplot(414)
ax_4.plot(np.arange(data[3].shape[0]), data[3], label = '2layers')
ax_4.plot(np.arange(data1[3].shape[0]), data1[3], label = '3layers')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_4.set_ylabel('Validation set ACC', fontsize = 12, fontweight = 1000)

plt.tight_layout()
fig_1.savefig('CNN_layers_25.pdf')

print(data[2][-1], data[3][-1])
print(data1[2][-1], data1[3][-1])
print(data2[2][-1], data2[3][-1])
# Out:
# 2.03120274742 0.220833332837
# 2.04388660689 0.243666666498
# 1.79633826911 0.345000000174

# %%
data = np.load('CNN_3cnn_2d.npy')
data1 = np.load('CNN_3cnn_2d_large.npy')

fig_1 = plt.figure(figsize=(10,20))

ax_1 = fig_1.add_subplot(411)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'small')
ax_1.plot(np.arange(data1[0].shape[0]), data1[0], label = 'large')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Training set error', fontsize = 12, fontweight = 1000)


ax_2 = fig_1.add_subplot(412)
ax_2.plot(np.arange(data[2].shape[0]), data[2], label = 'small')
ax_2.plot(np.arange(data1[2].shape[0]), data1[2], label = 'large')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_2.set_ylabel('Validation set error', fontsize = 12, fontweight = 1000)

ax_3 = fig_1.add_subplot(413)
ax_3.plot(np.arange(data[1].shape[0]), data[1], label = 'small')
ax_3.plot(np.arange(data1[1].shape[0]), data1[1], label = 'large')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_3.set_ylabel('Training set ACC', fontsize = 12, fontweight = 1000)


ax_4 = fig_1.add_subplot(414)
ax_4.plot(np.arange(data[3].shape[0]), data[3], label = 'small')
ax_4.plot(np.arange(data1[3].shape[0]), data1[3], label = 'large')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_4.set_ylabel('Validation set ACC', fontsize = 12, fontweight = 1000)

plt.tight_layout()
fig_1.savefig('CNN_d_layers_10.pdf')

print(data[2][-1], data[3][-1])
print(data1[2][-1], data1[3][-1])
# Out:
# 1.63018001715 0.419999999801
# 1.77122004628 0.367166667307

# %%
data = np.load('CNN_3cnn_2d_25.npy')
data1 = np.load('CNN_3cnn_2d_large_25.npy')

fig_1 = plt.figure(figsize=(10,20))

ax_1 = fig_1.add_subplot(411)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'small')
ax_1.plot(np.arange(data1[0].shape[0]), data1[0], label = 'large')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Training set error', fontsize = 12, fontweight = 1000)


ax_2 = fig_1.add_subplot(412)
ax_2.plot(np.arange(data[2].shape[0]), data[2], label = 'small')
ax_2.plot(np.arange(data1[2].shape[0]), data1[2], label = 'large')
ax_2.legend(loc=0)
ax_2.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_2.set_ylabel('Validation set error', fontsize = 12, fontweight = 1000)

ax_3 = fig_1.add_subplot(413)
ax_3.plot(np.arange(data[1].shape[0]), data[1], label = 'small')
ax_3.plot(np.arange(data1[1].shape[0]), data1[1], label = 'large')
ax_3.legend(loc=0)
ax_3.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_3.set_ylabel('Training set ACC', fontsize = 12, fontweight = 1000)


ax_4 = fig_1.add_subplot(414)
ax_4.plot(np.arange(data[3].shape[0]), data[3], label = 'small')
ax_4.plot(np.arange(data1[3].shape[0]), data1[3], label = 'large')
ax_4.legend(loc=0)
ax_4.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_4.set_ylabel('Validation set ACC', fontsize = 12, fontweight = 1000)

plt.tight_layout()
fig_1.savefig('CNN_d_layers_25.pdf')

print(data[2][-1], data[3][-1])
print(data1[2][-1], data1[3][-1])
# Out:
# 1.79633826911 0.345000000174
# 1.8769203186 0.323333334054
