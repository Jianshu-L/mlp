# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 10], 'targets')

# %%
def get_error_and_accuracy(data):
    """Calculate average error and classification accuracy across a dataset.
    
    Args:
        data: Data provider which iterates over input-target batches in dataset.
        
    Returns:
        Tuple with first element scalar value corresponding to average error
        across all batches in dataset and second value corresponding to
        average classification accuracy across all batches in dataset.
    """
    err = 0
    acc = 0
    for input_batch, target_batch in data:
        err += sess.run(error, feed_dict={inputs: input_batch, targets: target_batch})
        acc += sess.run(accuracy, feed_dict={inputs: input_batch, targets: target_batch})
    err /= data.num_batches
    acc /= data.num_batches
    return err, acc

# %%
n_hidden_1 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 10]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([10]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.nn.softmax(tf.matmul(layer_1, weights['out']) + biases['out'])
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = (out_layer - targets) * (out_layer - targets)
error = tf.reduce_sum(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate = 0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)

import data_providers as data_providers
train_data = data_providers.MSD10GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD10GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc, lr = sess.run(
            [train_step, error, accuracy, learning_rate], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc), 'learning rate = {1:.3f}'.format(e + 1, lr))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
LS_2layers_100_t = [error_train, acc_train, error_valid, acc_valid]
np.save('LS_2layers_100_t', LS_2layers_100_t)
# Out:
# End of epoch 1: running error average = 1487.12 running acc average = 0.13 learning rate = 0.001
# End of epoch 2: running error average = 1324.35 running acc average = 0.18 learning rate = 0.001
# End of epoch 3: running error average = 1185.38 running acc average = 0.25 learning rate = 0.001
# End of epoch 4: running error average = 1065.36 running acc average = 0.29 learning rate = 0.001
# End of epoch 5: running error average = 958.99 running acc average = 0.31 learning rate = 0.001
# End of epoch 6: running error average = 863.77 running acc average = 0.34 learning rate = 0.001
# End of epoch 7: running error average = 778.32 running acc average = 0.36 learning rate = 0.001
# End of epoch 8: running error average = 702.57 running acc average = 0.38 learning rate = 0.001
# End of epoch 9: running error average = 634.31 running acc average = 0.40 learning rate = 0.001
# End of epoch 10: running error average = 572.22 running acc average = 0.42 learning rate = 0.001
# End of epoch 11: running error average = 517.34 running acc average = 0.43 learning rate = 0.001
# End of epoch 12: running error average = 467.99 running acc average = 0.44 learning rate = 0.001
# End of epoch 13: running error average = 423.25 running acc average = 0.46 learning rate = 0.001
# End of epoch 14: running error average = 383.23 running acc average = 0.48 learning rate = 0.001
# End of epoch 15: running error average = 346.91 running acc average = 0.50 learning rate = 0.001
# End of epoch 16: running error average = 314.78 running acc average = 0.51 learning rate = 0.001
# End of epoch 17: running error average = 285.62 running acc average = 0.51 learning rate = 0.001
# End of epoch 18: running error average = 259.21 running acc average = 0.53 learning rate = 0.001
# End of epoch 19: running error average = 235.43 running acc average = 0.55 learning rate = 0.001
# End of epoch 20: running error average = 213.91 running acc average = 0.56 learning rate = 0.001
# End of epoch 21: running error average = 193.97 running acc average = 0.57 learning rate = 0.001
# End of epoch 22: running error average = 176.33 running acc average = 0.58 learning rate = 0.001
# End of epoch 23: running error average = 160.59 running acc average = 0.59 learning rate = 0.001
# End of epoch 24: running error average = 145.93 running acc average = 0.61 learning rate = 0.001
# End of epoch 25: running error average = 132.66 running acc average = 0.63 learning rate = 0.001
# End of epoch 26: running error average = 120.96 running acc average = 0.64 learning rate = 0.001
# End of epoch 27: running error average = 110.55 running acc average = 0.65 learning rate = 0.001
# End of epoch 28: running error average = 100.49 running acc average = 0.66 learning rate = 0.001
# End of epoch 29: running error average = 92.02 running acc average = 0.67 learning rate = 0.001
# End of epoch 30: running error average = 84.01 running acc average = 0.69 learning rate = 0.001
# End of epoch 31: running error average = 76.69 running acc average = 0.70 learning rate = 0.001
# End of epoch 32: running error average = 70.11 running acc average = 0.72 learning rate = 0.001
# End of epoch 33: running error average = 64.69 running acc average = 0.72 learning rate = 0.001
# End of epoch 34: running error average = 59.81 running acc average = 0.73 learning rate = 0.001
# End of epoch 35: running error average = 55.08 running acc average = 0.75 learning rate = 0.001
# End of epoch 36: running error average = 50.83 running acc average = 0.76 learning rate = 0.001
# End of epoch 37: running error average = 47.00 running acc average = 0.77 learning rate = 0.001
# End of epoch 38: running error average = 44.34 running acc average = 0.77 learning rate = 0.001
# End of epoch 39: running error average = 41.54 running acc average = 0.78 learning rate = 0.001
# End of epoch 40: running error average = 39.43 running acc average = 0.79 learning rate = 0.001
# End of epoch 41: running error average = 37.06 running acc average = 0.80 learning rate = 0.001
# End of epoch 42: running error average = 35.18 running acc average = 0.80 learning rate = 0.001
# End of epoch 43: running error average = 33.76 running acc average = 0.81 learning rate = 0.001
# End of epoch 44: running error average = 31.98 running acc average = 0.82 learning rate = 0.001
# End of epoch 45: running error average = 31.00 running acc average = 0.82 learning rate = 0.001
# End of epoch 46: running error average = 29.80 running acc average = 0.82 learning rate = 0.001
# End of epoch 47: running error average = 28.64 running acc average = 0.83 learning rate = 0.001
# End of epoch 48: running error average = 27.91 running acc average = 0.83 learning rate = 0.001
# End of epoch 49: running error average = 26.74 running acc average = 0.84 learning rate = 0.001
# End of epoch 50: running error average = 26.01 running acc average = 0.84 learning rate = 0.001
# End of epoch 51: running error average = 25.66 running acc average = 0.84 learning rate = 0.001
# End of epoch 52: running error average = 24.84 running acc average = 0.85 learning rate = 0.001
# End of epoch 53: running error average = 24.32 running acc average = 0.85 learning rate = 0.001
# End of epoch 54: running error average = 24.08 running acc average = 0.85 learning rate = 0.001
# End of epoch 55: running error average = 23.41 running acc average = 0.86 learning rate = 0.001
# End of epoch 56: running error average = 22.72 running acc average = 0.86 learning rate = 0.001
# End of epoch 57: running error average = 22.78 running acc average = 0.86 learning rate = 0.001
# End of epoch 58: running error average = 22.15 running acc average = 0.87 learning rate = 0.001
# End of epoch 59: running error average = 21.96 running acc average = 0.87 learning rate = 0.001
# End of epoch 60: running error average = 21.84 running acc average = 0.87 learning rate = 0.001
# End of epoch 61: running error average = 21.89 running acc average = 0.87 learning rate = 0.001
# End of epoch 62: running error average = 21.36 running acc average = 0.87 learning rate = 0.001
# End of epoch 63: running error average = 21.21 running acc average = 0.87 learning rate = 0.001
# End of epoch 64: running error average = 20.83 running acc average = 0.87 learning rate = 0.001
# End of epoch 65: running error average = 20.60 running acc average = 0.88 learning rate = 0.001
# End of epoch 66: running error average = 20.41 running acc average = 0.88 learning rate = 0.001
# End of epoch 67: running error average = 20.42 running acc average = 0.88 learning rate = 0.001
# End of epoch 68: running error average = 20.32 running acc average = 0.88 learning rate = 0.001
# End of epoch 69: running error average = 20.17 running acc average = 0.88 learning rate = 0.001
# End of epoch 70: running error average = 20.10 running acc average = 0.88 learning rate = 0.001
# End of epoch 71: running error average = 19.46 running acc average = 0.89 learning rate = 0.001
# End of epoch 72: running error average = 20.06 running acc average = 0.88 learning rate = 0.001
# End of epoch 73: running error average = 19.42 running acc average = 0.89 learning rate = 0.001
# End of epoch 74: running error average = 19.44 running acc average = 0.89 learning rate = 0.001
# End of epoch 75: running error average = 19.13 running acc average = 0.89 learning rate = 0.001
# End of epoch 76: running error average = 19.54 running acc average = 0.89 learning rate = 0.001
# End of epoch 77: running error average = 19.24 running acc average = 0.89 learning rate = 0.001
# End of epoch 78: running error average = 19.25 running acc average = 0.89 learning rate = 0.001
# End of epoch 79: running error average = 19.21 running acc average = 0.89 learning rate = 0.001
# End of epoch 80: running error average = 18.81 running acc average = 0.90 learning rate = 0.001
# End of epoch 81: running error average = 18.61 running acc average = 0.90 learning rate = 0.001
# End of epoch 82: running error average = 18.85 running acc average = 0.89 learning rate = 0.001
# End of epoch 83: running error average = 19.09 running acc average = 0.89 learning rate = 0.001
# End of epoch 84: running error average = 18.53 running acc average = 0.90 learning rate = 0.001
# End of epoch 85: running error average = 18.39 running acc average = 0.90 learning rate = 0.001
# End of epoch 86: running error average = 18.54 running acc average = 0.90 learning rate = 0.001
# End of epoch 87: running error average = 18.17 running acc average = 0.90 learning rate = 0.001
# End of epoch 88: running error average = 18.07 running acc average = 0.90 learning rate = 0.001
# End of epoch 89: running error average = 18.09 running acc average = 0.90 learning rate = 0.001
# End of epoch 90: running error average = 18.58 running acc average = 0.90 learning rate = 0.001
# End of epoch 91: running error average = 18.24 running acc average = 0.90 learning rate = 0.001
# End of epoch 92: running error average = 18.33 running acc average = 0.90 learning rate = 0.001
# End of epoch 93: running error average = 18.25 running acc average = 0.90 learning rate = 0.001
# End of epoch 94: running error average = 18.02 running acc average = 0.90 learning rate = 0.001
# End of epoch 95: running error average = 17.93 running acc average = 0.90 learning rate = 0.001
# End of epoch 96: running error average = 18.05 running acc average = 0.90 learning rate = 0.001
# End of epoch 97: running error average = 17.73 running acc average = 0.91 learning rate = 0.001
# End of epoch 98: running error average = 17.93 running acc average = 0.90 learning rate = 0.001
# End of epoch 99: running error average = 17.89 running acc average = 0.90 learning rate = 0.001
# End of epoch 100: running error average = 17.71 running acc average = 0.91 learning rate = 0.001

# %%
data = LS_2layers_100_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('LS_2layers_100_t(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('LS_2layers_100_t(error).pdf')

# %%
data = LS_2layers_100_t

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('LS_2layers_100_t(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('LS_2layers_100_t(acc).pdf')

# %%
inputs = tf.placeholder(tf.float32, [None, 3000], 'inputs')
targets = tf.placeholder(tf.float32, [None, 25], 'targets')

# %%
n_hidden_1 = 100
beta = 0.01 #0.009

weights = {
    'h1': tf.Variable(tf.random_normal([3000, n_hidden_1])),
    'out': tf.Variable(tf.random_normal([n_hidden_1, 25]))
}
biases = {
    'b1': tf.Variable(tf.random_normal([n_hidden_1])),
    'out': tf.Variable(tf.random_normal([25]))
}
def multilayer_2hidden100(data):
    layer_1 = tf.nn.tanh(tf.matmul(data, weights['h1']) + biases['b1'])
    out_layer = tf.nn.softmax(tf.matmul(layer_1, weights['out']) + biases['out'])
    return out_layer
out_layer = multilayer_2hidden100(inputs)

per_datapoint_errors = (out_layer - targets) * (out_layer - targets)
error = tf.reduce_sum(per_datapoint_errors)
regularizer = tf.nn.l2_loss(weights['h1'])+tf.nn.l2_loss(weights['out'])
error = tf.reduce_mean(error + beta * regularizer)

per_datapoint_pred_is_correct = tf.equal(tf.argmax(out_layer, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(per_datapoint_pred_is_correct, tf.float32))

train_step = tf.train.AdamOptimizer(learning_rate = 0.001).minimize(error)
sess = tf.InteractiveSession()

init_op = tf.global_variables_initializer()
sess.run(init_op)

import data_providers as data_providers
train_data = data_providers.MSD25GenreDataProvider('train', batch_size=50, flatten=True, one_hot=True)
valid_data = data_providers.MSD25GenreDataProvider('valid', batch_size=50, flatten=True, one_hot=True)

num_epoch = 100
error_train = []
error_valid = []
acc_train = []
acc_valid = []

for e in range(num_epoch):
    running_error = 0.
    running_acc = 0.
    for input_batch, target_batch in train_data:
        _, batch_error, batch_acc, lr = sess.run(
            [train_step, error, accuracy, learning_rate], 
            feed_dict={inputs: input_batch, targets: target_batch})
        running_error += batch_error
        running_acc += batch_acc
    running_error /= train_data.num_batches
    running_acc /= train_data.num_batches
    print('End of epoch {0}: running error average = {1:.2f}'.format(e + 1, running_error), 
          'running acc average = {1:.2f}'.format(e + 1, running_acc))
    error_train = np.append(error_train, running_error)
    acc_train = np.append(acc_train, running_acc)
    a = get_error_and_accuracy(valid_data)
    error_valid = np.append(error_valid, a[0])
    acc_valid = np.append(acc_valid, a[1])
    
LS_2layers_100_t_25 = [error_train, acc_train, error_valid, acc_valid]
np.save('LS_2layers_100_t_25', LS_2layers_100_t_25)
# Out:
# End of epoch 1: running error average = 1495.52 running acc average = 0.08
# End of epoch 2: running error average = 1329.57 running acc average = 0.14
# End of epoch 3: running error average = 1186.02 running acc average = 0.18
# End of epoch 4: running error average = 1058.81 running acc average = 0.21
# End of epoch 5: running error average = 944.55 running acc average = 0.23
# End of epoch 6: running error average = 841.83 running acc average = 0.26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-f82e7fda3ccd> in <module>()
#      46         _, batch_error, batch_acc, lr = sess.run(
#      47             [train_step, error, accuracy, learning_rate],
# ---> 48             feed_dict={inputs: input_batch, targets: target_batch})
#      49         running_error += batch_error
#      50         running_acc += batch_acc
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
data = LS_2layers_100_t_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[0].shape[0]), data[0], label = 'train')
ax_1.plot(np.arange(data[2].shape[0]), data[2], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('Error', fontsize = 12, fontweight = 1000)
ax_1.set_title('LS_2layers_100_t_25(error)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('LS_2layers_100_t_25(error).pdf')

# %%
data = LS_2layers_100_t_25

fig_1 = plt.figure(figsize=(10,6))
ax_1 = fig_1.add_subplot(111)
ax_1.plot(np.arange(data[1].shape[0]), data[1], label = 'train')
ax_1.plot(np.arange(data[3].shape[0]), data[3], label = 'valid')
ax_1.legend(loc=0)
ax_1.set_xlabel('Epoch number',fontsize = 12, fontweight = 1000)
ax_1.set_ylabel('ACC', fontsize = 12, fontweight = 1000)
ax_1.set_title('LS_2layers_100_t_25(acc)', fontsize = 14)
plt.tight_layout()
fig_1.savefig('LS_2layers_100_t_25(acc).pdf')
