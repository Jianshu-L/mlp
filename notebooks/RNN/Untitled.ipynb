# %%
import tensorflow as tf
from tensorflow.contrib import rnn

#import mnist dataset
from tensorflow.examples.tutorials.mnist import input_data
mnist=input_data.read_data_sets("/tmp/data/",one_hot=True)

#define constants
#unrolled through 28 time steps
time_steps=28
#hidden LSTM units
num_units=128
#rows of 28 pixels
n_input=28
#learning rate for adam
learning_rate=0.001
#mnist is meant to be classified in 10 classes(0-9).
n_classes=10
#size of batch
batch_size=128
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
#weights and biases of appropriate shape to accomplish above task
out_weights=tf.Variable(tf.random_normal([num_units,n_classes]))
out_bias=tf.Variable(tf.random_normal([n_classes]))

#defining placeholders
#input image placeholder
x=tf.placeholder("float",[None,time_steps,n_input])
#input label placeholder
y=tf.placeholder("float",[None,n_classes])

# %%
#processing the input tensor from [batch_size,n_steps,n_input] to "time_steps" number of [batch_size,n_input] tensors
input=tf.unstack(x ,time_steps,1)

# %%
#defining the network
outputs = [];
lstm_layer=rnn.BasicLSTMCell(num_units,forget_bias=1)
outputs,_=rnn.static_rnn(lstm_layer,input,dtype="float32")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-60ffd1a891e8> in <module>()
#       2 outputs = [];
#       3 lstm_layer=rnn.BasicLSTMCell(num_units,forget_bias=1)
# ----> 4 outputs,_=rnn.static_rnn(lstm_layer,input,dtype="float32")
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in static_rnn(cell, inputs, initial_state, dtype, sequence_length, scope)
#    1251             state_size=cell.state_size)
#    1252       else:
# -> 1253         (output, state) = call_cell()
#    1254
#    1255       outputs.append(output)
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in <lambda>()
#    1238         varscope.reuse_variables()
#    1239       # pylint: disable=cell-var-from-loop
# -> 1240       call_cell = lambda: cell(input_, state)
#    1241       # pylint: enable=cell-var-from-loop
#    1242       if sequence_length is not None:
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     181       with vs.variable_scope(vs.get_variable_scope(),
#     182                              custom_getter=self._rnn_get_variable):
# --> 183         return super(RNNCell, self).__call__(inputs, state)
#     184
#     185   def _rnn_get_variable(self, getter, *args, **kwargs):
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     573         if in_graph_mode:
#     574           self._assert_input_compatibility(inputs)
# --> 575         outputs = self.call(inputs, *args, **kwargs)
#     576
#     577         if outputs is None:
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in call(self, inputs, state)
#     436
#     437     if self._linear is None:
# --> 438       self._linear = _Linear([inputs, h], 4 * self._num_units, True)
#     439     # i = input_gate, j = new_input, f = forget_gate, o = output_gate
#     440     i, j, f, o = array_ops.split(
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in __init__(self, args, output_size, build_bias, bias_initializer, kernel_initializer)
#    1169           _WEIGHTS_VARIABLE_NAME, [total_arg_size, output_size],
#    1170           dtype=dtype,
# -> 1171           initializer=kernel_initializer)
#    1172       if build_bias:
#    1173         with vs.variable_scope(outer_scope) as inner_scope:
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1201       partitioner=partitioner, validate_shape=validate_shape,
#    1202       use_resource=use_resource, custom_getter=custom_getter,
# -> 1203       constraint=constraint)
#    1204 get_variable_or_local_docstring = (
#    1205     """%s
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#    1090           partitioner=partitioner, validate_shape=validate_shape,
#    1091           use_resource=use_resource, custom_getter=custom_getter,
# -> 1092           constraint=constraint)
#    1093
#    1094   def _get_partitioned_variable(self,
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint)
#     415       if "constraint" in estimator_util.fn_args(custom_getter):
#     416         custom_getter_kwargs["constraint"] = constraint
# --> 417       return custom_getter(**custom_getter_kwargs)
#     418     else:
#     419       return _true_getter(
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py in _rnn_get_variable(self, getter, *args, **kwargs)
#     184
#     185   def _rnn_get_variable(self, getter, *args, **kwargs):
# --> 186     variable = getter(*args, **kwargs)
#     187     if context.in_graph_mode():
#     188       trainable = (variable in tf_variables.trainable_variables() or
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint)
#     392           trainable=trainable, collections=collections,
#     393           caching_device=caching_device, validate_shape=validate_shape,
# --> 394           use_resource=use_resource, constraint=constraint)
#     395
#     396     if custom_getter is not None:
#
# ~/miniconda3/envs/mlp/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint)
#     740                          "reuse=tf.AUTO_REUSE in VarScope? "
#     741                          "Originally defined at:\n\n%s" % (
# --> 742                              name, "".join(traceback.format_list(tb))))
#     743       found_var = self._vars[name]
#     744       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable rnn/basic_lstm_cell/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "<ipython-input-4-60ffd1a891e8>", line 4, in <module>
#     outputs,_=rnn.static_rnn(lstm_layer,input,dtype="float32")
#   File "/afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/afs/inf.ed.ac.uk/user/s17/s1773005/miniconda3/envs/mlp/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):

# %%
print (outputs)
# Out:
# []

# %%
#converting last output of dimension [batch_size,num_units] to [batch_size,n_classes] by out_weight multiplication
prediction=tf.matmul(outputs[-1],out_weights)+out_bias

# %%
#loss_function
loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y))
#optimization
opt=tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

#model evaluation
correct_prediction=tf.equal(tf.argmax(prediction,1),tf.argmax(y,1))
accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
#initialize variables
init=tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    iter=1
    while iter<800:
        batch_x,batch_y=mnist.train.next_batch(batch_size=batch_size)

        batch_x=batch_x.reshape((batch_size,time_steps,n_input))

        sess.run(opt, feed_dict={x: batch_x, y: batch_y})

        if iter %10==0:
            acc=sess.run(accuracy,feed_dict={x:batch_x,y:batch_y})
            los=sess.run(loss,feed_dict={x:batch_x,y:batch_y})
            print("For iter ",iter)
            print("Accuracy ",acc)
            print("Loss ",los)
            print("__________________")

        iter=iter+1
# Out:
# For iter  10
# Accuracy  0.3125
# Loss  1.8528
# __________________
# For iter  20
# Accuracy  0.53125
# Loss  1.52027
# __________________
# For iter  30
# Accuracy  0.5
# Loss  1.35213
# __________________
# For iter  40
# Accuracy  0.648438
# Loss  1.01119
# __________________
# For iter  50
# Accuracy  0.609375
# Loss  1.16775
# __________________
# For iter  60
# Accuracy  0.695312
# Loss  0.832353
# __________________
# For iter  70
# Accuracy  0.78125
# Loss  0.602419
# __________________
# For iter  80
# Accuracy  0.773438
# Loss  0.648312
# __________________
# For iter  90
# Accuracy  0.78125
# Loss  0.680835
# __________________
# For iter  100
# Accuracy  0.914062
# Loss  0.313708
# __________________
# For iter  110
# Accuracy  0.851562
# Loss  0.449999
# __________________
# For iter  120
# Accuracy  0.859375
# Loss  0.443124
# __________________
# For iter  130
# Accuracy  0.84375
# Loss  0.481302
# __________________
# For iter  140
# Accuracy  0.90625
# Loss  0.303208
# __________________
# For iter  150
# Accuracy  0.929688
# Loss  0.229743
# __________________
# For iter  160
# Accuracy  0.898438
# Loss  0.387679
# __________________
# For iter  170
# Accuracy  0.898438
# Loss  0.330663
# __________________
# For iter  180
# Accuracy  0.921875
# Loss  0.29351
# __________________
# For iter  190
# Accuracy  0.9375
# Loss  0.271448
# __________________
# For iter  200
# Accuracy  0.9375
# Loss  0.204013
# __________________
# For iter  210
# Accuracy  0.9375
# Loss  0.220133
# __________________
# For iter  220
# Accuracy  0.914062
# Loss  0.241215
# __________________
# For iter  230
# Accuracy  0.976562
# Loss  0.11533
# __________________
# For iter  240
# Accuracy  0.929688
# Loss  0.192224
# __________________
# For iter  250
# Accuracy  0.945312
# Loss  0.147064
# __________________
# For iter  260
# Accuracy  0.960938
# Loss  0.214362
# __________________
# For iter  270
# Accuracy  0.9375
# Loss  0.181914
# __________________
# For iter  280
# Accuracy  0.921875
# Loss  0.271993
# __________________
# For iter  290
# Accuracy  0.90625
# Loss  0.263853
# __________________
# For iter  300
# Accuracy  0.976562
# Loss  0.0821898
# __________________
# For iter  310
# Accuracy  0.945312
# Loss  0.177658
# __________________
# For iter  320
# Accuracy  0.929688
# Loss  0.183677
# __________________
# For iter  330
# Accuracy  0.9375
# Loss  0.157376
# __________________
# For iter  340
# Accuracy  0.953125
# Loss  0.152232
# __________________
# For iter  350
# Accuracy  0.945312
# Loss  0.2118
# __________________
# For iter  360
# Accuracy  0.9375
# Loss  0.224755
# __________________
# For iter  370
# Accuracy  0.921875
# Loss  0.192757
# __________________
# For iter  380
# Accuracy  0.945312
# Loss  0.154682
# __________________
# For iter  390
# Accuracy  0.960938
# Loss  0.123325
# __________________
# For iter  400
# Accuracy  0.953125
# Loss  0.137074
# __________________
# For iter  410
# Accuracy  0.976562
# Loss  0.0983485
# __________________
# For iter  420
# Accuracy  0.9375
# Loss  0.183085
# __________________
# For iter  430
# Accuracy  0.960938
# Loss  0.130127
# __________________
# For iter  440
# Accuracy  0.984375
# Loss  0.0873655
# __________________
# For iter  450
# Accuracy  0.945312
# Loss  0.126171
# __________________
# For iter  460
# Accuracy  0.992188
# Loss  0.0702224
# __________________
# For iter  470
# Accuracy  0.914062
# Loss  0.160306
# __________________
# For iter  480
# Accuracy  0.960938
# Loss  0.0994897
# __________________
# For iter  490
# Accuracy  0.960938
# Loss  0.102088
# __________________
# For iter  500
# Accuracy  0.96875
# Loss  0.0821842
# __________________
# For iter  510
# Accuracy  0.976562
# Loss  0.0993008
# __________________
# For iter  520
# Accuracy  0.945312
# Loss  0.156953
# __________________
# For iter  530
# Accuracy  0.953125
# Loss  0.129767
# __________________
# For iter  540
# Accuracy  0.921875
# Loss  0.163017
# __________________
# For iter  550
# Accuracy  0.953125
# Loss  0.110944
# __________________
# For iter  560
# Accuracy  0.992188
# Loss  0.0758268
# __________________
# For iter  570
# Accuracy  0.953125
# Loss  0.17906
# __________________
# For iter  580
# Accuracy  0.976562
# Loss  0.0676852
# __________________
# For iter  590
# Accuracy  0.976562
# Loss  0.169668
# __________________
# For iter  600
# Accuracy  0.96875
# Loss  0.104732
# __________________
# For iter  610
# Accuracy  0.96875
# Loss  0.085388
# __________________
# For iter  620
# Accuracy  0.960938
# Loss  0.108751
# __________________
# For iter  630
# Accuracy  0.953125
# Loss  0.145614
# __________________
# For iter  640
# Accuracy  0.945312
# Loss  0.0982035
# __________________
# For iter  650
# Accuracy  0.96875
# Loss  0.0710377
# __________________
# For iter  660
# Accuracy  0.945312
# Loss  0.206794
# __________________
# For iter  670
# Accuracy  0.992188
# Loss  0.0668783
# __________________
# For iter  680
# Accuracy  0.976562
# Loss  0.0798532
# __________________
# For iter  690
# Accuracy  0.984375
# Loss  0.0863475
# __________________
# For iter  700
# Accuracy  0.921875
# Loss  0.144408
# __________________
# For iter  710
# Accuracy  0.984375
# Loss  0.0659089
# __________________
# For iter  720
# Accuracy  0.953125
# Loss  0.1019
# __________________
# For iter  730
# Accuracy  0.929688
# Loss  0.173891
# __________________
# For iter  740
# Accuracy  1.0
# Loss  0.0410705
# __________________
# For iter  750
# Accuracy  0.976562
# Loss  0.123647
# __________________
# For iter  760
# Accuracy  0.960938
# Loss  0.149676
# __________________
# For iter  770
# Accuracy  0.953125
# Loss  0.109074
# __________________
# For iter  780
# Accuracy  0.945312
# Loss  0.165424
# __________________
# For iter  790
# Accuracy  0.953125
# Loss  0.0901208
# __________________
